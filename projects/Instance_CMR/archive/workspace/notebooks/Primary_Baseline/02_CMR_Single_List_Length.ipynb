# %% [markdown]
# # CMR - Single List Length
# Now that relevant dependencies are specified and testing, we'll jump right into fitting the model to larger portions of the dataset. This time, we'll do the entire 20-item list length subset of the Murdock (1962) dataset.

# %% [markdown]
# ## Load Data

# %%
from instance_cmr.datasets import prepare_murddata
from instance_cmr.model_fitting import cmr_murd_likelihood
from instance_cmr.model_fitting import cmr_murd_objective_function
from instance_cmr.model_fitting import visualize_fit
from instance_cmr.models import CMR

murd_trials0, murd_events0, murd_length0 = prepare_murddata(
    '../../data/MurdData_clean.mat', 0)

murd_events0.head()
# Out:
#    subject  list  item  input  output  study  recall  repeat  intrusion
# 0        1     1     1      1     5.0   True    True       0      False
# 1        1     1     2      2     7.0   True    True       0      False
# 2        1     1     3      3     NaN   True   False       0      False
# 3        1     1     4      4     NaN   True   False       0      False
# 4        1     1     5      5     NaN   True   False       0      False

# %% [markdown]
# ## Fitting

# %%
from scipy.optimize import differential_evolution
from numba.typed import List
import numpy as np

free_parameters = [
    'encoding_drift_rate',
    'start_drift_rate',
    'recall_drift_rate',
    'shared_support',
    'item_support',
    'learning_rate',
    'primacy_scale',
    'primacy_decay',
    'stop_probability_scale',
    'stop_probability_growth',
    'choice_sensitivity']

lb = np.finfo(float).eps
ub = 1-np.finfo(float).eps

bounds = [
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, 100),
    (lb, 100),
    (lb, ub),
    (lb, 10),
    (lb, 10)
]

# cost function to be minimized
# ours scales inversely with the probability that the data could have been 
# generated using the specified parameters and our model
cost_function = cmr_murd_objective_function(
    List([murd_trials0]), 
    {'item_counts': List([murd_length0]), 'sampling_rule': 1}, free_parameters)

result = differential_evolution(cost_function, bounds, disp=True)
print(result)
# Out:
# differential_evolution step 1: f(x)= 41859.3
# differential_evolution step 2: f(x)= 28559.7
# differential_evolution step 3: f(x)= 28559.7
# differential_evolution step 4: f(x)= 26275.9
# differential_evolution step 5: f(x)= 26275.9
# differential_evolution step 6: f(x)= 26260.1
# differential_evolution step 7: f(x)= 25281.9
# differential_evolution step 8: f(x)= 24664.3
# differential_evolution step 9: f(x)= 24411.5
# differential_evolution step 10: f(x)= 23131
# differential_evolution step 11: f(x)= 22779.6
# differential_evolution step 12: f(x)= 22779.6
# differential_evolution step 13: f(x)= 22737.3
# differential_evolution step 14: f(x)= 21742.3
# differential_evolution step 15: f(x)= 21742.3
# differential_evolution step 16: f(x)= 21742.3
# differential_evolution step 17: f(x)= 21673.1
# differential_evolution step 18: f(x)= 21673.1
# differential_evolution step 19: f(x)= 21673.1
# differential_evolution step 20: f(x)= 21673.1
# differential_evolution step 21: f(x)= 21673.1
# differential_evolution step 22: f(x)= 21673.1
# differential_evolution step 23: f(x)= 21673.1
# differential_evolution step 24: f(x)= 21673.1
# differential_evolution step 25: f(x)= 21673.1
# differential_evolution step 26: f(x)= 21673.1
# differential_evolution step 27: f(x)= 21465.6
# differential_evolution step 28: f(x)= 21465.6
# differential_evolution step 29: f(x)= 21465.6
# differential_evolution step 30: f(x)= 21465.6
# differential_evolution step 31: f(x)= 21465.6
# differential_evolution step 32: f(x)= 21465.6
# differential_evolution step 33: f(x)= 21465.6
# differential_evolution step 34: f(x)= 21465.6
# differential_evolution step 35: f(x)= 21465.6
# differential_evolution step 36: f(x)= 21463.2
# differential_evolution step 37: f(x)= 21424.7
# differential_evolution step 38: f(x)= 21424.7
# differential_evolution step 39: f(x)= 21342.7
# differential_evolution step 40: f(x)= 21342.7
# differential_evolution step 41: f(x)= 21328.5
# differential_evolution step 42: f(x)= 21328.5
# differential_evolution step 43: f(x)= 21328.5
# differential_evolution step 44: f(x)= 21242.9
# differential_evolution step 45: f(x)= 21242.9
# differential_evolution step 46: f(x)= 21242.9
# differential_evolution step 47: f(x)= 21242.9
# differential_evolution step 48: f(x)= 21242.9
#      fun: 21044.43341269291
#      jac: array([-1.05610525,  0.92877599,  0.76688593,  0.12332748, -0.16079866,
#         0.10841177,  0.16916602,  0.        ,  2.16859917,  0.93714334,
#        -0.09968062])
#  message: 'Optimization terminated successfully.'
#     nfev: 9765
#      nit: 48
#  success: True
#        x: array([3.84490851e-01, 1.03544139e-01, 8.97147902e-01, 5.72375815e-01,
#        6.50500658e-01, 2.88957939e-01, 1.50208362e+00, 8.57441102e+01,
#        2.86117024e-02, 2.92330837e-01, 3.30045609e-01])

# %% [markdown]
# ## Results
# ```
#      fun: 21239.596136083273
#  message: 'Optimization terminated successfully.'
#     nfev: 9606
#      nit: 57
#  success: True
#        x: array([ 0.54926441,  0.12884982,  0.74057096,  0.26469486,  0.18835232,
#         0.18321188,  2.88148434, 30.13008952,  0.04958878,  0.21112143,
#         5.58388858])
# ```

# %%
parameters = {
    'item_count':murd_length0,
    'presentation_count': murd_length0,
    'sampling_rule': 1
}

visualize_fit(CMR, 
              {**parameters, 
               **{free_parameters[i]:result.x[i] for i in range(len(result.x))}}, 
              murd_events0, 'subject > -1', experiment_count=1000, savefig=True)

# %%
stored_result = np.array([ 0.54926441,  0.12884982,  0.74057096,  0.26469486,  0.18835232,
        0.18321188,  2.88148434, 30.13008952,  0.04958878,  0.21112143,
        5.58388858])
      
parameters = {
    'item_count':murd_length0,
    'presentation_count': murd_length0,
    'sampling_rule', 0
}

visualize_fit(CMR, 
              {**parameters, 
               **{free_parameters[i]:stored_result[i] for i in range(len(stored_result))}}, 
              murd_events0, 'subject > -1', experiment_count=1000, savefig=True)
