# %% [markdown]
# # InstanceCMR - Repetitions Fitting
# Now that relevant dependencies are specified and testing, we'll jump right into fitting the model to larger portions of the dataset. This time, we'll do the entire 20-item list length subset of the Murdock (1962) dataset.

# %% [markdown]
# ## Load Data

# %%
from instance_cmr.datasets import prepare_repdata
from instance_cmr.model_fitting import icmr_rep_likelihood
from instance_cmr.model_fitting import icmr_rep_objective_function
from instance_cmr.model_fitting import visualize_rep_fit
from instance_cmr.models import InstanceCMR

trials, events, list_length, presentations, list_types, rep_data, subjects = prepare_repdata(
    '../../data/repFR.mat')

events.head()
# Out:
#    subject  list  item  input  output  study  recall  repeat  intrusion  \
# 0        1     1     0      1     1.0   True    True       0      False
# 1        1     1     1      2     2.0   True    True       0      False
# 2        1     1     2      3     3.0   True    True       0      False
# 3        1     1     3      4     4.0   True    True       0      False
# 4        1     1     4      5     5.0   True    True       0      False
#
#    condition
# 0          4
# 1          4
# 2          4
# 3          4
# 4          4

# %% [markdown]
# ## Fitting With Echo-Based Sensitivity Parameter

# %%
from scipy.optimize import differential_evolution
from numba.typed import List
import numpy as np

free_parameters = [
    'encoding_drift_rate',
    'start_drift_rate',
    'recall_drift_rate',
    'shared_support',
    'item_support',
    'learning_rate',
    'primacy_scale',
    'primacy_decay',
    'stop_probability_scale',
    'stop_probability_growth',
    'choice_sensitivity']

lb = np.finfo(float).eps
ub = 1-np.finfo(float).eps

bounds = [
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, 100),
    (lb, 100),
    (lb, ub),
    (lb, 10),
    (1, 10)
]

# %%
# cost function to be minimized
# ours scales inversely with the probability that the data could have been 
# generated using the specified parameters and our model
for condition_index, selection in enumerate([list_types == 1, list_types > 1, list_types > 0]):

    cost_function = icmr_rep_objective_function(
            trials[selection], presentations[selection], list_types[selection], list_length,
             {'context_sensitivity': 1, 'feature_sensitivity': 1}, free_parameters)

    result = differential_evolution(cost_function, bounds, disp=True)
    print(result)
# Out:
# differential_evolution step 1: f(x)= 38789.5
# differential_evolution step 2: f(x)= 34444.9
# differential_evolution step 3: f(x)= 29701.2
# differential_evolution step 4: f(x)= 23469.7
# differential_evolution step 5: f(x)= 23352.4
# differential_evolution step 6: f(x)= 23352.4
# differential_evolution step 7: f(x)= 22746.8
# differential_evolution step 8: f(x)= 22128.9
# differential_evolution step 9: f(x)= 22040.2
# differential_evolution step 10: f(x)= 22040.2
# differential_evolution step 11: f(x)= 21878.7
# differential_evolution step 12: f(x)= 21877.6
# differential_evolution step 13: f(x)= 21877.6
# differential_evolution step 14: f(x)= 21822.2
# differential_evolution step 15: f(x)= 21702.1
# differential_evolution step 16: f(x)= 21702.1
# differential_evolution step 17: f(x)= 21702.1
# differential_evolution step 18: f(x)= 21702.1
# differential_evolution step 19: f(x)= 21702.1
# differential_evolution step 20: f(x)= 21663.4
# differential_evolution step 21: f(x)= 21663.4
# differential_evolution step 22: f(x)= 19344.9
# differential_evolution step 23: f(x)= 19344.9
# differential_evolution step 24: f(x)= 19344.9
# differential_evolution step 25: f(x)= 19344.9
# differential_evolution step 26: f(x)= 19344.9
# differential_evolution step 27: f(x)= 19344.9
# differential_evolution step 28: f(x)= 19190.7
# differential_evolution step 29: f(x)= 19190.7
# differential_evolution step 30: f(x)= 19190.7
# differential_evolution step 31: f(x)= 19092.6
# differential_evolution step 32: f(x)= 19092.6
# differential_evolution step 33: f(x)= 19092.6
# differential_evolution step 34: f(x)= 19083.1
# differential_evolution step 35: f(x)= 19083.1
# differential_evolution step 36: f(x)= 19083.1
# differential_evolution step 37: f(x)= 19083.1
# differential_evolution step 38: f(x)= 19083.1
# differential_evolution step 39: f(x)= 19083.1
# differential_evolution step 40: f(x)= 19083.1
# differential_evolution step 41: f(x)= 19032.7
# differential_evolution step 42: f(x)= 19032.7
# differential_evolution step 43: f(x)= 19026.9
# differential_evolution step 44: f(x)= 19003.4
# differential_evolution step 45: f(x)= 19001.9
# differential_evolution step 46: f(x)= 19001.9
# differential_evolution step 47: f(x)= 19001.9
# differential_evolution step 48: f(x)= 19001.9
# differential_evolution step 49: f(x)= 19001.9
# differential_evolution step 50: f(x)= 19001.9
# differential_evolution step 51: f(x)= 18999.2
#      fun: 18922.648442570688
#      jac: array([ 2.86441353e+02, -1.40171323e+01,  2.04308161e+02, -4.84103512e+05,
#         6.10095158e+03, -8.38504639e+02, -1.22163329e+00,  0.00000000e+00,
#         1.12474372e+03,  3.79117410e+01,  3.48663891e+01])
#  message: 'Optimization terminated successfully.'
#     nfev: 10548
#      nit: 51
#  success: True
#        x: array([8.51183986e-01, 5.58979217e-01, 9.73335908e-01, 1.66278952e-05,
#        2.19717916e-03, 5.00818205e-03, 2.13098377e+00, 6.60969216e+01,
#        2.99867976e-02, 7.95858924e-02, 1.23284382e+00])
# differential_evolution step 1: f(x)= 110047
# differential_evolution step 2: f(x)= 55730.1
# differential_evolution step 3: f(x)= 48477.7
# differential_evolution step 4: f(x)= 48477.7
# differential_evolution step 5: f(x)= 48477.7
# differential_evolution step 6: f(x)= 48158.2
# differential_evolution step 7: f(x)= 48158.2
# differential_evolution step 8: f(x)= 48158.2
# differential_evolution step 9: f(x)= 48158.2
# differential_evolution step 10: f(x)= 48158.2
# differential_evolution step 11: f(x)= 48158.2

# %% [markdown]
# 1:
# ```
#      fun: 18893.699623102842
#      jac: array([ -2.6411726 ,  26.22655303,  41.66249689,  -5.70616976,
#          6.89069562,  -7.58045644,   0.81890896,  -0.11823431,
#         -2.05327524,   6.80774975, -32.23576625])
#  message: 'Optimization terminated successfully.'
#     nfev: 14136
#      nit: 71
#  success: True
#        x: array([9.27680726e-01, 2.19052136e-01, 9.96823218e-01, 2.57065752e-04,
#        5.44460212e-01, 2.37385091e-01, 2.38541093e+01, 9.60950231e-01,
#        2.35458005e-02, 9.14176255e-02, 5.20733974e-01])
# ```
#
# 2,3,4:
# ```
#      fun: 41705.95666110226
#      jac: array([-14.48352115,  -3.5157427 , -97.52548018, 127.94771465,
#         14.22886271, -26.20945451,  -1.47992979,   0.        ,
#         52.31922841, -31.09962565,  -4.51400408])
#  message: 'Optimization terminated successfully.'
#     nfev: 9219
#      nit: 42
#  success: True
#        x: array([8.76094526e-01, 8.52373452e-01, 9.70242081e-01, 1.88866325e-04,
#        3.98399638e-02, 3.24525612e-02, 2.38791407e+00, 6.66023782e+01,
#        2.19539367e-02, 1.20933358e-01, 9.80864346e-01])
# ```
#
# 1,2,3,4:
# ```
#      fun: 60731.76861567584
#      jac: array([ 1.79899506e+02,  2.07095581e+02, -7.38997183e+01,  9.18937876e+03,
#        -3.99745477e+02,  2.86886643e+02,  3.04571588e+00,  0.00000000e+00,
#         3.54426447e+01,  2.16765329e+01,  5.13064149e+01])
#  message: 'Optimization terminated successfully.'
#     nfev: 10917
#      nit: 48
#  success: True
#        x: array([8.85729103e-01, 8.64309296e-01, 9.72950128e-01, 9.69878669e-05,
#        2.12559236e-02, 2.29115877e-02, 2.12408541e+00, 6.16905440e+01,
#        2.51658967e-02, 1.01416770e-01, 9.63953204e-01])
# ```

# %%
for subject in np.unique(subjects):
    for condition_index, condition in enumerate([list_types == 1, list_types > 1, list_types > 0]):
    
        print(subject, condition_index)
        selection = np.logical_and(condition, subjects == subject)
        cost_function = icmr_rep_objective_function(
            trials[selection], presentations[selection], list_types[selection], list_length,
            {'context_sensitivity': 1, 'feature_sensitivity': 1}, free_parameters)

        result = differential_evolution(cost_function, bounds, disp=True)
        
        print(result)
# Out:
# 1 0
# differential_evolution step 1: f(x)= 1033.6
# differential_evolution step 2: f(x)= 977.043
# differential_evolution step 3: f(x)= 977.043
# differential_evolution step 4: f(x)= 977.043
# differential_evolution step 5: f(x)= 977.043
# differential_evolution step 6: f(x)= 900.264
# differential_evolution step 7: f(x)= 900.264
# differential_evolution step 8: f(x)= 879.565
# differential_evolution step 9: f(x)= 879.565
# differential_evolution step 10: f(x)= 879.565
# differential_evolution step 11: f(x)= 848.283
# differential_evolution step 12: f(x)= 848.283
# differential_evolution step 13: f(x)= 848.283
# differential_evolution step 14: f(x)= 848.283
# differential_evolution step 15: f(x)= 848.283
# differential_evolution step 16: f(x)= 758.945
# differential_evolution step 17: f(x)= 758.945
# differential_evolution step 18: f(x)= 758.945
# differential_evolution step 19: f(x)= 758.945
# differential_evolution step 20: f(x)= 758.945
# differential_evolution step 21: f(x)= 758.945
# differential_evolution step 22: f(x)= 758.945
# differential_evolution step 23: f(x)= 758.945
# differential_evolution step 24: f(x)= 758.945
# differential_evolution step 25: f(x)= 758.945
# differential_evolution step 26: f(x)= 748.497
# differential_evolution step 27: f(x)= 744.497
# differential_evolution step 28: f(x)= 744.497
# differential_evolution step 29: f(x)= 744.497
# differential_evolution step 30: f(x)= 744.497
# differential_evolution step 31: f(x)= 741.097
# differential_evolution step 32: f(x)= 737.46
# differential_evolution step 33: f(x)= 737.46
# differential_evolution step 34: f(x)= 737.46
# differential_evolution step 35: f(x)= 737.46
# differential_evolution step 36: f(x)= 731.723
# differential_evolution step 37: f(x)= 731.723
# differential_evolution step 38: f(x)= 731.723
# differential_evolution step 39: f(x)= 731.723
# differential_evolution step 40: f(x)= 731.723
# differential_evolution step 41: f(x)= 731.723
# differential_evolution step 42: f(x)= 725.724
# differential_evolution step 43: f(x)= 723.56
# differential_evolution step 44: f(x)= 714.915
# differential_evolution step 45: f(x)= 713.159
# differential_evolution step 46: f(x)= 713.159
# differential_evolution step 47: f(x)= 713.159
# differential_evolution step 48: f(x)= 710.316
# differential_evolution step 49: f(x)= 707.907
# differential_evolution step 50: f(x)= 707.907
# differential_evolution step 51: f(x)= 707.907
# differential_evolution step 52: f(x)= 707.095
# differential_evolution step 53: f(x)= 704.809
# differential_evolution step 54: f(x)= 702.285
# differential_evolution step 55: f(x)= 702.285
# differential_evolution step 56: f(x)= 702.061
# differential_evolution step 57: f(x)= 702.061
# differential_evolution step 58: f(x)= 702.061
# differential_evolution step 59: f(x)= 702.061
# differential_evolution step 60: f(x)= 702.061
# differential_evolution step 61: f(x)= 702.061
# differential_evolution step 62: f(x)= 701.197
# differential_evolution step 63: f(x)= 697.703
# differential_evolution step 64: f(x)= 697.703
#      fun: 693.3921768285054
#      jac: array([ -4.76469493,  -4.47353159,  -0.10600161,   0.23351276,
#          2.6677526 ,   1.33035201,  -0.1476792 ,   0.        ,
#        -34.30106972,  -0.45308752,  -2.25657006])
#  message: 'Optimization terminated successfully.'
#     nfev: 12009
#      nit: 64
#  success: True
#        x: array([8.11161697e-01, 2.75013104e-01, 9.88091342e-01, 1.70397797e-03,
#        4.06608176e-01, 2.90565564e-01, 7.07914204e+00, 9.77636887e+01,
#        9.98075134e-05, 3.61939155e-01, 1.17369772e+00])
# 1 1
# differential_evolution step 1: f(x)= 2274.95
# differential_evolution step 2: f(x)= 1766.02
# differential_evolution step 3: f(x)= 1766.02
# differential_evolution step 4: f(x)= 1766.02
# differential_evolution step 5: f(x)= 1766.02
# differential_evolution step 6: f(x)= 1766.02
# differential_evolution step 7: f(x)= 1750.53
# differential_evolution step 8: f(x)= 1714.81
# differential_evolution step 9: f(x)= 1714.81
# differential_evolution step 10: f(x)= 1685.52
# differential_evolution step 11: f(x)= 1297.87
# differential_evolution step 12: f(x)= 1297.87
# differential_evolution step 13: f(x)= 1297.87
# differential_evolution step 14: f(x)= 1297.87
# differential_evolution step 15: f(x)= 1297.87
# differential_evolution step 16: f(x)= 1297.87
# differential_evolution step 17: f(x)= 1297.87
# differential_evolution step 18: f(x)= 1297.87
# differential_evolution step 19: f(x)= 1297.87
# differential_evolution step 20: f(x)= 1297.87
# differential_evolution step 21: f(x)= 1297.87
# differential_evolution step 22: f(x)= 1297.87
# differential_evolution step 23: f(x)= 1297.87
# differential_evolution step 24: f(x)= 1297.87
# differential_evolution step 25: f(x)= 1297.87
# differential_evolution step 26: f(x)= 1297.87
# differential_evolution step 27: f(x)= 1297.87
# differential_evolution step 28: f(x)= 1297.87
# differential_evolution step 29: f(x)= 1297.87
# differential_evolution step 30: f(x)= 1297.87
# differential_evolution step 31: f(x)= 1249.63
# differential_evolution step 32: f(x)= 1249.63
# differential_evolution step 33: f(x)= 1249.63
# differential_evolution step 34: f(x)= 1249.63
# differential_evolution step 35: f(x)= 1249.63
# differential_evolution step 36: f(x)= 1249.63
# differential_evolution step 37: f(x)= 1243.47
# differential_evolution step 38: f(x)= 1227.38
# differential_evolution step 39: f(x)= 1227.38
# differential_evolution step 40: f(x)= 1227.38
# differential_evolution step 41: f(x)= 1227.38
# differential_evolution step 42: f(x)= 1227.38
# differential_evolution step 43: f(x)= 1224.56
# differential_evolution step 44: f(x)= 1224.56
# differential_evolution step 45: f(x)= 1224.56
# differential_evolution step 46: f(x)= 1224.56
# differential_evolution step 47: f(x)= 1224.56
# differential_evolution step 48: f(x)= 1224.56
# differential_evolution step 49: f(x)= 1224.56
# differential_evolution step 50: f(x)= 1214.68
# differential_evolution step 51: f(x)= 1210.97
# differential_evolution step 52: f(x)= 1210.97
# differential_evolution step 53: f(x)= 1203.66
# differential_evolution step 54: f(x)= 1203.66
# differential_evolution step 55: f(x)= 1203.66
# differential_evolution step 56: f(x)= 1203.66
# differential_evolution step 57: f(x)= 1203.66
# differential_evolution step 58: f(x)= 1202.54
# differential_evolution step 59: f(x)= 1202.54
# differential_evolution step 60: f(x)= 1202.54
# differential_evolution step 61: f(x)= 1202.54
# differential_evolution step 62: f(x)= 1202.54
# differential_evolution step 63: f(x)= 1202.38
# differential_evolution step 64: f(x)= 1202.38
# differential_evolution step 65: f(x)= 1194.08
# differential_evolution step 66: f(x)= 1194.08
# differential_evolution step 67: f(x)= 1184.38
# differential_evolution step 68: f(x)= 1184.38
#      fun: 1171.0527248132898
#      jac: array([ -1.619469  ,  -5.31697421,  -3.35232924, -15.92738954,
#         -2.62514276,  14.11444828,   0.32869136,   2.38530902,
#         17.94307991, -10.05728337,   1.62431207])
#  message: 'Optimization terminated successfully.'
#     nfev: 12969
#      nit: 68
#  success: True
#        x: array([8.15731024e-01, 8.58828551e-01, 9.66807602e-01, 2.65117054e-03,
#        8.61190864e-01, 1.62286052e-01, 8.07465172e+00, 3.41119072e-01,
#        1.39454569e-03, 2.85876198e-01, 1.29322508e+00])
# 1 2
# differential_evolution step 1: f(x)= 4137.7
# differential_evolution step 2: f(x)= 3500.49
# differential_evolution step 3: f(x)= 2971.97
# differential_evolution step 4: f(x)= 2640.28
# differential_evolution step 5: f(x)= 2640.28
# differential_evolution step 6: f(x)= 2636.28
# differential_evolution step 7: f(x)= 2636.28
# differential_evolution step 8: f(x)= 2590.66
# differential_evolution step 9: f(x)= 2590.66
# differential_evolution step 10: f(x)= 2590.66
# differential_evolution step 11: f(x)= 2590.66
# differential_evolution step 12: f(x)= 2587.33
# differential_evolution step 13: f(x)= 2584.21
# differential_evolution step 14: f(x)= 2584.21
# differential_evolution step 15: f(x)= 2573.3
# differential_evolution step 16: f(x)= 2566.67
# differential_evolution step 17: f(x)= 2525.41
# differential_evolution step 18: f(x)= 2514.45
# differential_evolution step 19: f(x)= 2514.45
# differential_evolution step 20: f(x)= 2514.45
# differential_evolution step 21: f(x)= 2514.45
# differential_evolution step 22: f(x)= 2514.45
# differential_evolution step 23: f(x)= 2514.45
#      fun: 2490.0093107515495
#      jac: array([-1.81433278e+01, -1.16622604e+03,  8.94351610e+00,  1.31394700e+00,
#        -1.04801074e+00,  1.03087586e+01,  1.51794653e-01, -4.31738954e+01,
#        -9.39710117e+02, -8.38666438e+01,  2.33117135e+01])
#  message: 'Optimization terminated successfully.'
#     nfev: 4800
#      nit: 23
#  success: True
#        x: array([6.63803457e-01, 9.99891681e-01, 5.95987675e-01, 3.64840358e-01,
#        5.56435103e-01, 5.96251292e-01, 6.10582078e+01, 1.58505437e-01,
#        2.42353210e-03, 2.30559913e-01, 4.97465189e-01])
# 2 0
# differential_evolution step 1: f(x)= 467.368
# differential_evolution step 2: f(x)= 467.368
# differential_evolution step 3: f(x)= 467.368
# differential_evolution step 4: f(x)= 467.368
# differential_evolution step 5: f(x)= 467.368
# differential_evolution step 6: f(x)= 467.368
# differential_evolution step 7: f(x)= 467.368
# differential_evolution step 8: f(x)= 467.368
# differential_evolution step 9: f(x)= 467.368
# differential_evolution step 10: f(x)= 467.368
# differential_evolution step 11: f(x)= 467.368
# differential_evolution step 12: f(x)= 467.368
# differential_evolution step 13: f(x)= 465.008
# differential_evolution step 14: f(x)= 461.309
# differential_evolution step 15: f(x)= 459.592
# differential_evolution step 16: f(x)= 458.509
# differential_evolution step 17: f(x)= 458.509
# differential_evolution step 18: f(x)= 458.212
# differential_evolution step 19: f(x)= 450.346
# differential_evolution step 20: f(x)= 450.346
# differential_evolution step 21: f(x)= 450.346
# differential_evolution step 22: f(x)= 450.346
# differential_evolution step 23: f(x)= 450.346
# differential_evolution step 24: f(x)= 450.346
# differential_evolution step 25: f(x)= 450.346
# differential_evolution step 26: f(x)= 445.588
# differential_evolution step 27: f(x)= 445.588
#      fun: 428.31038418789103
#      jac: array([ 9.87256499e-02,  2.99110069e-02, -1.50180650e+03,  1.08718722e-01,
#         2.79669621e-03, -4.34128803e+02,  5.28643799e-03,  1.58223656e-01,
#        -9.46386081e-02, -1.55762336e-01,  2.49087863e-02])
#  message: 'Optimization terminated successfully.'
#     nfev: 8148
#      nit: 27
#  success: True
#        x: array([8.14362432e-02, 8.85355046e-01, 1.00000000e+00, 7.51826476e-01,
#        2.22044605e-16, 1.00000000e+00, 1.27000898e+00, 2.77060580e-01,
#        1.11372689e-02, 2.65739492e-01, 4.17275265e+00])
# 2 1
# differential_evolution step 1: f(x)= 1834.97
# differential_evolution step 2: f(x)= 1834.97
# differential_evolution step 3: f(x)= 1332.32
# differential_evolution step 4: f(x)= 1332.32
# differential_evolution step 5: f(x)= 1173.77
# differential_evolution step 6: f(x)= 1173.77
# differential_evolution step 7: f(x)= 1173.77
# differential_evolution step 8: f(x)= 1173.69
# differential_evolution step 9: f(x)= 1173.32
# differential_evolution step 10: f(x)= 1173.32
# differential_evolution step 11: f(x)= 1173.32
# differential_evolution step 12: f(x)= 1173.32
# differential_evolution step 13: f(x)= 1171.01
# differential_evolution step 14: f(x)= 1166.9
# differential_evolution step 15: f(x)= 1130.6
# differential_evolution step 16: f(x)= 1130.6
# differential_evolution step 17: f(x)= 1130.6
# differential_evolution step 18: f(x)= 1095.53
# differential_evolution step 19: f(x)= 1095.53
# differential_evolution step 20: f(x)= 1095.53
# differential_evolution step 21: f(x)= 1095.53
# differential_evolution step 22: f(x)= 1095.53
# differential_evolution step 23: f(x)= 1095.53
# differential_evolution step 24: f(x)= 1095.53
# differential_evolution step 25: f(x)= 1076.68
# differential_evolution step 26: f(x)= 1069.63
# differential_evolution step 27: f(x)= 1068.83
# differential_evolution step 28: f(x)= 1042.09
# differential_evolution step 29: f(x)= 1042.09
# differential_evolution step 30: f(x)= 1017.76
# differential_evolution step 31: f(x)= 1017.76
# differential_evolution step 32: f(x)= 1017.76
# differential_evolution step 33: f(x)= 1017.76
# differential_evolution step 34: f(x)= 1017.76
# differential_evolution step 35: f(x)= 1017.76
# differential_evolution step 36: f(x)= 1017.76
# differential_evolution step 37: f(x)= 1017.76
# differential_evolution step 38: f(x)= 1017.76
# differential_evolution step 39: f(x)= 1017.76
# differential_evolution step 40: f(x)= 1017.76
# differential_evolution step 41: f(x)= 1017.76
# differential_evolution step 42: f(x)= 1017.76
# differential_evolution step 43: f(x)= 1010.19
# differential_evolution step 44: f(x)= 1010.19
# differential_evolution step 45: f(x)= 1010.19
# differential_evolution step 46: f(x)= 1010.19
# differential_evolution step 47: f(x)= 1010.19
# differential_evolution step 48: f(x)= 1007.64
# differential_evolution step 49: f(x)= 1007.64
# differential_evolution step 50: f(x)= 1005.77
# differential_evolution step 51: f(x)= 1005.77
# differential_evolution step 52: f(x)= 1005.77
# differential_evolution step 53: f(x)= 1005.77
# differential_evolution step 54: f(x)= 997.116
# differential_evolution step 55: f(x)= 997.116
#      fun: 991.1662858564413
#      jac: array([ 9.73305982e+00, -3.05320782e+00, -7.65008959e+00,  2.45957635e+05,
#         3.47046125e+00,  1.70132353e-01, -4.84419575e-02,  1.05275148e+00,
#        -2.08500069e+01, -1.06549010e+01, -5.34215585e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 11820
#      nit: 55
#  success: True
#        x: array([8.75262641e-01, 1.04314923e-01, 9.91767855e-01, 2.22044605e-16,
#        6.64158570e-04, 3.14845750e-04, 2.04519675e+01, 5.08023678e-01,
#        2.32488529e-02, 1.55740604e-01, 7.61653413e-01])
# 2 2
# differential_evolution step 1: f(x)= 2231.16
# differential_evolution step 2: f(x)= 1649
# differential_evolution step 3: f(x)= 1649
# differential_evolution step 4: f(x)= 1649
# differential_evolution step 5: f(x)= 1649
# differential_evolution step 6: f(x)= 1649
# differential_evolution step 7: f(x)= 1649
# differential_evolution step 8: f(x)= 1635.08
# differential_evolution step 9: f(x)= 1635.08
# differential_evolution step 10: f(x)= 1635.08
# differential_evolution step 11: f(x)= 1629.14
# differential_evolution step 12: f(x)= 1628.43
# differential_evolution step 13: f(x)= 1628.43
# differential_evolution step 14: f(x)= 1527.35
# differential_evolution step 15: f(x)= 1527.35
# differential_evolution step 16: f(x)= 1527.35
# differential_evolution step 17: f(x)= 1527.35
# differential_evolution step 18: f(x)= 1477.86
# differential_evolution step 19: f(x)= 1477.86
# differential_evolution step 20: f(x)= 1477.86
# differential_evolution step 21: f(x)= 1477.86
# differential_evolution step 22: f(x)= 1477.86
# differential_evolution step 23: f(x)= 1477.86
# differential_evolution step 24: f(x)= 1477.86
# differential_evolution step 25: f(x)= 1477.86
# differential_evolution step 26: f(x)= 1477.86
# differential_evolution step 27: f(x)= 1477.86
# differential_evolution step 28: f(x)= 1477.86
# differential_evolution step 29: f(x)= 1477.86
# differential_evolution step 30: f(x)= 1475.42
# differential_evolution step 31: f(x)= 1452.3
# differential_evolution step 32: f(x)= 1452.3
# differential_evolution step 33: f(x)= 1452.3
# differential_evolution step 34: f(x)= 1452.3
# differential_evolution step 35: f(x)= 1450.07
# differential_evolution step 36: f(x)= 1450.07
# differential_evolution step 37: f(x)= 1450.07
# differential_evolution step 38: f(x)= 1450.07
# differential_evolution step 39: f(x)= 1450.07
# differential_evolution step 40: f(x)= 1450.07
# differential_evolution step 41: f(x)= 1439.86
# differential_evolution step 42: f(x)= 1439.86
# differential_evolution step 43: f(x)= 1439.86
# differential_evolution step 44: f(x)= 1439.86
# differential_evolution step 45: f(x)= 1439.86
# differential_evolution step 46: f(x)= 1432.72
# differential_evolution step 47: f(x)= 1432.72
# differential_evolution step 48: f(x)= 1432.72
# differential_evolution step 49: f(x)= 1432.72
# differential_evolution step 50: f(x)= 1432.72
# differential_evolution step 51: f(x)= 1432.72
#      fun: 1413.4366928835639
#      jac: array([-0.12253167,  0.38928647, -0.04663434,  4.02071691,  0.28844624,
#         0.07389644,  0.02735305,  0.01773515, -0.46522928,  0.18519586,
#        -0.13476438])
#  message: 'Optimization terminated successfully.'
#     nfev: 10488
#      nit: 51
#  success: True
#        x: array([8.72785221e-01, 4.98325085e-02, 9.94090367e-01, 9.27917734e-04,
#        8.38145008e-01, 1.80438154e-01, 5.97062589e+01, 8.61784027e-01,
#        2.20817587e-02, 1.66704277e-01, 5.96993789e-01])
# 3 0
# differential_evolution step 1: f(x)= 936.178
# differential_evolution step 2: f(x)= 936.178
# differential_evolution step 3: f(x)= 936.178
# differential_evolution step 4: f(x)= 936.178
# differential_evolution step 5: f(x)= 891.885
# differential_evolution step 6: f(x)= 891.885
# differential_evolution step 7: f(x)= 891.584
# differential_evolution step 8: f(x)= 891.584
# differential_evolution step 9: f(x)= 875.789
# differential_evolution step 10: f(x)= 824.796
# differential_evolution step 11: f(x)= 823.881
# differential_evolution step 12: f(x)= 821.544
# differential_evolution step 13: f(x)= 821.544
# differential_evolution step 14: f(x)= 821.544
# differential_evolution step 15: f(x)= 820.333
# differential_evolution step 16: f(x)= 818.641
# differential_evolution step 17: f(x)= 810.653
# differential_evolution step 18: f(x)= 810.653
# differential_evolution step 19: f(x)= 801.599
# differential_evolution step 20: f(x)= 801.599
# differential_evolution step 21: f(x)= 794.202
# differential_evolution step 22: f(x)= 794.202
# differential_evolution step 23: f(x)= 794.202
# differential_evolution step 24: f(x)= 751.196
# differential_evolution step 25: f(x)= 751.196
# differential_evolution step 26: f(x)= 751.196
# differential_evolution step 27: f(x)= 751.196
# differential_evolution step 28: f(x)= 748.933
# differential_evolution step 29: f(x)= 748.933
# differential_evolution step 30: f(x)= 748.933
# differential_evolution step 31: f(x)= 748.933
# differential_evolution step 32: f(x)= 735.825
# differential_evolution step 33: f(x)= 711.971
# differential_evolution step 34: f(x)= 711.971
# differential_evolution step 35: f(x)= 711.971
# differential_evolution step 36: f(x)= 711.971
# differential_evolution step 37: f(x)= 711.971
# differential_evolution step 38: f(x)= 711.971
# differential_evolution step 39: f(x)= 711.971
# differential_evolution step 40: f(x)= 709.315
# differential_evolution step 41: f(x)= 709.315
# differential_evolution step 42: f(x)= 709.315
# differential_evolution step 43: f(x)= 708.886
# differential_evolution step 44: f(x)= 706.929
# differential_evolution step 45: f(x)= 701.875
# differential_evolution step 46: f(x)= 698.772
# differential_evolution step 47: f(x)= 692.887
# differential_evolution step 48: f(x)= 692.887
# differential_evolution step 49: f(x)= 692.887
# differential_evolution step 50: f(x)= 692.887
# differential_evolution step 51: f(x)= 692.887
# differential_evolution step 52: f(x)= 691.682
# differential_evolution step 53: f(x)= 691.682
#      fun: 684.1852817602553
#      jac: array([-0.04935146,  0.02532943, -0.23601387,  0.38254484,  0.0259206 ,
#         0.05351239,  0.02545448,  0.04276899, -0.14997568,  0.07396466,
#        -0.06430128])
#  message: 'Optimization terminated successfully.'
#     nfev: 10650
#      nit: 53
#  success: True
#        x: array([8.23384682e-01, 8.45458224e-03, 9.31218311e-01, 2.34200955e-03,
#        8.45221323e-01, 3.99020101e-01, 1.91952586e+01, 1.05129093e+00,
#        7.38648423e-03, 1.27797509e-01, 9.65060512e-01])
# 3 1
# differential_evolution step 1: f(x)= 3411.64
# differential_evolution step 2: f(x)= 2472.14
# differential_evolution step 3: f(x)= 2316.42
# differential_evolution step 4: f(x)= 2316.42
# differential_evolution step 5: f(x)= 2316.42
# differential_evolution step 6: f(x)= 1789.1
# differential_evolution step 7: f(x)= 1721.76
# differential_evolution step 8: f(x)= 1721.76
# differential_evolution step 9: f(x)= 1721.76
# differential_evolution step 10: f(x)= 1703.7
# differential_evolution step 11: f(x)= 1703.7
# differential_evolution step 12: f(x)= 1687.78
# differential_evolution step 13: f(x)= 1687.78
# differential_evolution step 14: f(x)= 1687.78
# differential_evolution step 15: f(x)= 1687.78
# differential_evolution step 16: f(x)= 1678.63
# differential_evolution step 17: f(x)= 1670.35
# differential_evolution step 18: f(x)= 1639.47
# differential_evolution step 19: f(x)= 1639.47
# differential_evolution step 20: f(x)= 1639.47
# differential_evolution step 21: f(x)= 1635.83
# differential_evolution step 22: f(x)= 1635.83
# differential_evolution step 23: f(x)= 1605.93
# differential_evolution step 24: f(x)= 1605.93
# differential_evolution step 25: f(x)= 1605.93
# differential_evolution step 26: f(x)= 1595.59
# differential_evolution step 27: f(x)= 1595.59
# differential_evolution step 28: f(x)= 1593.89
# differential_evolution step 29: f(x)= 1593.89
# differential_evolution step 30: f(x)= 1540.45
# differential_evolution step 31: f(x)= 1540.45
# differential_evolution step 32: f(x)= 1540.45
# differential_evolution step 33: f(x)= 1531.55
# differential_evolution step 34: f(x)= 1531.55
# differential_evolution step 35: f(x)= 1527.38
# differential_evolution step 36: f(x)= 1515.35
# differential_evolution step 37: f(x)= 1515.35
# differential_evolution step 38: f(x)= 1515.35
# differential_evolution step 39: f(x)= 1515.35
# differential_evolution step 40: f(x)= 1506.49
# differential_evolution step 41: f(x)= 1506.49
# differential_evolution step 42: f(x)= 1505.39
# differential_evolution step 43: f(x)= 1478.45
# differential_evolution step 44: f(x)= 1478.45
# differential_evolution step 45: f(x)= 1478.45
# differential_evolution step 46: f(x)= 1478.45
# differential_evolution step 47: f(x)= 1478.45
# differential_evolution step 48: f(x)= 1476.32
# differential_evolution step 49: f(x)= 1476.32
# differential_evolution step 50: f(x)= 1476.32
# differential_evolution step 51: f(x)= 1476.32
# differential_evolution step 52: f(x)= 1470.28
# differential_evolution step 53: f(x)= 1466.79
# differential_evolution step 54: f(x)= 1466.79
# differential_evolution step 55: f(x)= 1466.79
# differential_evolution step 56: f(x)= 1466.79
# differential_evolution step 57: f(x)= 1462.24
# differential_evolution step 58: f(x)= 1462.24
# differential_evolution step 59: f(x)= 1462.24
# differential_evolution step 60: f(x)= 1457.73
# differential_evolution step 61: f(x)= 1457.73
# differential_evolution step 62: f(x)= 1457.73
# differential_evolution step 63: f(x)= 1457.31
# differential_evolution step 64: f(x)= 1457.24
#      fun: 1451.812047995352
#      jac: array([ 6.61430019e-02, -1.11497229e+00, -5.70707922e-02, -4.79826667e-01,
#        -5.12909534e-01, -5.34328138e-03,  5.43195714e-02,  7.04858336e-04,
#        -1.25926363e+00,  1.67506187e-01, -1.09002939e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 11553
#      nit: 64
#  success: True
#        x: array([8.76717571e-01, 1.62126295e-01, 9.76979883e-01, 2.19959583e-03,
#        7.08160819e-01, 3.41271389e-01, 6.24508743e+00, 1.08944965e+01,
#        3.23717655e-03, 2.29049486e-01, 8.70293493e-01])
# 3 2
# differential_evolution step 1: f(x)= 3132.82
# differential_evolution step 2: f(x)= 2793.97
# differential_evolution step 3: f(x)= 2793.97
# differential_evolution step 4: f(x)= 2632.93
# differential_evolution step 5: f(x)= 2632.93
# differential_evolution step 6: f(x)= 2531.54
# differential_evolution step 7: f(x)= 2531.54
# differential_evolution step 8: f(x)= 2518.65
# differential_evolution step 9: f(x)= 2510.89
# differential_evolution step 10: f(x)= 2510.89
# differential_evolution step 11: f(x)= 2510.89
# differential_evolution step 12: f(x)= 2510.89
# differential_evolution step 13: f(x)= 2508.33
# differential_evolution step 14: f(x)= 2508.33
# differential_evolution step 15: f(x)= 2508.33
# differential_evolution step 16: f(x)= 2505.31
# differential_evolution step 17: f(x)= 2505.31
# differential_evolution step 18: f(x)= 2505.31
# differential_evolution step 19: f(x)= 2491.84
# differential_evolution step 20: f(x)= 2491.84
# differential_evolution step 21: f(x)= 2451.2
# differential_evolution step 22: f(x)= 2451.2
#      fun: 2163.460624149504
#      jac: array([ 0.00231921, -0.04201866,  1.28429746, -0.6047685 , -0.45656634,
#         0.01100489,  0.12232703,  0.08758434,  0.04947651, -0.09745236,
#         0.07617018])
#  message: 'Optimization terminated successfully.'
#     nfev: 6351
#      nit: 22
#  success: True
#        x: array([9.18119663e-01, 1.79870690e-02, 9.84700804e-01, 3.07128715e-04,
#        7.99894556e-01, 2.55213969e-01, 3.64984548e+01, 7.88195033e+00,
#        9.66095227e-03, 1.36592082e-01, 5.38633762e-01])
# 4 0
# differential_evolution step 1: f(x)= 396.281
# differential_evolution step 2: f(x)= 320.68
# differential_evolution step 3: f(x)= 320.68
# differential_evolution step 4: f(x)= 320.68
# differential_evolution step 5: f(x)= 318.353
# differential_evolution step 6: f(x)= 318.164
# differential_evolution step 7: f(x)= 317.884
# differential_evolution step 8: f(x)= 317.884
# differential_evolution step 9: f(x)= 317.884
# differential_evolution step 10: f(x)= 317.538
# differential_evolution step 11: f(x)= 315.857
# differential_evolution step 12: f(x)= 315.857
# differential_evolution step 13: f(x)= 315.857
# differential_evolution step 14: f(x)= 315.857
# differential_evolution step 15: f(x)= 311.645
# differential_evolution step 16: f(x)= 309.988
# differential_evolution step 17: f(x)= 304.341
# differential_evolution step 18: f(x)= 301.42
# differential_evolution step 19: f(x)= 299.503
# differential_evolution step 20: f(x)= 299.503
# differential_evolution step 21: f(x)= 299.503
# differential_evolution step 22: f(x)= 299.503
# differential_evolution step 23: f(x)= 299.503
# differential_evolution step 24: f(x)= 296.258
# differential_evolution step 25: f(x)= 294.804
# differential_evolution step 26: f(x)= 294.804
# differential_evolution step 27: f(x)= 294.804
# differential_evolution step 28: f(x)= 294.804
# differential_evolution step 29: f(x)= 294.804
# differential_evolution step 30: f(x)= 287.988
# differential_evolution step 31: f(x)= 287.988
# differential_evolution step 32: f(x)= 287.648
# differential_evolution step 33: f(x)= 287.648
# differential_evolution step 34: f(x)= 286.182
# differential_evolution step 35: f(x)= 286.182
# differential_evolution step 36: f(x)= 286.182
# differential_evolution step 37: f(x)= 286.052
# differential_evolution step 38: f(x)= 284.374
# differential_evolution step 39: f(x)= 284.374
# differential_evolution step 40: f(x)= 284.249
# differential_evolution step 41: f(x)= 283.207
# differential_evolution step 42: f(x)= 283.207
# differential_evolution step 43: f(x)= 283.207
# differential_evolution step 44: f(x)= 283.207
# differential_evolution step 45: f(x)= 283.207
# differential_evolution step 46: f(x)= 283.207
#      fun: 282.63866334033287
#      jac: array([ 0.08620873,  0.00100044,  0.04340563,  0.77001232,  0.01551825,
#        -0.14973693, -0.02630145,  0.        ,  0.01385274, -0.00660521,
#        -0.26093971])
#  message: 'Optimization terminated successfully.'
#     nfev: 8871
#      nit: 46
#  success: True
#        x: array([9.15509286e-01, 9.82901653e-02, 9.97824113e-01, 3.99757036e-04,
#        8.14739880e-01, 7.01847736e-01, 9.01871759e+00, 8.16407272e+01,
#        8.00962690e-02, 8.51373690e-02, 4.95342049e-01])
# 4 1
# differential_evolution step 1: f(x)= 931.612
# differential_evolution step 2: f(x)= 931.612
# differential_evolution step 3: f(x)= 931.612
# differential_evolution step 4: f(x)= 888.754
# differential_evolution step 5: f(x)= 888.754
# differential_evolution step 6: f(x)= 888.754
# differential_evolution step 7: f(x)= 888.754
# differential_evolution step 8: f(x)= 888.014
# differential_evolution step 9: f(x)= 877.505
# differential_evolution step 10: f(x)= 877.505
# differential_evolution step 11: f(x)= 877.505
# differential_evolution step 12: f(x)= 877.505
# differential_evolution step 13: f(x)= 877.505
# differential_evolution step 14: f(x)= 877.505
# differential_evolution step 15: f(x)= 877.505
# differential_evolution step 16: f(x)= 877.505
# differential_evolution step 17: f(x)= 877.505
# differential_evolution step 18: f(x)= 877.505
# differential_evolution step 19: f(x)= 877.505
# differential_evolution step 20: f(x)= 863.362
# differential_evolution step 21: f(x)= 863.362
#      fun: 800.5280561985785
#      jac: array([ 2.91739296e+01,  1.29106979e+01,  6.58474161e-01,  8.87656355e+05,
#         9.86531177e+00, -1.82764164e+02,  4.04270361e-02,  0.00000000e+00,
#        -4.70409873e+01, -5.09398660e+01,  9.43828122e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 6714
#      nit: 21
#  success: True
#        x: array([9.42040985e-01, 2.22044605e-16, 9.81542285e-01, 2.22044605e-16,
#        2.22961689e-03, 9.99244729e-01, 2.88367119e+01, 7.21145760e+01,
#        6.00500920e-02, 1.03141788e-01, 6.57974607e-01])
# 4 2
# differential_evolution step 1: f(x)= 1227.4
# differential_evolution step 2: f(x)= 1216.56
# differential_evolution step 3: f(x)= 1216.56
# differential_evolution step 4: f(x)= 1216.56
# differential_evolution step 5: f(x)= 1210.97
# differential_evolution step 6: f(x)= 1207.93
# differential_evolution step 7: f(x)= 1203.93
# differential_evolution step 8: f(x)= 1203.93
# differential_evolution step 9: f(x)= 1203.93
# differential_evolution step 10: f(x)= 1203.93
# differential_evolution step 11: f(x)= 1203.93
# differential_evolution step 12: f(x)= 1203.53
# differential_evolution step 13: f(x)= 1200.04
# differential_evolution step 14: f(x)= 1198.7
# differential_evolution step 15: f(x)= 1195.13
# differential_evolution step 16: f(x)= 1195.13
# differential_evolution step 17: f(x)= 1171.33
# differential_evolution step 18: f(x)= 1161.22
# differential_evolution step 19: f(x)= 1156.36
# differential_evolution step 20: f(x)= 1156.36
# differential_evolution step 21: f(x)= 1156.36
#      fun: 1083.216136004795
#      jac: array([-5.01561314e+00,  1.13239594e+01, -1.49362676e+01,  1.16891293e+05,
#         1.64503899e+02, -5.62254172e+00,  1.19280231e-01,  0.00000000e+00,
#        -1.53424935e+00, -1.55355792e+01,  5.11499818e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 7446
#      nit: 21
#  success: True
#        x: array([8.73678229e-01, 1.88595734e-01, 9.84600784e-01, 2.22044605e-16,
#        3.75380470e-04, 6.52895389e-04, 7.35102600e+00, 5.28891055e+01,
#        6.13990275e-02, 1.12336517e-01, 8.45432623e-01])
# 5 0
# differential_evolution step 1: f(x)= 819.034
# differential_evolution step 2: f(x)= 809.355
# differential_evolution step 3: f(x)= 809.355
# differential_evolution step 4: f(x)= 809.355
# differential_evolution step 5: f(x)= 809.355
# differential_evolution step 6: f(x)= 809.355
# differential_evolution step 7: f(x)= 809.355
# differential_evolution step 8: f(x)= 809.355
# differential_evolution step 9: f(x)= 801.648
# differential_evolution step 10: f(x)= 801.648
# differential_evolution step 11: f(x)= 801.648
# differential_evolution step 12: f(x)= 799.938
# differential_evolution step 13: f(x)= 799.938
# differential_evolution step 14: f(x)= 798.293
# differential_evolution step 15: f(x)= 787.659
# differential_evolution step 16: f(x)= 787.659
# differential_evolution step 17: f(x)= 787.659
# differential_evolution step 18: f(x)= 787.659
# differential_evolution step 19: f(x)= 781.995
# differential_evolution step 20: f(x)= 743.015
# differential_evolution step 21: f(x)= 729.095
# differential_evolution step 22: f(x)= 729.095
# differential_evolution step 23: f(x)= 716.954
# differential_evolution step 24: f(x)= 716.954
# differential_evolution step 25: f(x)= 716.954
# differential_evolution step 26: f(x)= 715.997
# differential_evolution step 27: f(x)= 715.997
# differential_evolution step 28: f(x)= 715.997
# differential_evolution step 29: f(x)= 715.997
# differential_evolution step 30: f(x)= 715.997
# differential_evolution step 31: f(x)= 715.997
# differential_evolution step 32: f(x)= 707.273
# differential_evolution step 33: f(x)= 707.273
# differential_evolution step 34: f(x)= 698.602
# differential_evolution step 35: f(x)= 698.602
# differential_evolution step 36: f(x)= 698.602
# differential_evolution step 37: f(x)= 696.063
# differential_evolution step 38: f(x)= 694.333
# differential_evolution step 39: f(x)= 694.216
# differential_evolution step 40: f(x)= 694.216
# differential_evolution step 41: f(x)= 694.216
# differential_evolution step 42: f(x)= 690.98
# differential_evolution step 43: f(x)= 690.98
# differential_evolution step 44: f(x)= 688.363
# differential_evolution step 45: f(x)= 688.363
# differential_evolution step 46: f(x)= 688.363
# differential_evolution step 47: f(x)= 688.363
# differential_evolution step 48: f(x)= 688.363
# differential_evolution step 49: f(x)= 688.363
# differential_evolution step 50: f(x)= 688.363
# differential_evolution step 51: f(x)= 688.302
# differential_evolution step 52: f(x)= 688.302
#      fun: 675.1434727090693
#      jac: array([-1.56773466e+01, -4.28019424e+05, -3.23429957e+00,  2.63385914e+01,
#         7.27231964e-01, -7.58248007e+00,  5.12022783e-01,  0.00000000e+00,
#        -2.58212822e+01, -3.81760401e-01,  1.89620549e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 10017
#      nit: 52
#  success: True
#        x: array([6.34939729e-01, 1.00000000e+00, 8.82055536e-01, 2.09172287e-04,
#        2.43071026e-01, 7.80306836e-02, 7.94866721e+00, 7.15676609e+01,
#        1.41810613e-03, 2.41259444e-01, 8.98840004e-01])
# 5 1
# differential_evolution step 1: f(x)= 1679.38
# differential_evolution step 2: f(x)= 1679.38
# differential_evolution step 3: f(x)= 1679.38
# differential_evolution step 4: f(x)= 1591.32
# differential_evolution step 5: f(x)= 1591.32
# differential_evolution step 6: f(x)= 1578.27
# differential_evolution step 7: f(x)= 1572.99
# differential_evolution step 8: f(x)= 1565.59
# differential_evolution step 9: f(x)= 1561.56
# differential_evolution step 10: f(x)= 1546.28
# differential_evolution step 11: f(x)= 1546.28
# differential_evolution step 12: f(x)= 1536.46
# differential_evolution step 13: f(x)= 1536.46
# differential_evolution step 14: f(x)= 1529.66
# differential_evolution step 15: f(x)= 1529.66
# differential_evolution step 16: f(x)= 1529.66
# differential_evolution step 17: f(x)= 1527.24
# differential_evolution step 18: f(x)= 1527.24
# differential_evolution step 19: f(x)= 1524.11
# differential_evolution step 20: f(x)= 1485.07
# differential_evolution step 21: f(x)= 1485.07
#      fun: 1370.999392271428
#      jac: array([ 1.62910964e+01, -1.64828495e+07, -3.63153275e+01,  6.07964935e+03,
#         1.51260337e+00, -2.30415253e+01,  8.62883027e-02,  0.00000000e+00,
#         1.28005559e+02,  1.96254860e+01,  1.97110467e+01])
#  message: 'Optimization terminated successfully.'
#     nfev: 7170
#      nit: 21
#  success: True
#        x: array([8.07253098e-01, 1.00000000e+00, 9.64690102e-01, 2.00113870e-06,
#        5.34674756e-01, 1.25759150e-01, 2.59810156e+01, 5.18082740e+01,
#        5.35378215e-03, 2.27387740e-01, 4.21115707e-01])
# 5 2
# differential_evolution step 1: f(x)= 2428.15
# differential_evolution step 2: f(x)= 2428.15
# differential_evolution step 3: f(x)= 2401.28
# differential_evolution step 4: f(x)= 2401.28
# differential_evolution step 5: f(x)= 2396.09
# differential_evolution step 6: f(x)= 2354.55
# differential_evolution step 7: f(x)= 2354.55
# differential_evolution step 8: f(x)= 2354.55
# differential_evolution step 9: f(x)= 2354.55
# differential_evolution step 10: f(x)= 2348.07
# differential_evolution step 11: f(x)= 2348.07
# differential_evolution step 12: f(x)= 2339.02
# differential_evolution step 13: f(x)= 2237.71
# differential_evolution step 14: f(x)= 2237.71
# differential_evolution step 15: f(x)= 2237.71
# differential_evolution step 16: f(x)= 2237.71
# differential_evolution step 17: f(x)= 2237.71
# differential_evolution step 18: f(x)= 2237.71
# differential_evolution step 19: f(x)= 2237.71
# differential_evolution step 20: f(x)= 2237.71
# differential_evolution step 21: f(x)= 2237.71
# differential_evolution step 22: f(x)= 2237.71
# differential_evolution step 23: f(x)= 2237.71
# differential_evolution step 24: f(x)= 2237.71
# differential_evolution step 25: f(x)= 2222.86
# differential_evolution step 26: f(x)= 2222.86
# differential_evolution step 27: f(x)= 2222.86
# differential_evolution step 28: f(x)= 2192.33
# differential_evolution step 29: f(x)= 2167.83
# differential_evolution step 30: f(x)= 2117.59
# differential_evolution step 31: f(x)= 2117.59
# differential_evolution step 32: f(x)= 2117.59
# differential_evolution step 33: f(x)= 2117.59
# differential_evolution step 34: f(x)= 2117.59
# differential_evolution step 35: f(x)= 2117.59
# differential_evolution step 36: f(x)= 2114.98
# differential_evolution step 37: f(x)= 2111.6
# differential_evolution step 38: f(x)= 2111.6
# differential_evolution step 39: f(x)= 2111.6
# differential_evolution step 40: f(x)= 2111.6
# differential_evolution step 41: f(x)= 2106.94
# differential_evolution step 42: f(x)= 2088.08
# differential_evolution step 43: f(x)= 2088.08
# differential_evolution step 44: f(x)= 2088.08
# differential_evolution step 45: f(x)= 2088.08
# differential_evolution step 46: f(x)= 2066.15
# differential_evolution step 47: f(x)= 2066.15
# differential_evolution step 48: f(x)= 2056.63
# differential_evolution step 49: f(x)= 2056.63
# differential_evolution step 50: f(x)= 2056.63
# differential_evolution step 51: f(x)= 2056.63
# differential_evolution step 52: f(x)= 2056.63
# differential_evolution step 53: f(x)= 2056.63
# differential_evolution step 54: f(x)= 2056.63
# differential_evolution step 55: f(x)= 2056.63
# differential_evolution step 56: f(x)= 2056.63
# differential_evolution step 57: f(x)= 2056.63
# differential_evolution step 58: f(x)= 2056.63
# differential_evolution step 59: f(x)= 2056.63
# differential_evolution step 60: f(x)= 2056.63
#      fun: 2048.8234406041347
#      jac: array([ 1.79261405e-01,  1.06088009e+00,  6.05268721e-02, -1.15182957e+00,
#        -7.05995259e-01,  7.57154340e-02, -1.00044418e-03,  0.00000000e+00,
#        -1.03304956e+00,  1.52158464e-01,  7.73070501e-04])
#  message: 'Optimization terminated successfully.'
#     nfev: 12969
#      nit: 60
#  success: True
#        x: array([6.51370678e-01, 9.99722792e-01, 8.86403596e-01, 3.66773379e-03,
#        1.00000000e+00, 2.78841361e-01, 1.22712528e+00, 7.58647254e+01,
#        6.24983489e-03, 1.92311974e-01, 1.23827852e+00])
# 6 0
# differential_evolution step 1: f(x)= 772.943
# differential_evolution step 2: f(x)= 772.943
# differential_evolution step 3: f(x)= 772.943
# differential_evolution step 4: f(x)= 772.943
# differential_evolution step 5: f(x)= 770.065
# differential_evolution step 6: f(x)= 770.065
# differential_evolution step 7: f(x)= 764.635
# differential_evolution step 8: f(x)= 753.013
# differential_evolution step 9: f(x)= 753.013
# differential_evolution step 10: f(x)= 753.013
# differential_evolution step 11: f(x)= 753.013
# differential_evolution step 12: f(x)= 753.013
# differential_evolution step 13: f(x)= 753.013
# differential_evolution step 14: f(x)= 753.013
# differential_evolution step 15: f(x)= 753.013
# differential_evolution step 16: f(x)= 749.458
# differential_evolution step 17: f(x)= 749.458
# differential_evolution step 18: f(x)= 749.458
# differential_evolution step 19: f(x)= 749.458
# differential_evolution step 20: f(x)= 749.458
# differential_evolution step 21: f(x)= 723.381
# differential_evolution step 22: f(x)= 723.381
# differential_evolution step 23: f(x)= 683.211
# differential_evolution step 24: f(x)= 683.211
# differential_evolution step 25: f(x)= 683.211
# differential_evolution step 26: f(x)= 683.211
# differential_evolution step 27: f(x)= 683.211
# differential_evolution step 28: f(x)= 683.211
# differential_evolution step 29: f(x)= 683.211
# differential_evolution step 30: f(x)= 683.211
# differential_evolution step 31: f(x)= 683.211
# differential_evolution step 32: f(x)= 683.211
# differential_evolution step 33: f(x)= 679.758
# differential_evolution step 34: f(x)= 679.758
# differential_evolution step 35: f(x)= 672.461
# differential_evolution step 36: f(x)= 672.189
# differential_evolution step 37: f(x)= 672.189
# differential_evolution step 38: f(x)= 672.189
# differential_evolution step 39: f(x)= 672.189
# differential_evolution step 40: f(x)= 672.189
# differential_evolution step 41: f(x)= 672.189
# differential_evolution step 42: f(x)= 672.189
# differential_evolution step 43: f(x)= 663.033
# differential_evolution step 44: f(x)= 663.033
# differential_evolution step 45: f(x)= 663.033
# differential_evolution step 46: f(x)= 663.033
# differential_evolution step 47: f(x)= 660.52
# differential_evolution step 48: f(x)= 660.478
# differential_evolution step 49: f(x)= 660.478
# differential_evolution step 50: f(x)= 653.098
# differential_evolution step 51: f(x)= 653.098
# differential_evolution step 52: f(x)= 653.098
# differential_evolution step 53: f(x)= 653.098
# differential_evolution step 54: f(x)= 651.38
# differential_evolution step 55: f(x)= 651.38
# differential_evolution step 56: f(x)= 651.38
# differential_evolution step 57: f(x)= 648.269
# differential_evolution step 58: f(x)= 648.269
# differential_evolution step 59: f(x)= 648.269
# differential_evolution step 60: f(x)= 648.269
# differential_evolution step 61: f(x)= 647.384
# differential_evolution step 62: f(x)= 647.384
# differential_evolution step 63: f(x)= 647.384
# differential_evolution step 64: f(x)= 647.384
# differential_evolution step 65: f(x)= 647.036
# differential_evolution step 66: f(x)= 645.468
# differential_evolution step 67: f(x)= 645.468
# differential_evolution step 68: f(x)= 645.468
# differential_evolution step 69: f(x)= 645.468
# differential_evolution step 70: f(x)= 645.297
# differential_evolution step 71: f(x)= 645.297
# differential_evolution step 72: f(x)= 643.777
# differential_evolution step 73: f(x)= 643.777
# differential_evolution step 74: f(x)= 643.777
# differential_evolution step 75: f(x)= 643.777
# differential_evolution step 76: f(x)= 643.777
# differential_evolution step 77: f(x)= 643.777
#      fun: 640.3714290802552
#      jac: array([ 0.08870984,  3.89982233, -0.72698185, 61.74420832, -4.02145588,
#         2.11371116, -0.23276243,  0.        , -0.6754135 , -0.39394763,
#         0.94048574])
#  message: 'Optimization terminated successfully.'
#     nfev: 14430
#      nit: 77
#  success: True
#        x: array([8.04952544e-01, 2.22044605e-16, 9.82715550e-01, 4.98258168e-04,
#        4.02328853e-02, 1.30038607e-01, 1.94290755e+00, 7.45675283e+01,
#        2.22994450e-03, 2.37662590e-01, 1.63140327e+00])
# 6 1
# differential_evolution step 1: f(x)= 3488.3
# differential_evolution step 2: f(x)= 2628.5
# differential_evolution step 3: f(x)= 2011.54
# differential_evolution step 4: f(x)= 1712.42
# differential_evolution step 5: f(x)= 1712.42
# differential_evolution step 6: f(x)= 1701.97
# differential_evolution step 7: f(x)= 1699.38
# differential_evolution step 8: f(x)= 1698.85
# differential_evolution step 9: f(x)= 1680.53
# differential_evolution step 10: f(x)= 1680.53
# differential_evolution step 11: f(x)= 1636.96
# differential_evolution step 12: f(x)= 1636.96
# differential_evolution step 13: f(x)= 1636.96
# differential_evolution step 14: f(x)= 1636.96
# differential_evolution step 15: f(x)= 1636.96
# differential_evolution step 16: f(x)= 1622.4
# differential_evolution step 17: f(x)= 1616.99
# differential_evolution step 18: f(x)= 1616.99
# differential_evolution step 19: f(x)= 1616.99
# differential_evolution step 20: f(x)= 1578.97
# differential_evolution step 21: f(x)= 1578.97
# differential_evolution step 22: f(x)= 1537.59
# differential_evolution step 23: f(x)= 1537.59
# differential_evolution step 24: f(x)= 1537.59
# differential_evolution step 25: f(x)= 1537.59
# differential_evolution step 26: f(x)= 1537.59
# differential_evolution step 27: f(x)= 1513.45
# differential_evolution step 28: f(x)= 1513.45
# differential_evolution step 29: f(x)= 1513.45
# differential_evolution step 30: f(x)= 1505.46
# differential_evolution step 31: f(x)= 1479.63
# differential_evolution step 32: f(x)= 1479.63
# differential_evolution step 33: f(x)= 1457.43
# differential_evolution step 34: f(x)= 1457.43
# differential_evolution step 35: f(x)= 1457.43
# differential_evolution step 36: f(x)= 1457.43
# differential_evolution step 37: f(x)= 1457.43
# differential_evolution step 38: f(x)= 1457.43
# differential_evolution step 39: f(x)= 1448.39
# differential_evolution step 40: f(x)= 1448.39
# differential_evolution step 41: f(x)= 1448.39
# differential_evolution step 42: f(x)= 1448.39
# differential_evolution step 43: f(x)= 1445.93
# differential_evolution step 44: f(x)= 1445.93
# differential_evolution step 45: f(x)= 1445.93
# differential_evolution step 46: f(x)= 1445.93
# differential_evolution step 47: f(x)= 1441.29
# differential_evolution step 48: f(x)= 1441.29
# differential_evolution step 49: f(x)= 1441.29
# differential_evolution step 50: f(x)= 1441.16
# differential_evolution step 51: f(x)= 1441.16
# differential_evolution step 52: f(x)= 1441.16
# differential_evolution step 53: f(x)= 1441.16
# differential_evolution step 54: f(x)= 1441.16
# differential_evolution step 55: f(x)= 1430.28
# differential_evolution step 56: f(x)= 1428.44
# differential_evolution step 57: f(x)= 1428.44
# differential_evolution step 58: f(x)= 1428.44
# differential_evolution step 59: f(x)= 1428.44
# differential_evolution step 60: f(x)= 1427.64
# differential_evolution step 61: f(x)= 1427.64
# differential_evolution step 62: f(x)= 1427.64
# differential_evolution step 63: f(x)= 1427.64
# differential_evolution step 64: f(x)= 1427.64
# differential_evolution step 65: f(x)= 1427.64
#      fun: 1422.0373965673107
#      jac: array([ 0.00161435,  0.06584742,  0.40868144, -0.12182682,  0.40854502,
#         0.04324647, -0.05563834,  0.        ,  0.34128789,  0.02266916,
#         0.01875833])
#  message: 'Optimization terminated successfully.'
#     nfev: 13002
#      nit: 65
#  success: True
#        x: array([8.28689649e-01, 6.77218621e-02, 9.98475586e-01, 3.20056046e-03,
#        6.84381622e-01, 1.88139747e-01, 7.23140182e+00, 3.80829603e+01,
#        1.17582467e-03, 3.13952465e-01, 9.78878824e-01])
# 6 2
# differential_evolution step 1: f(x)= 2635.84
# differential_evolution step 2: f(x)= 2635.84
# differential_evolution step 3: f(x)= 2635.84
# differential_evolution step 4: f(x)= 2635.84
# differential_evolution step 5: f(x)= 2531.14
# differential_evolution step 6: f(x)= 2472.67
# differential_evolution step 7: f(x)= 2472.67
# differential_evolution step 8: f(x)= 2439.74
# differential_evolution step 9: f(x)= 2439.17
# differential_evolution step 10: f(x)= 2439.17
# differential_evolution step 11: f(x)= 2433.56
# differential_evolution step 12: f(x)= 2433.56
# differential_evolution step 13: f(x)= 2433.56
# differential_evolution step 14: f(x)= 2433.56
# differential_evolution step 15: f(x)= 2433.56
# differential_evolution step 16: f(x)= 2433.56
# differential_evolution step 17: f(x)= 2418.81
# differential_evolution step 18: f(x)= 2399.4
# differential_evolution step 19: f(x)= 2399.4
# differential_evolution step 20: f(x)= 2361.97
# differential_evolution step 21: f(x)= 2352.97
# differential_evolution step 22: f(x)= 2352.97
# differential_evolution step 23: f(x)= 2221.7
# differential_evolution step 24: f(x)= 2221.7
# differential_evolution step 25: f(x)= 2182.02
# differential_evolution step 26: f(x)= 2182.02
# differential_evolution step 27: f(x)= 2182.02
# differential_evolution step 28: f(x)= 2182.02
# differential_evolution step 29: f(x)= 2182.02
# differential_evolution step 30: f(x)= 2182.02
# differential_evolution step 31: f(x)= 2176.85
# differential_evolution step 32: f(x)= 2145.75
# differential_evolution step 33: f(x)= 2145.75
# differential_evolution step 34: f(x)= 2132.74
# differential_evolution step 35: f(x)= 2132.74
# differential_evolution step 36: f(x)= 2132.74
# differential_evolution step 37: f(x)= 2132.74
# differential_evolution step 38: f(x)= 2132.74
# differential_evolution step 39: f(x)= 2132.74
# differential_evolution step 40: f(x)= 2132.74
# differential_evolution step 41: f(x)= 2132.74
# differential_evolution step 42: f(x)= 2132.74
# differential_evolution step 43: f(x)= 2132.74
# differential_evolution step 44: f(x)= 2125.12
# differential_evolution step 45: f(x)= 2125.12
# differential_evolution step 46: f(x)= 2121.16
# differential_evolution step 47: f(x)= 2121.16
# differential_evolution step 48: f(x)= 2118.72
# differential_evolution step 49: f(x)= 2104.73
# differential_evolution step 50: f(x)= 2104.73
# differential_evolution step 51: f(x)= 2099.1
# differential_evolution step 52: f(x)= 2099.1
# differential_evolution step 53: f(x)= 2095.95
# differential_evolution step 54: f(x)= 2092.39
# differential_evolution step 55: f(x)= 2092.39
# differential_evolution step 56: f(x)= 2092.39
# differential_evolution step 57: f(x)= 2092.39
#      fun: 2073.35877195745
#      jac: array([-3.37022355e+00, -2.47750904e+00, -1.48906064e+02,  5.29816771e+02,
#        -1.09771463e+00, -2.99496605e-01, -5.75437301e-01,  0.00000000e+00,
# ...
# differential_evolution step 42: f(x)= 1942.1
# differential_evolution step 43: f(x)= 1942.1
# differential_evolution step 44: f(x)= 1942.1
# differential_evolution step 45: f(x)= 1942.1
# differential_evolution step 46: f(x)= 1942.1
# differential_evolution step 47: f(x)= 1937.12
# differential_evolution step 48: f(x)= 1937.12
# differential_evolution step 49: f(x)= 1925.27
# differential_evolution step 50: f(x)= 1925.27
# differential_evolution step 51: f(x)= 1925.27
# differential_evolution step 52: f(x)= 1925.27
# differential_evolution step 53: f(x)= 1919.7
# differential_evolution step 54: f(x)= 1919.7
# differential_evolution step 55: f(x)= 1919.7
# differential_evolution step 56: f(x)= 1919.7
# differential_evolution step 57: f(x)= 1919.7
# differential_evolution step 58: f(x)= 1919.7
# differential_evolution step 59: f(x)= 1919.7
#      fun: 1907.825838842364
#      jac: array([-0.02876277,  0.19265371,  0.32271146, -0.82616225,  0.08958523,
#         0.06818937, -0.29547209,  0.        ,  1.15985586,  0.2235538 ,
#        -0.17073489])
#  message: 'Optimization terminated successfully.'
#     nfev: 10812
#      nit: 59
#  success: True
#        x: array([8.73090050e-01, 7.78849314e-01, 9.85093163e-01, 4.55541231e-03,
#        7.45122655e-01, 4.91983508e-01, 1.73285274e+00, 4.23287796e+01,
#        6.68325508e-03, 1.89761462e-01, 1.24318872e+00])
# 36 0
# differential_evolution step 1: f(x)= 1083.75
# differential_evolution step 2: f(x)= 654.502
# differential_evolution step 3: f(x)= 577.736
# differential_evolution step 4: f(x)= 506.789
# differential_evolution step 5: f(x)= 506.789
# differential_evolution step 6: f(x)= 506.789
# differential_evolution step 7: f(x)= 506.789
# differential_evolution step 8: f(x)= 506.789
# differential_evolution step 9: f(x)= 506.789
# differential_evolution step 10: f(x)= 506.789
# differential_evolution step 11: f(x)= 497.44
# differential_evolution step 12: f(x)= 497.44
# differential_evolution step 13: f(x)= 497.44
# differential_evolution step 14: f(x)= 497.44
# differential_evolution step 15: f(x)= 497.44
# differential_evolution step 16: f(x)= 497.44
# differential_evolution step 17: f(x)= 497.44
# differential_evolution step 18: f(x)= 497.44
# differential_evolution step 19: f(x)= 497.44
# differential_evolution step 20: f(x)= 497.44
# differential_evolution step 21: f(x)= 492.478
# differential_evolution step 22: f(x)= 492.478
# differential_evolution step 23: f(x)= 492.478
# differential_evolution step 24: f(x)= 490.197
# differential_evolution step 25: f(x)= 490.197
# differential_evolution step 26: f(x)= 490.197
# differential_evolution step 27: f(x)= 488.475
# differential_evolution step 28: f(x)= 488.475
# differential_evolution step 29: f(x)= 488.475
# differential_evolution step 30: f(x)= 488.475
# differential_evolution step 31: f(x)= 488.475
# differential_evolution step 32: f(x)= 488.475
# differential_evolution step 33: f(x)= 487.904
# differential_evolution step 34: f(x)= 486.88
# differential_evolution step 35: f(x)= 486.88
# differential_evolution step 36: f(x)= 485.906
# differential_evolution step 37: f(x)= 485.906
# differential_evolution step 38: f(x)= 485.906
# differential_evolution step 39: f(x)= 483.12
# differential_evolution step 40: f(x)= 483.12
# differential_evolution step 41: f(x)= 483.12
# differential_evolution step 42: f(x)= 483.12
# differential_evolution step 43: f(x)= 483.12
# differential_evolution step 44: f(x)= 481.709
# differential_evolution step 45: f(x)= 481.709
# differential_evolution step 46: f(x)= 481.709
# differential_evolution step 47: f(x)= 481.709
# differential_evolution step 48: f(x)= 481.709
#      fun: 478.32131831868355
#      jac: array([-0.02801244, -0.03070113, -0.01887201,  0.0221803 , -0.01871285,
#        -0.002467  ,  0.0520572 ,  0.        , -0.04541221,  0.00030695,
#        -0.01301146])
#  message: 'Optimization terminated successfully.'
#     nfev: 9897
#      nit: 48
#  success: True
#        x: array([7.56556809e-01, 9.71939601e-01, 7.01304692e-01, 4.91031009e-03,
#        8.65644831e-01, 5.75329787e-01, 2.22044605e-16, 7.84942974e+01,
#        1.48218616e-02, 1.79360319e-01, 1.20865985e+00])
# 36 1
# differential_evolution step 1: f(x)= 1287.83
# differential_evolution step 2: f(x)= 1287.83
# differential_evolution step 3: f(x)= 1213.03
# differential_evolution step 4: f(x)= 1213.03
# differential_evolution step 5: f(x)= 1193.19
# differential_evolution step 6: f(x)= 1185.19
# differential_evolution step 7: f(x)= 1185.19
# differential_evolution step 8: f(x)= 1185.19
# differential_evolution step 9: f(x)= 1181.3
# differential_evolution step 10: f(x)= 1179.41
# differential_evolution step 11: f(x)= 1172.05
# differential_evolution step 12: f(x)= 1172.05
# differential_evolution step 13: f(x)= 1172.05
# differential_evolution step 14: f(x)= 1172.05
# differential_evolution step 15: f(x)= 1149.37
# differential_evolution step 16: f(x)= 1149.37
# differential_evolution step 17: f(x)= 1149.37
# differential_evolution step 18: f(x)= 1149.37
# differential_evolution step 19: f(x)= 1149.37
# differential_evolution step 20: f(x)= 1149.37
# differential_evolution step 21: f(x)= 1149.37
#      fun: 1110.9606122502428
#      jac: array([-1.25169208e-01, -1.03972524e+01, -4.34147294e-01,  4.18333457e+00,
#        -2.77395883e-03,  3.83124641e-02, -2.09183783e-02,  0.00000000e+00,
#         5.27506927e-03,  1.06126663e+00, -2.76031642e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 6786
#      nit: 21
#  success: True
#        x: array([9.25134978e-01, 9.99922156e-01, 9.90317198e-01, 5.99169947e-04,
#        9.21759782e-01, 9.77887786e-01, 3.51780302e+00, 7.52765303e+01,
#        3.02840535e-02, 1.26497704e-01, 4.00367387e-01])
# 36 2
# differential_evolution step 1: f(x)= 3568.55
# differential_evolution step 2: f(x)= 1819.63
# differential_evolution step 3: f(x)= 1819.63
# differential_evolution step 4: f(x)= 1754.4
# differential_evolution step 5: f(x)= 1750.38
# differential_evolution step 6: f(x)= 1726.46
# differential_evolution step 7: f(x)= 1726.46
# differential_evolution step 8: f(x)= 1719.46
# differential_evolution step 9: f(x)= 1707.32
# differential_evolution step 10: f(x)= 1704.39
# differential_evolution step 11: f(x)= 1704.39
# differential_evolution step 12: f(x)= 1701.45
# differential_evolution step 13: f(x)= 1701.45
# differential_evolution step 14: f(x)= 1701.02
# differential_evolution step 15: f(x)= 1693.65
# differential_evolution step 16: f(x)= 1693.65
# differential_evolution step 17: f(x)= 1693.65
# differential_evolution step 18: f(x)= 1691.05
# differential_evolution step 19: f(x)= 1691.05
# differential_evolution step 20: f(x)= 1687.44
# differential_evolution step 21: f(x)= 1687.44
# differential_evolution step 22: f(x)= 1687.44
#      fun: 1594.1740417768162
#      jac: array([ 3.04680724e-03,  1.78488334e-02, -1.17097442e-02,  8.93805918e-02,
#        -1.38697941e-03,  2.27373674e-05,  6.31871448e-02,  0.00000000e+00,
#        -5.37966116e-02, -6.66204869e-03, -1.86673787e-02])
#  message: 'Optimization terminated successfully.'
#     nfev: 5319
#      nit: 22
#  success: True
#        x: array([8.74435752e-01, 9.98000108e-01, 9.73952544e-01, 1.30779977e-03,
#        7.26244266e-01, 8.40390655e-01, 2.38682952e+00, 8.02622034e+01,
#        2.61515108e-02, 1.37162252e-01, 5.42156107e-01])
# 37 0
# differential_evolution step 1: f(x)= 436.808
# differential_evolution step 2: f(x)= 310.698
# differential_evolution step 3: f(x)= 310.658
# differential_evolution step 4: f(x)= 310.658
# differential_evolution step 5: f(x)= 309.501
# differential_evolution step 6: f(x)= 309.501
# differential_evolution step 7: f(x)= 309.501
# differential_evolution step 8: f(x)= 306.712
# differential_evolution step 9: f(x)= 306.712
# differential_evolution step 10: f(x)= 306.712
# differential_evolution step 11: f(x)= 306.712
# differential_evolution step 12: f(x)= 306.712
# differential_evolution step 13: f(x)= 295.905
# differential_evolution step 14: f(x)= 295.905
# differential_evolution step 15: f(x)= 295.905
# differential_evolution step 16: f(x)= 295.905
# differential_evolution step 17: f(x)= 275.735
# differential_evolution step 18: f(x)= 275.735
# differential_evolution step 19: f(x)= 275.735
# differential_evolution step 20: f(x)= 275.735
# differential_evolution step 21: f(x)= 275.735
# differential_evolution step 22: f(x)= 275.735
# differential_evolution step 23: f(x)= 273.398
# differential_evolution step 24: f(x)= 273.398
# differential_evolution step 25: f(x)= 273.398
# differential_evolution step 26: f(x)= 273.398
# differential_evolution step 27: f(x)= 273.398
# differential_evolution step 28: f(x)= 273.398
# differential_evolution step 29: f(x)= 267.593
# differential_evolution step 30: f(x)= 267.593
# differential_evolution step 31: f(x)= 267.593
# differential_evolution step 32: f(x)= 267.593
# differential_evolution step 33: f(x)= 266.563
# differential_evolution step 34: f(x)= 266.563
# differential_evolution step 35: f(x)= 266.563
# differential_evolution step 36: f(x)= 264.524
# differential_evolution step 37: f(x)= 264.524
# differential_evolution step 38: f(x)= 263.371
# differential_evolution step 39: f(x)= 263.371
# differential_evolution step 40: f(x)= 261.928
# differential_evolution step 41: f(x)= 261.005
# differential_evolution step 42: f(x)= 259.425
# differential_evolution step 43: f(x)= 259.425
# differential_evolution step 44: f(x)= 259.425
# differential_evolution step 45: f(x)= 259.425
# differential_evolution step 46: f(x)= 259.425
# differential_evolution step 47: f(x)= 258.31
# differential_evolution step 48: f(x)= 258.31
# differential_evolution step 49: f(x)= 258.31
# differential_evolution step 50: f(x)= 258.31
# differential_evolution step 51: f(x)= 258.31
# differential_evolution step 52: f(x)= 258.31
# differential_evolution step 53: f(x)= 258.31
# differential_evolution step 54: f(x)= 258.31
# differential_evolution step 55: f(x)= 258.31
# differential_evolution step 56: f(x)= 258.31
# differential_evolution step 57: f(x)= 258.31
# differential_evolution step 58: f(x)= 258.214
#      fun: 255.56859536168943
#      jac: array([-1.13595035e+00, -2.04520632e+00,  1.70194880e-01,  3.07370641e+04,
#        -7.79990529e+01,  8.37706864e+00,  4.49063012e-02,  0.00000000e+00,
#         8.41690280e+01,  1.39146265e+01, -1.97769056e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 12219
#      nit: 58
#  success: True
#        x: array([8.12210656e-01, 2.80947585e-01, 9.83530638e-01, 5.03602684e-07,
#        1.60271612e-04, 6.15620543e-04, 3.36341689e+00, 8.80672997e+01,
#        6.35614532e-03, 5.37494679e-01, 1.62399306e+00])
# 37 1
# differential_evolution step 1: f(x)= 807.953
# differential_evolution step 2: f(x)= 807.953
# differential_evolution step 3: f(x)= 661.375
# differential_evolution step 4: f(x)= 661.375
# differential_evolution step 5: f(x)= 661.197
# differential_evolution step 6: f(x)= 661.197
# differential_evolution step 7: f(x)= 661.197
# differential_evolution step 8: f(x)= 657.07
# differential_evolution step 9: f(x)= 657.07
# differential_evolution step 10: f(x)= 657.07
# differential_evolution step 11: f(x)= 653.466
# differential_evolution step 12: f(x)= 653.466
# differential_evolution step 13: f(x)= 653.466
# differential_evolution step 14: f(x)= 653.466
# differential_evolution step 15: f(x)= 650.422
# differential_evolution step 16: f(x)= 650.422
# differential_evolution step 17: f(x)= 644.038
# differential_evolution step 18: f(x)= 623.559
# differential_evolution step 19: f(x)= 604.37
# differential_evolution step 20: f(x)= 604.37
# differential_evolution step 21: f(x)= 604.37
# differential_evolution step 22: f(x)= 604.37
# differential_evolution step 23: f(x)= 604.37
# differential_evolution step 24: f(x)= 604.37
# differential_evolution step 25: f(x)= 604.37
# differential_evolution step 26: f(x)= 604.37
# differential_evolution step 27: f(x)= 604.37
# differential_evolution step 28: f(x)= 604.37
# differential_evolution step 29: f(x)= 604.37
# differential_evolution step 30: f(x)= 604.37
# differential_evolution step 31: f(x)= 603.746
# differential_evolution step 32: f(x)= 603.746
# differential_evolution step 33: f(x)= 603.746
# differential_evolution step 34: f(x)= 602.532
# differential_evolution step 35: f(x)= 600.554
# differential_evolution step 36: f(x)= 600.554
# differential_evolution step 37: f(x)= 600.554
# differential_evolution step 38: f(x)= 597.334
# differential_evolution step 39: f(x)= 597.334
# differential_evolution step 40: f(x)= 597.334
# differential_evolution step 41: f(x)= 597.334
# differential_evolution step 42: f(x)= 597.334
# differential_evolution step 43: f(x)= 592.756
# differential_evolution step 44: f(x)= 592.756
# differential_evolution step 45: f(x)= 592.756
# differential_evolution step 46: f(x)= 592.756
# differential_evolution step 47: f(x)= 592.756
# differential_evolution step 48: f(x)= 591.517
#      fun: 590.1100716831975
#      jac: array([ 5.92001467e+00, -1.66789960e+00, -7.79188133e+04,  5.99311534e-01,
#         3.76962815e-01,  8.64622507e-01,  4.90899725e-02,  0.00000000e+00,
#         5.21577021e+00, -1.46959565e+00,  2.05538983e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 8649
#      nit: 48
#  success: True
#        x: array([8.64950163e-01, 1.75481780e-01, 1.00000000e+00, 6.36849695e-03,
#        8.20183684e-01, 4.20622086e-01, 2.68995925e+01, 1.77793980e+01,
#        5.80754118e-02, 2.24134779e-01, 1.02034071e+00])
# 37 2
# differential_evolution step 1: f(x)= 1168.76
# differential_evolution step 2: f(x)= 978.189
# differential_evolution step 3: f(x)= 978.189
# differential_evolution step 4: f(x)= 971.801
# differential_evolution step 5: f(x)= 971.801
# differential_evolution step 6: f(x)= 971.122
# differential_evolution step 7: f(x)= 971.122
# differential_evolution step 8: f(x)= 971.122
# differential_evolution step 9: f(x)= 966.415
# differential_evolution step 10: f(x)= 966.415
# differential_evolution step 11: f(x)= 966.415
# differential_evolution step 12: f(x)= 966.415
# differential_evolution step 13: f(x)= 966.415
# differential_evolution step 14: f(x)= 928.327
# differential_evolution step 15: f(x)= 928.327
# differential_evolution step 16: f(x)= 928.327
# differential_evolution step 17: f(x)= 928.327
# differential_evolution step 18: f(x)= 898
# differential_evolution step 19: f(x)= 898
# differential_evolution step 20: f(x)= 898
# differential_evolution step 21: f(x)= 898
# differential_evolution step 22: f(x)= 898
# differential_evolution step 23: f(x)= 895.47
# differential_evolution step 24: f(x)= 873.943
# differential_evolution step 25: f(x)= 873.943
# differential_evolution step 26: f(x)= 873.943
# differential_evolution step 27: f(x)= 873.943
# differential_evolution step 28: f(x)= 873.943
# differential_evolution step 29: f(x)= 866.563
# differential_evolution step 30: f(x)= 866.563
# differential_evolution step 31: f(x)= 866.563
# differential_evolution step 32: f(x)= 866.563
# differential_evolution step 33: f(x)= 866.563
# differential_evolution step 34: f(x)= 866.563
# differential_evolution step 35: f(x)= 866.563
# differential_evolution step 36: f(x)= 866.563
# differential_evolution step 37: f(x)= 866.563
# differential_evolution step 38: f(x)= 866.563
# differential_evolution step 39: f(x)= 866.563
# differential_evolution step 40: f(x)= 866.563
# differential_evolution step 41: f(x)= 866.563
# differential_evolution step 42: f(x)= 866.563
# differential_evolution step 43: f(x)= 866.563
# differential_evolution step 44: f(x)= 865.129
# differential_evolution step 45: f(x)= 865.129
# differential_evolution step 46: f(x)= 865.129
# differential_evolution step 47: f(x)= 864.443
# differential_evolution step 48: f(x)= 861.445
# differential_evolution step 49: f(x)= 861.445
# differential_evolution step 50: f(x)= 861.445
# differential_evolution step 51: f(x)= 860.186
# differential_evolution step 52: f(x)= 860.186
# differential_evolution step 53: f(x)= 858.46
#      fun: 846.821922130709
#      jac: array([-1.26239910e+01,  3.91955837e+00,  3.78959497e+02,  4.79054791e+02,
#         2.62843969e-01, -2.16027729e+00,  6.08679279e-02,  1.78779375e+00,
#        -2.34764457e+01, -1.66738119e+01, -4.67878183e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 11814
#      nit: 53
#  success: True
#        x: array([8.49119108e-01, 1.91622226e-01, 9.99947688e-01, 1.47051988e-06,
#        3.60102013e-04, 5.03556513e-04, 1.32752059e+01, 2.56747595e+00,
#        4.72152178e-02, 2.51254066e-01, 1.15671779e+00])

# %% [markdown]
# ## Trace-Based Sensitivity

# %%
from scipy.optimize import differential_evolution
from numba.typed import List
import numpy as np

free_parameters = [
    'encoding_drift_rate',
    'start_drift_rate',
    'recall_drift_rate',
    'shared_support',
    'item_support',
    'learning_rate',
    'primacy_scale',
    'primacy_decay',
    'stop_probability_scale',
    'stop_probability_growth',
    'context_sensitivity']

lb = np.finfo(float).eps
ub = 1-np.finfo(float).eps

bounds = [
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, 100),
    (lb, 100),
    (lb, ub),
    (lb, 10),
    (lb, 10)
]

# %%
# cost function to be minimized
# ours scales inversely with the probability that the data could have been 
# generated using the specified parameters and our model
for condition_index, selection in enumerate([list_types == 1, list_types > 1]): #, list_types > 0

    cost_function = icmr_rep_objective_function(
            trials[selection], presentations[selection], list_types[selection], list_length,
             {'choice_sensitivity': 1, 'feature_sensitivity': 1}, free_parameters)

    result = differential_evolution(cost_function, bounds, disp=True)
    print(result)
# Out:
# differential_evolution step 1: f(x)= 37124.5
# differential_evolution step 2: f(x)= 32693.2
# differential_evolution step 3: f(x)= 27901.6
# differential_evolution step 4: f(x)= 22056.2
# differential_evolution step 5: f(x)= 21903
# differential_evolution step 6: f(x)= 21903
# differential_evolution step 7: f(x)= 21903
# differential_evolution step 8: f(x)= 21644.5
# differential_evolution step 9: f(x)= 21644.5
# differential_evolution step 10: f(x)= 21644.5
# differential_evolution step 11: f(x)= 21644.5
# differential_evolution step 12: f(x)= 21644.5
# differential_evolution step 13: f(x)= 21644.5
# differential_evolution step 14: f(x)= 21644.5
# differential_evolution step 15: f(x)= 21644.5
# differential_evolution step 16: f(x)= 21454.7
# differential_evolution step 17: f(x)= 20979.8
# differential_evolution step 18: f(x)= 20979.8
# differential_evolution step 19: f(x)= 20979.8
# differential_evolution step 20: f(x)= 20979.8
# differential_evolution step 21: f(x)= 20979.8
# differential_evolution step 22: f(x)= 20979.8
#      fun: 19098.218026023933
#      jac: array([ 3.62488207e+00,  6.06451064e+00, -2.35130209e+02,  2.41554102e+04,
#        -3.28604074e+01, -1.87393743e+02,  2.00088960e-01,  0.00000000e+00,
#         5.69198164e+00,  4.81086318e+00, -9.93932190e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 5103
#      nit: 22
#  success: True
#        x: array([9.84725082e-01, 6.18614650e-01, 9.99888330e-01, 2.18012206e-06,
#        2.76591916e-01, 7.33807988e-01, 8.24784048e+01, 9.46421512e+01,
#        2.35978806e-02, 9.12987996e-02, 3.02041112e-01])
# differential_evolution step 1: f(x)= 54927.4
# differential_evolution step 2: f(x)= 54927.4
# differential_evolution step 3: f(x)= 54927.4
# differential_evolution step 4: f(x)= 49738.8
# differential_evolution step 5: f(x)= 49738.8
# differential_evolution step 6: f(x)= 48840.3
# differential_evolution step 7: f(x)= 48406
# differential_evolution step 8: f(x)= 48173.4
# differential_evolution step 9: f(x)= 48173.4
# differential_evolution step 10: f(x)= 48163.6
# differential_evolution step 11: f(x)= 47995
# differential_evolution step 12: f(x)= 47488.9
# differential_evolution step 13: f(x)= 47488.9
# differential_evolution step 14: f(x)= 47488.9
# differential_evolution step 15: f(x)= 47488.9
# differential_evolution step 16: f(x)= 47488.9
# differential_evolution step 17: f(x)= 47488.9
# differential_evolution step 18: f(x)= 47488.9
# differential_evolution step 19: f(x)= 45390.6
# differential_evolution step 20: f(x)= 45390.6
# differential_evolution step 21: f(x)= 44237.7
# differential_evolution step 22: f(x)= 44212.4
# differential_evolution step 23: f(x)= 44212.4
# differential_evolution step 24: f(x)= 44137.4
# differential_evolution step 25: f(x)= 43266.9
# differential_evolution step 26: f(x)= 43266.9
# differential_evolution step 27: f(x)= 43266.9
# differential_evolution step 28: f(x)= 43266.9
# differential_evolution step 29: f(x)= 43266.9
# differential_evolution step 30: f(x)= 43198.6
# differential_evolution step 31: f(x)= 43198.6
# differential_evolution step 32: f(x)= 43096.8
# differential_evolution step 33: f(x)= 43096.8
# differential_evolution step 34: f(x)= 42998.5
# differential_evolution step 35: f(x)= 42439.8
# differential_evolution step 36: f(x)= 42439.8
# differential_evolution step 37: f(x)= 42439.8
# differential_evolution step 38: f(x)= 42040.4
# differential_evolution step 39: f(x)= 42040.4
# differential_evolution step 40: f(x)= 42040.4
# differential_evolution step 41: f(x)= 42040.4
# differential_evolution step 42: f(x)= 42040.4
# differential_evolution step 43: f(x)= 42040.4
# differential_evolution step 44: f(x)= 42040.4
# differential_evolution step 45: f(x)= 42040.4
# differential_evolution step 46: f(x)= 42040.4
# differential_evolution step 47: f(x)= 42040.4
# differential_evolution step 48: f(x)= 41969.3
# differential_evolution step 49: f(x)= 41937.2
# differential_evolution step 50: f(x)= 41937.2
# differential_evolution step 51: f(x)= 41937.2
# differential_evolution step 52: f(x)= 41937.2
# differential_evolution step 53: f(x)= 41937.2
# differential_evolution step 54: f(x)= 41937.2
#      fun: 41755.575092051775
#      jac: array([ 23.12444837,  -2.56331985,  -0.15934347,   9.86474333,
#        -50.49369064, 100.90516298,  13.50126703,   0.        ,
#         -8.342613  , -56.25406632,  -2.31666489])
#  message: 'Optimization terminated successfully.'
#     nfev: 12063
#      nit: 54
#  success: True
#        x: array([8.81678157e-01, 6.77627307e-01, 9.84423376e-01, 1.40316632e-04,
#        4.33123134e-02, 1.40160529e-02, 6.40805490e+00, 4.40322799e+01,
#        2.19419807e-02, 1.20925596e-01, 8.40359946e-01])

# %%
for subject in np.unique(subjects):
    for condition_index, condition in enumerate([list_types > 0]):  # list_types == 1, list_types > 1
    
        print(subject, condition_index)
        selection = np.logical_and(condition, subjects == subject)
        cost_function = icmr_rep_objective_function(
            trials[selection], presentations[selection], list_types[selection], list_length,
            {'choice_sensitivity': 1, 'feature_sensitivity': 1}, free_parameters)

        result = differential_evolution(cost_function, bounds, disp=True)
        
        print(result)
# Out:
# 1 0
# differential_evolution step 1: f(x)= 5227.65
# differential_evolution step 2: f(x)= 3303.44
# differential_evolution step 3: f(x)= 3155.21
# differential_evolution step 4: f(x)= 2969.98
# differential_evolution step 5: f(x)= 2709.26
# differential_evolution step 6: f(x)= 2600.69
# differential_evolution step 7: f(x)= 2600.69
# differential_evolution step 8: f(x)= 2600.69
# differential_evolution step 9: f(x)= 2600.69
# differential_evolution step 10: f(x)= 2583.9
# differential_evolution step 11: f(x)= 2583.9
# differential_evolution step 12: f(x)= 2579.42
# differential_evolution step 13: f(x)= 2517.08
# differential_evolution step 14: f(x)= 2517.08
# differential_evolution step 15: f(x)= 2517.08
# differential_evolution step 16: f(x)= 2517.08
# differential_evolution step 17: f(x)= 2473.21
# differential_evolution step 18: f(x)= 2354.8
# differential_evolution step 19: f(x)= 2288.58
# differential_evolution step 20: f(x)= 2288.58
# differential_evolution step 21: f(x)= 2288.58
# differential_evolution step 22: f(x)= 2095.5
# differential_evolution step 23: f(x)= 2095.5
# differential_evolution step 24: f(x)= 2095.5
# differential_evolution step 25: f(x)= 2095.5
# differential_evolution step 26: f(x)= 2095.5
# differential_evolution step 27: f(x)= 2095.5
# differential_evolution step 28: f(x)= 2095.5
# differential_evolution step 29: f(x)= 2031.29
# differential_evolution step 30: f(x)= 2027.2
# differential_evolution step 31: f(x)= 2027.2
# differential_evolution step 32: f(x)= 1990.26
# differential_evolution step 33: f(x)= 1990.26
# differential_evolution step 34: f(x)= 1990.26
# differential_evolution step 35: f(x)= 1983.49
# differential_evolution step 36: f(x)= 1974.84
# differential_evolution step 37: f(x)= 1970.64
# differential_evolution step 38: f(x)= 1970.64
# differential_evolution step 39: f(x)= 1970.64
# differential_evolution step 40: f(x)= 1969.58
# differential_evolution step 41: f(x)= 1963.78
# differential_evolution step 42: f(x)= 1947.5
# differential_evolution step 43: f(x)= 1947.5
# differential_evolution step 44: f(x)= 1947.5
# differential_evolution step 45: f(x)= 1947.5
# differential_evolution step 46: f(x)= 1934.31
# differential_evolution step 47: f(x)= 1934.31
# differential_evolution step 48: f(x)= 1928.76
# differential_evolution step 49: f(x)= 1928.76
# differential_evolution step 50: f(x)= 1928.76
# differential_evolution step 51: f(x)= 1928.76
# differential_evolution step 52: f(x)= 1925.22
# differential_evolution step 53: f(x)= 1925.22
# differential_evolution step 54: f(x)= 1925.22
# differential_evolution step 55: f(x)= 1914.27
# differential_evolution step 56: f(x)= 1907.49
# differential_evolution step 57: f(x)= 1907.49
# differential_evolution step 58: f(x)= 1907.49
#      fun: 1885.4435131911107
#      jac: array([ 9.94987199e-02,  9.45874485e-02, -2.66436472e-01,  5.72299541e-01,
#        -1.70316524e+00, -1.86992111e-01,  5.61999517e-01, -1.47679202e-01,
#         4.08965661e+00,  1.65982783e-03, -2.96176951e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 15471
#      nit: 58
#  success: True
#        x: array([8.31904734e-01, 8.99504522e-01, 9.67905564e-01, 3.85244438e-03,
#        1.00000000e+00, 2.77978435e-01, 4.31090556e+00, 3.62135463e-01,
#        1.54384863e-03, 2.56471493e-01, 1.26313359e+00])
# 2 0
# differential_evolution step 1: f(x)= 1775.71
# differential_evolution step 2: f(x)= 1660.44
# differential_evolution step 3: f(x)= 1660.44
# differential_evolution step 4: f(x)= 1660.44
# differential_evolution step 5: f(x)= 1660.44
# differential_evolution step 6: f(x)= 1660.44
# differential_evolution step 7: f(x)= 1660.44
# differential_evolution step 8: f(x)= 1660.44
# differential_evolution step 9: f(x)= 1640.73
# differential_evolution step 10: f(x)= 1640.73
# differential_evolution step 11: f(x)= 1639.48
# differential_evolution step 12: f(x)= 1639.48
# differential_evolution step 13: f(x)= 1638.88
# differential_evolution step 14: f(x)= 1619.24
# differential_evolution step 15: f(x)= 1619.24
# differential_evolution step 16: f(x)= 1619.24
# differential_evolution step 17: f(x)= 1619.24
# differential_evolution step 18: f(x)= 1610.34
# differential_evolution step 19: f(x)= 1610.34
# differential_evolution step 20: f(x)= 1594.15
# differential_evolution step 21: f(x)= 1594.15
# differential_evolution step 22: f(x)= 1594.11
# differential_evolution step 23: f(x)= 1594.11
# differential_evolution step 24: f(x)= 1590.25
# differential_evolution step 25: f(x)= 1590.25
# differential_evolution step 26: f(x)= 1590.25
# differential_evolution step 27: f(x)= 1524.36
#      fun: 1447.4610244898363
#      jac: array([ 5.22959451e-03,  3.66776476e+00,  1.06861079e+00,  1.36216386e+01,
#        -1.95707344e+00,  7.82374623e+00,  2.26009575e-02,  0.00000000e+00,
#        -4.12064764e+00, -3.66003406e+00,  2.12371560e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 5664
#      nit: 27
#  success: True
#        x: array([9.86198757e-01, 2.52177733e-01, 9.98552892e-01, 6.55584143e-05,
#        4.33865419e-01, 9.68730529e-01, 7.84881649e+01, 5.17111395e+01,
#        2.24555894e-02, 1.65138896e-01, 3.96375986e-01])
# 3 0
# differential_evolution step 1: f(x)= 4434.59
# differential_evolution step 2: f(x)= 3240.17
# differential_evolution step 3: f(x)= 3076.55
# differential_evolution step 4: f(x)= 3047.82
# differential_evolution step 5: f(x)= 2815.77
# differential_evolution step 6: f(x)= 2815.77
# differential_evolution step 7: f(x)= 2578.7
# differential_evolution step 8: f(x)= 2554.94
# differential_evolution step 9: f(x)= 2546.73
# differential_evolution step 10: f(x)= 2533.8
# differential_evolution step 11: f(x)= 2519.54
# differential_evolution step 12: f(x)= 2505.44
# differential_evolution step 13: f(x)= 2505.44
# differential_evolution step 14: f(x)= 2505
# differential_evolution step 15: f(x)= 2504.99
# differential_evolution step 16: f(x)= 2503.5
# differential_evolution step 17: f(x)= 2501.92
# differential_evolution step 18: f(x)= 2501.92
# differential_evolution step 19: f(x)= 2501.92
# differential_evolution step 20: f(x)= 2501.92
# differential_evolution step 21: f(x)= 2501.92
# differential_evolution step 22: f(x)= 2501.92
# differential_evolution step 23: f(x)= 2467.73
#      fun: 2336.7290032970586
#      jac: array([-2.89316220e+02,  4.25784490e+00, -1.10051087e+02,  1.29251979e+06,
#        -5.86305757e+00,  1.39307304e+00,  3.12866152e-02,  0.00000000e+00,
#        -2.49937057e+02,  1.53284009e+02, -2.61770583e+02])
#  message: 'Optimization terminated successfully.'
#     nfev: 7236
#      nit: 23
#  success: True
#        x: array([9.65637313e-01, 5.36628881e-01, 4.37607375e-01, 2.22044605e-16,
#        7.85895599e-01, 1.35877457e-01, 5.57659388e+01, 6.33249284e+01,
#        5.23480832e-03, 1.60637545e-01, 2.21189329e-01])
# 4 0
# differential_evolution step 1: f(x)= 1208.29
# differential_evolution step 2: f(x)= 1208.29
# differential_evolution step 3: f(x)= 1208.29
# differential_evolution step 4: f(x)= 1205
# differential_evolution step 5: f(x)= 1205
# differential_evolution step 6: f(x)= 1205
# differential_evolution step 7: f(x)= 1204.85
# differential_evolution step 8: f(x)= 1202.01
# differential_evolution step 9: f(x)= 1202.01
# differential_evolution step 10: f(x)= 1202.01
# differential_evolution step 11: f(x)= 1202.01
# differential_evolution step 12: f(x)= 1202.01
# differential_evolution step 13: f(x)= 1202.01
# differential_evolution step 14: f(x)= 1200.46
# differential_evolution step 15: f(x)= 1200.46
# differential_evolution step 16: f(x)= 1194.66
# differential_evolution step 17: f(x)= 1194.66
# differential_evolution step 18: f(x)= 1189.63
# differential_evolution step 19: f(x)= 1189.63
# differential_evolution step 20: f(x)= 1189.63
# differential_evolution step 21: f(x)= 1176.2
# differential_evolution step 22: f(x)= 1176.16
# differential_evolution step 23: f(x)= 1176.16
#      fun: 1083.2591090660117
#      jac: array([-1.48958860e+01,  6.97855285e+00, -5.54599407e+01,  2.48518802e+04,
#        -1.29307409e+00, -3.34816832e+00, -1.01499609e-01,  0.00000000e+00,
#         4.38150891e+01,  2.68912118e+01, -3.48643423e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 6864
#      nit: 23
#  success: True
#        x: array([8.70500668e-01, 1.51539771e-01, 9.75833537e-01, 2.22044605e-16,
#        3.96286096e-04, 1.43909691e-04, 6.94833345e+00, 1.75187671e+01,
#        5.53955867e-02, 1.31076196e-01, 8.39680299e-01])
# 5 0
# differential_evolution step 1: f(x)= 2366.08
# differential_evolution step 2: f(x)= 2366.08
# differential_evolution step 3: f(x)= 2366.08
# differential_evolution step 4: f(x)= 2366.08
# differential_evolution step 5: f(x)= 2366.08
# differential_evolution step 6: f(x)= 2366.08
# differential_evolution step 7: f(x)= 2366.08
# differential_evolution step 8: f(x)= 2366.08
# differential_evolution step 9: f(x)= 2366.08
# differential_evolution step 10: f(x)= 2366.08
# differential_evolution step 11: f(x)= 2358.25
# differential_evolution step 12: f(x)= 2358.25
# differential_evolution step 13: f(x)= 2308.26
# differential_evolution step 14: f(x)= 2308.26
# differential_evolution step 15: f(x)= 2308.26
# differential_evolution step 16: f(x)= 2308.26
# differential_evolution step 17: f(x)= 2251.63
# differential_evolution step 18: f(x)= 2251.63
# differential_evolution step 19: f(x)= 2224.94
# differential_evolution step 20: f(x)= 2224.94
# differential_evolution step 21: f(x)= 2213.11
# differential_evolution step 22: f(x)= 2213.11
# differential_evolution step 23: f(x)= 2201.6
# differential_evolution step 24: f(x)= 2201.6
# differential_evolution step 25: f(x)= 2201.6
# differential_evolution step 26: f(x)= 2198.92
# differential_evolution step 27: f(x)= 2198.92
# differential_evolution step 28: f(x)= 2198.92
# differential_evolution step 29: f(x)= 2147.39
# differential_evolution step 30: f(x)= 2147.39
# differential_evolution step 31: f(x)= 2147.39
# differential_evolution step 32: f(x)= 2122.13
# differential_evolution step 33: f(x)= 2122.13
# differential_evolution step 34: f(x)= 2122.13
# differential_evolution step 35: f(x)= 2122.13
# differential_evolution step 36: f(x)= 2106.56
# differential_evolution step 37: f(x)= 2106.56
# differential_evolution step 38: f(x)= 2106.56
# differential_evolution step 39: f(x)= 2106.56
# differential_evolution step 40: f(x)= 2106.56
# differential_evolution step 41: f(x)= 2106.56
# differential_evolution step 42: f(x)= 2106.56
# differential_evolution step 43: f(x)= 2106.56
# differential_evolution step 44: f(x)= 2106.56
# differential_evolution step 45: f(x)= 2106.56
# differential_evolution step 46: f(x)= 2106.56
# differential_evolution step 47: f(x)= 2104.06
# differential_evolution step 48: f(x)= 2094.93
# differential_evolution step 49: f(x)= 2094.93
# differential_evolution step 50: f(x)= 2078.92
# differential_evolution step 51: f(x)= 2078.92
# differential_evolution step 52: f(x)= 2078.92
# differential_evolution step 53: f(x)= 2078.92
# differential_evolution step 54: f(x)= 2073.63
# differential_evolution step 55: f(x)= 2073.63
# differential_evolution step 56: f(x)= 2071.46
# differential_evolution step 57: f(x)= 2066.09
# differential_evolution step 58: f(x)= 2066.09
# differential_evolution step 59: f(x)= 2066.09
# differential_evolution step 60: f(x)= 2066.09
# differential_evolution step 61: f(x)= 2066.09
# differential_evolution step 62: f(x)= 2066.09
# differential_evolution step 63: f(x)= 2060.7
# differential_evolution step 64: f(x)= 2060.7
#      fun: 2049.1180167393286
#      jac: array([-0.44183252, -3.44139151,  0.41800376,  2.91374818, -0.66638676,
#        -0.07539711,  0.63009793,  0.        , -1.79961717, -0.39731276,
#        -0.5077709 ])
#  message: 'Optimization terminated successfully.'
#     nfev: 12213
#      nit: 64
#  success: True
#        x: array([6.60575886e-01, 9.99822923e-01, 8.90801836e-01, 3.05431962e-03,
#        9.87580105e-01, 3.20559370e-01, 1.61105239e+00, 5.17427286e+01,
#        6.26729744e-03, 1.92152477e-01, 1.14370952e+00])
# 6 0
# differential_evolution step 1: f(x)= 3051.82
# differential_evolution step 2: f(x)= 2606.91
# differential_evolution step 3: f(x)= 2606.91
# differential_evolution step 4: f(x)= 2467.36
# differential_evolution step 5: f(x)= 2467.36
# differential_evolution step 6: f(x)= 2434.94
# differential_evolution step 7: f(x)= 2434.94
# differential_evolution step 8: f(x)= 2434.94
# differential_evolution step 9: f(x)= 2434.94
# differential_evolution step 10: f(x)= 2434.94
# differential_evolution step 11: f(x)= 2434.94
# differential_evolution step 12: f(x)= 2434.94
# differential_evolution step 13: f(x)= 2434.94
# differential_evolution step 14: f(x)= 2434.94
# differential_evolution step 15: f(x)= 2355.09
# differential_evolution step 16: f(x)= 2355.09
# differential_evolution step 17: f(x)= 2355.09
# differential_evolution step 18: f(x)= 2355.09
# differential_evolution step 19: f(x)= 2355.09
# differential_evolution step 20: f(x)= 2355.09
# differential_evolution step 21: f(x)= 2355.09
# differential_evolution step 22: f(x)= 2311.23
# differential_evolution step 23: f(x)= 2311.23
# differential_evolution step 24: f(x)= 2311.23
# differential_evolution step 25: f(x)= 2273.01
# differential_evolution step 26: f(x)= 2273.01
# differential_evolution step 27: f(x)= 2273.01
# differential_evolution step 28: f(x)= 2189.65
# differential_evolution step 29: f(x)= 2189.65
# differential_evolution step 30: f(x)= 2189.65
# differential_evolution step 31: f(x)= 2189.65
# differential_evolution step 32: f(x)= 2189.65
# differential_evolution step 33: f(x)= 2189.65
# differential_evolution step 34: f(x)= 2189.65
# differential_evolution step 35: f(x)= 2189.65
# differential_evolution step 36: f(x)= 2189.65
# differential_evolution step 37: f(x)= 2189.65
# differential_evolution step 38: f(x)= 2189.65
# differential_evolution step 39: f(x)= 2189.65
# differential_evolution step 40: f(x)= 2189.65
# differential_evolution step 41: f(x)= 2184.74
# differential_evolution step 42: f(x)= 2184.74
# differential_evolution step 43: f(x)= 2176.27
# differential_evolution step 44: f(x)= 2176.27
# differential_evolution step 45: f(x)= 2168.98
# differential_evolution step 46: f(x)= 2126.05
# differential_evolution step 47: f(x)= 2110.28
# differential_evolution step 48: f(x)= 2110.28
# differential_evolution step 49: f(x)= 2105.23
# differential_evolution step 50: f(x)= 2105.23
# differential_evolution step 51: f(x)= 2105.23
# differential_evolution step 52: f(x)= 2093.35
# differential_evolution step 53: f(x)= 2093.35
# differential_evolution step 54: f(x)= 2093.35
# differential_evolution step 55: f(x)= 2093.35
# differential_evolution step 56: f(x)= 2093.35
# differential_evolution step 57: f(x)= 2093.35
# differential_evolution step 58: f(x)= 2089.27
# differential_evolution step 59: f(x)= 2089.27
# differential_evolution step 60: f(x)= 2083.82
# differential_evolution step 61: f(x)= 2083.82
# differential_evolution step 62: f(x)= 2083.82
# differential_evolution step 63: f(x)= 2083.82
# differential_evolution step 64: f(x)= 2083.82
# differential_evolution step 65: f(x)= 2083.82
#      fun: 2065.64972698386
#      jac: array([-0.19035724,  0.05056791,  0.11450538,  1.09243956,  0.66970642,
#         0.04192771, -0.45461093,  0.20090738, -2.28919816, -0.54369593,
#         0.37925929])
#  message: 'Optimization terminated successfully.'
#     nfev: 13818
#      nit: 65
#  success: True
#        x: array([8.03675521e-01, 4.42597839e-02, 9.93237568e-01, 4.60768667e-03,
#        4.11522394e-01, 4.23454735e-01, 3.52677666e+00, 9.35076046e-01,
#        3.11612608e-03, 2.35283241e-01, 1.48348530e+00])
# 7 0
# differential_evolution step 1: f(x)= 1241.73
# differential_evolution step 2: f(x)= 1241.73
# differential_evolution step 3: f(x)= 1241.73
# differential_evolution step 4: f(x)= 1241.73
# differential_evolution step 5: f(x)= 1094.73
# differential_evolution step 6: f(x)= 1092.06
# differential_evolution step 7: f(x)= 1090.81
# differential_evolution step 8: f(x)= 1090.81
# differential_evolution step 9: f(x)= 1090.81
# differential_evolution step 10: f(x)= 1090.81
# differential_evolution step 11: f(x)= 1086.67
# differential_evolution step 12: f(x)= 1086.67
# differential_evolution step 13: f(x)= 1086.67
# differential_evolution step 14: f(x)= 1086.67
# differential_evolution step 15: f(x)= 1086.67
# differential_evolution step 16: f(x)= 1086.54
# differential_evolution step 17: f(x)= 1083.2
#      fun: 1050.036260726569
#      jac: array([ 6.25277607e-03,  1.20508047e-03,  3.77440299e-03, -2.78259903e-01,
#        -1.79852577e-02, -4.68073720e+00, -2.41016097e-03,  2.95585778e-04,
#        -6.66204869e-03,  2.47837306e-03, -1.06865628e-03])
#  message: 'Optimization terminated successfully.'
#     nfev: 6090
#      nit: 17
#  success: True
#        x: array([4.83929189e-02, 6.47256209e-01, 9.19593569e-01, 1.00000000e+00,
#        6.16738541e-04, 1.00000000e+00, 1.32041559e+00, 3.24292411e-01,
#        7.56504907e-02, 1.18064624e-01, 4.26367385e+00])
# 8 0
# differential_evolution step 1: f(x)= 2662.34
# differential_evolution step 2: f(x)= 2125.54
# differential_evolution step 3: f(x)= 2125.54
# differential_evolution step 4: f(x)= 2125.54
# differential_evolution step 5: f(x)= 2099.82
# differential_evolution step 6: f(x)= 2099.82
# differential_evolution step 7: f(x)= 2099.82
# differential_evolution step 8: f(x)= 2099.82
# differential_evolution step 9: f(x)= 2091.34
# differential_evolution step 10: f(x)= 2091.34
# differential_evolution step 11: f(x)= 2091.34
# differential_evolution step 12: f(x)= 2090.56
# differential_evolution step 13: f(x)= 2090.56
# differential_evolution step 14: f(x)= 2090.56
# differential_evolution step 15: f(x)= 2090.56
# differential_evolution step 16: f(x)= 2088.75
# differential_evolution step 17: f(x)= 2088.21
# differential_evolution step 18: f(x)= 2083.43
# differential_evolution step 19: f(x)= 2031.37
# differential_evolution step 20: f(x)= 2031.37
# differential_evolution step 21: f(x)= 2031.37
# differential_evolution step 22: f(x)= 2031.37
# differential_evolution step 23: f(x)= 2031.37
# differential_evolution step 24: f(x)= 2031.37
#      fun: 1981.2136169741416
#      jac: array([ 0.08694769,  1.58563579,  2.48328432,  2.11857696,  4.84278644,
#         2.48580818,  0.12435066,  0.        ,  2.28860699,  0.62477739,
#        -0.22407676])
#  message: 'Optimization terminated successfully.'
#     nfev: 6033
#      nit: 24
#  success: True
#        x: array([9.66217666e-01, 9.75822971e-01, 9.90238484e-01, 2.00179541e-04,
#        2.29927557e-01, 2.11852152e-04, 7.31850501e+00, 4.89598957e+01,
#        1.75554034e-02, 1.25387005e-01, 4.46882633e-01])
# 10 0
# differential_evolution step 1: f(x)= 4540.57
# differential_evolution step 2: f(x)= 3655.19
# differential_evolution step 3: f(x)= 3073.95
# differential_evolution step 4: f(x)= 3073.95
# differential_evolution step 5: f(x)= 3073.95
# differential_evolution step 6: f(x)= 2015.66
# differential_evolution step 7: f(x)= 2015.66
# differential_evolution step 8: f(x)= 1947.87
# differential_evolution step 9: f(x)= 1947.87
# differential_evolution step 10: f(x)= 1947.7
# differential_evolution step 11: f(x)= 1947.7
# differential_evolution step 12: f(x)= 1947.7
# differential_evolution step 13: f(x)= 1929.49
# differential_evolution step 14: f(x)= 1895.96
# differential_evolution step 15: f(x)= 1735.73
# differential_evolution step 16: f(x)= 1693.65
# differential_evolution step 17: f(x)= 1693.65
# differential_evolution step 18: f(x)= 1693.65
# differential_evolution step 19: f(x)= 1693.65
# differential_evolution step 20: f(x)= 1693.65
# differential_evolution step 21: f(x)= 1689.54
# differential_evolution step 22: f(x)= 1689.54
# differential_evolution step 23: f(x)= 1689.54
# differential_evolution step 24: f(x)= 1689.54
# differential_evolution step 25: f(x)= 1689.54
# differential_evolution step 26: f(x)= 1689.54
# differential_evolution step 27: f(x)= 1689.54
# differential_evolution step 28: f(x)= 1689.54
# differential_evolution step 29: f(x)= 1689.54
# differential_evolution step 30: f(x)= 1689.54
# differential_evolution step 31: f(x)= 1664.5
# differential_evolution step 32: f(x)= 1664.5
# differential_evolution step 33: f(x)= 1664.5
# differential_evolution step 34: f(x)= 1635.79
# differential_evolution step 35: f(x)= 1635.79
# differential_evolution step 36: f(x)= 1621.79
# differential_evolution step 37: f(x)= 1605.28
# differential_evolution step 38: f(x)= 1605.28
# differential_evolution step 39: f(x)= 1578.71
# differential_evolution step 40: f(x)= 1575.55
# differential_evolution step 41: f(x)= 1569.16
# differential_evolution step 42: f(x)= 1569.16
# differential_evolution step 43: f(x)= 1560.03
# differential_evolution step 44: f(x)= 1559.3
# differential_evolution step 45: f(x)= 1555.84
# differential_evolution step 46: f(x)= 1555.84
# differential_evolution step 47: f(x)= 1555.84
# differential_evolution step 48: f(x)= 1555.23
# differential_evolution step 49: f(x)= 1549.8
# differential_evolution step 50: f(x)= 1546.17
# differential_evolution step 51: f(x)= 1546.17
# differential_evolution step 52: f(x)= 1541.96
# differential_evolution step 53: f(x)= 1539.85
# differential_evolution step 54: f(x)= 1539.85
# differential_evolution step 55: f(x)= 1539.85
# differential_evolution step 56: f(x)= 1539.85
# differential_evolution step 57: f(x)= 1539.85
# differential_evolution step 58: f(x)= 1539.85
# differential_evolution step 59: f(x)= 1536.47
#      fun: 1532.341366885666
#      jac: array([ 0.02346496,  0.01216449, -0.03919922,  0.27403075, -0.11680186,
#        -0.01909939,  0.01650733,  0.        ,  0.05916263, -0.02837623,
#         0.0110731 ])
#  message: 'Optimization terminated successfully.'
#     nfev: 12324
#      nit: 59
#  success: True
#        x: array([8.14360971e-01, 1.12457332e-01, 9.94283868e-01, 4.88785262e-03,
#        9.73963827e-01, 4.11675093e-01, 4.51810916e+00, 2.10176721e+01,
#        3.66762591e-02, 6.45906404e-02, 1.31623901e+00])
# 11 0
# differential_evolution step 1: f(x)= 3203.61
# differential_evolution step 2: f(x)= 2983.22
# differential_evolution step 3: f(x)= 2983.22
# differential_evolution step 4: f(x)= 2729.97
# differential_evolution step 5: f(x)= 2729.97
# differential_evolution step 6: f(x)= 2729.97
# differential_evolution step 7: f(x)= 2729.97
# differential_evolution step 8: f(x)= 2705.09
# differential_evolution step 9: f(x)= 2705.09
# differential_evolution step 10: f(x)= 2683.36
# differential_evolution step 11: f(x)= 2683.36
# differential_evolution step 12: f(x)= 2652.58
# differential_evolution step 13: f(x)= 2652.58
# differential_evolution step 14: f(x)= 2637.86
# differential_evolution step 15: f(x)= 2625.93
# differential_evolution step 16: f(x)= 2625.93
# differential_evolution step 17: f(x)= 2618.16
# differential_evolution step 18: f(x)= 2611.45
# differential_evolution step 19: f(x)= 2611.45
# differential_evolution step 20: f(x)= 2611.45
# differential_evolution step 21: f(x)= 2611.45
# differential_evolution step 22: f(x)= 2611.45
# differential_evolution step 23: f(x)= 2611.45
# differential_evolution step 24: f(x)= 2604.48
# differential_evolution step 25: f(x)= 2604.48
# differential_evolution step 26: f(x)= 2604.48
# differential_evolution step 27: f(x)= 2548.04
# differential_evolution step 28: f(x)= 2548.04
# differential_evolution step 29: f(x)= 2548.04
# differential_evolution step 30: f(x)= 2548.04
# differential_evolution step 31: f(x)= 2548.04
# differential_evolution step 32: f(x)= 2548.04
# differential_evolution step 33: f(x)= 2548.04
# differential_evolution step 34: f(x)= 2548.04
# differential_evolution step 35: f(x)= 2537.13
# differential_evolution step 36: f(x)= 2537.13
# differential_evolution step 37: f(x)= 2537.13
# differential_evolution step 38: f(x)= 2537.13
# differential_evolution step 39: f(x)= 2530.55
# differential_evolution step 40: f(x)= 2526.57
#      fun: 2476.605142075588
#      jac: array([-3.08652942e+01, -7.15160692e+01,  2.11734504e+02,  2.77844306e+03,
#        -9.42281981e-01,  3.03702564e+01,  7.29414690e-02,  0.00000000e+00,
#         1.63856280e+03,  2.32132152e+01, -1.76245067e+01])
#  message: 'Optimization terminated successfully.'
#     nfev: 9333
#      nit: 40
#  success: True
#        x: array([8.41952663e-01, 9.98708170e-01, 9.97785957e-01, 3.19408709e-04,
#        8.81660357e-01, 1.68735092e-04, 9.91823544e+00, 3.03355623e+01,
#        5.52747831e-04, 3.17881520e-01, 3.53601568e-01])
# 12 0
# differential_evolution step 1: f(x)= 3215.44
# differential_evolution step 2: f(x)= 3215.44
# differential_evolution step 3: f(x)= 3215.44
# differential_evolution step 4: f(x)= 3215.44
# differential_evolution step 5: f(x)= 3215.44
# differential_evolution step 6: f(x)= 3211.84
# differential_evolution step 7: f(x)= 3211.84
# differential_evolution step 8: f(x)= 3174.28
# differential_evolution step 9: f(x)= 3174.28
# differential_evolution step 10: f(x)= 3174.28
# differential_evolution step 11: f(x)= 3174.28
# differential_evolution step 12: f(x)= 3174.28
# differential_evolution step 13: f(x)= 3172.89
# differential_evolution step 14: f(x)= 3141.67
# differential_evolution step 15: f(x)= 3141.67
# differential_evolution step 16: f(x)= 2856.55
# differential_evolution step 17: f(x)= 2856.55
# differential_evolution step 18: f(x)= 2856.55
# differential_evolution step 19: f(x)= 2856.55
# differential_evolution step 20: f(x)= 2856.55
# differential_evolution step 21: f(x)= 2746.48
# differential_evolution step 22: f(x)= 2584.3
# differential_evolution step 23: f(x)= 2278.12
# differential_evolution step 24: f(x)= 2278.12
# differential_evolution step 25: f(x)= 2278.12
# differential_evolution step 26: f(x)= 2278.12
# differential_evolution step 27: f(x)= 2278.12
# differential_evolution step 28: f(x)= 2191.26
# differential_evolution step 29: f(x)= 2191.26
# differential_evolution step 30: f(x)= 2091.93
# differential_evolution step 31: f(x)= 2084.8
# differential_evolution step 32: f(x)= 2084.8
# differential_evolution step 33: f(x)= 2084.8
# differential_evolution step 34: f(x)= 2084.8
# differential_evolution step 35: f(x)= 2084.8
# differential_evolution step 36: f(x)= 2084.8
# differential_evolution step 37: f(x)= 2065.72
# differential_evolution step 38: f(x)= 2065.72
# differential_evolution step 39: f(x)= 2065.72
# differential_evolution step 40: f(x)= 2065.72
# differential_evolution step 41: f(x)= 2055.34
# differential_evolution step 42: f(x)= 2018.71
# differential_evolution step 43: f(x)= 2018.71
# differential_evolution step 44: f(x)= 1971.24
# differential_evolution step 45: f(x)= 1971.24
# differential_evolution step 46: f(x)= 1968.86
# differential_evolution step 47: f(x)= 1968.86
# differential_evolution step 48: f(x)= 1968.86
# differential_evolution step 49: f(x)= 1968.77
# differential_evolution step 50: f(x)= 1968.77
# differential_evolution step 51: f(x)= 1968.77
# differential_evolution step 52: f(x)= 1968.77
# differential_evolution step 53: f(x)= 1968.77
# differential_evolution step 54: f(x)= 1968.77
# differential_evolution step 55: f(x)= 1968.77
# differential_evolution step 56: f(x)= 1968.77
# differential_evolution step 57: f(x)= 1968.77
# differential_evolution step 58: f(x)= 1968.6
# differential_evolution step 59: f(x)= 1968.6
# differential_evolution step 60: f(x)= 1968.6
# differential_evolution step 61: f(x)= 1968.6
# differential_evolution step 62: f(x)= 1968.6
# differential_evolution step 63: f(x)= 1959.12
# differential_evolution step 64: f(x)= 1959.12
# differential_evolution step 65: f(x)= 1959.12
# differential_evolution step 66: f(x)= 1959.12
# differential_evolution step 67: f(x)= 1959.12
# differential_evolution step 68: f(x)= 1955.17
# differential_evolution step 69: f(x)= 1952.15
# differential_evolution step 70: f(x)= 1952.15
# differential_evolution step 71: f(x)= 1952.15
# differential_evolution step 72: f(x)= 1950.3
# differential_evolution step 73: f(x)= 1946.6
#      fun: 1936.4981530184477
#      jac: array([-0.4974936 ,  1.11892859,  0.55777036,  1.36078597, -2.93666743,
#        -0.19631443,  0.02719389,  0.        , 11.72450084,  0.61650098,
#         0.03881269])
#  message: 'Optimization terminated successfully.'
#     nfev: 15342
#      nit: 73
#  success: True
#        x: array([8.78662821e-01, 9.77476140e-01, 9.09454659e-01, 7.50978417e-03,
#        1.00000000e+00, 5.17220420e-01, 4.59008307e-01, 8.19780637e+01,
#        2.78050462e-03, 1.51816402e-01, 2.12038285e+00])
# 13 0
# differential_evolution step 1: f(x)= 2621.59
# differential_evolution step 2: f(x)= 2621.59
# differential_evolution step 3: f(x)= 2587.56
# differential_evolution step 4: f(x)= 2413.39
# differential_evolution step 5: f(x)= 2413.1
# differential_evolution step 6: f(x)= 2360.92
# differential_evolution step 7: f(x)= 2348.83
# differential_evolution step 8: f(x)= 2340.62
# differential_evolution step 9: f(x)= 2340.62
# differential_evolution step 10: f(x)= 2340.62
# differential_evolution step 11: f(x)= 2340.62
# differential_evolution step 12: f(x)= 2340.62
# differential_evolution step 13: f(x)= 2321.67
# differential_evolution step 14: f(x)= 2309.11
# differential_evolution step 15: f(x)= 2309.11
# differential_evolution step 16: f(x)= 2309.11
# differential_evolution step 17: f(x)= 2309.11
# differential_evolution step 18: f(x)= 2305.11
# differential_evolution step 19: f(x)= 2219.36
# differential_evolution step 20: f(x)= 2219.36
#      fun: 2150.1535468808024
#      jac: array([ -0.27362148,  -1.33231878,   2.98537087, -15.29324436,
#          1.00112629,  -5.31103979,   0.02191882,   0.        ,
#          0.42141437,   0.82218321,  -0.02110028])
#  message: 'Optimization terminated successfully.'
#     nfev: 6333
#      nit: 20
#  success: True
#        x: array([9.10980424e-01, 9.98959311e-01, 9.98491216e-01, 6.80348502e-05,
#        2.72528883e-01, 1.05950596e-04, 3.62252864e+01, 2.50750075e+01,
#        8.05956920e-03, 1.67354540e-01, 3.86672386e-01])
# 14 0
# differential_evolution step 1: f(x)= 4650.36
# differential_evolution step 2: f(x)= 3075.19
# differential_evolution step 3: f(x)= 2975.24
# differential_evolution step 4: f(x)= 2975.24
# differential_evolution step 5: f(x)= 2909.3
# differential_evolution step 6: f(x)= 2909.3
# differential_evolution step 7: f(x)= 2909.3
# differential_evolution step 8: f(x)= 2909.3
# differential_evolution step 9: f(x)= 2880.46
# differential_evolution step 10: f(x)= 2879.52
# differential_evolution step 11: f(x)= 2879.52
# differential_evolution step 12: f(x)= 2879.52
# differential_evolution step 13: f(x)= 2879.52
# differential_evolution step 14: f(x)= 2879.52
# differential_evolution step 15: f(x)= 2879.52
# differential_evolution step 16: f(x)= 2875.45
# differential_evolution step 17: f(x)= 2857.97
# differential_evolution step 18: f(x)= 2857.97
# differential_evolution step 19: f(x)= 2857.97
# differential_evolution step 20: f(x)= 2855.02
# differential_evolution step 21: f(x)= 2818.73
# differential_evolution step 22: f(x)= 2818.73
#      fun: 2752.459215174692
#      jac: array([-1.54204826e+00,  6.30006980e+00,  8.53979141e+00,  1.78370101e+01,
#        -8.26275937e-02,  6.31462171e-01,  9.00399680e-03,  0.00000000e+00,
#        -3.00406100e-01,  3.21383595e+00, -1.49689186e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 6603
#      nit: 22
#  success: True
#        x: array([8.90640754e-01, 1.36565330e-01, 9.75165775e-01, 2.96076587e-04,
#        1.93524439e-01, 1.11617491e-03, 2.60631611e+01, 5.42562409e+01,
#        2.88276660e-03, 1.77327632e-01, 4.54724362e-01])
# 15 0
# differential_evolution step 1: f(x)= 3262.91
# differential_evolution step 2: f(x)= 3262.91
# differential_evolution step 3: f(x)= 2426.71
# differential_evolution step 4: f(x)= 2426.71
# differential_evolution step 5: f(x)= 2400.37
# differential_evolution step 6: f(x)= 2320.48
# differential_evolution step 7: f(x)= 2241.76
# differential_evolution step 8: f(x)= 2241.76
# differential_evolution step 9: f(x)= 2236.59
# differential_evolution step 10: f(x)= 2236.59
# differential_evolution step 11: f(x)= 2209.57
# differential_evolution step 12: f(x)= 2199.64
# differential_evolution step 13: f(x)= 2199.64
# differential_evolution step 14: f(x)= 2195.32
# differential_evolution step 15: f(x)= 2163.71
# differential_evolution step 16: f(x)= 2163.71
# differential_evolution step 17: f(x)= 2039.67
# differential_evolution step 18: f(x)= 1987.74
# differential_evolution step 19: f(x)= 1922.05
# differential_evolution step 20: f(x)= 1922.05
# differential_evolution step 21: f(x)= 1922.05
# differential_evolution step 22: f(x)= 1882.28
# differential_evolution step 23: f(x)= 1882.28
# differential_evolution step 24: f(x)= 1882.28
# differential_evolution step 25: f(x)= 1882.28
# differential_evolution step 26: f(x)= 1882.28
# differential_evolution step 27: f(x)= 1816.23
# differential_evolution step 28: f(x)= 1816.23
# differential_evolution step 29: f(x)= 1782.88
# differential_evolution step 30: f(x)= 1777.72
# differential_evolution step 31: f(x)= 1755.56
# differential_evolution step 32: f(x)= 1755.56
# differential_evolution step 33: f(x)= 1744.69
# differential_evolution step 34: f(x)= 1744.69
# differential_evolution step 35: f(x)= 1728.16
# differential_evolution step 36: f(x)= 1728.16
# differential_evolution step 37: f(x)= 1711.85
# differential_evolution step 38: f(x)= 1711.85
# differential_evolution step 39: f(x)= 1711.85
# differential_evolution step 40: f(x)= 1708.38
# differential_evolution step 41: f(x)= 1708.38
# differential_evolution step 42: f(x)= 1701.32
# differential_evolution step 43: f(x)= 1701.32
# differential_evolution step 44: f(x)= 1669.27
# differential_evolution step 45: f(x)= 1669.27
# differential_evolution step 46: f(x)= 1669.27
# differential_evolution step 47: f(x)= 1669.27
# differential_evolution step 48: f(x)= 1669.27
# differential_evolution step 49: f(x)= 1652.29
# differential_evolution step 50: f(x)= 1652.29
# differential_evolution step 51: f(x)= 1652.29
# differential_evolution step 52: f(x)= 1652.29
# differential_evolution step 53: f(x)= 1652.29
# differential_evolution step 54: f(x)= 1652.29
#      fun: 1608.60055518367
#      jac: array([-2.06862295, -0.67482233, -1.76833054, -1.70614385, -0.82961833,
#         2.07276116, -0.05745733, -1.99147506,  9.29001089,  4.03267677,
#         0.17214461])
#  message: 'Optimization terminated successfully.'
#     nfev: 16899
#      nit: 54
#  success: True
#        x: array([7.51315995e-01, 3.22241294e-01, 9.66064867e-01, 2.27545054e-03,
#        1.60128557e-01, 4.46696373e-01, 4.66715970e+00, 6.30314368e-01,
#        2.42142779e-03, 2.77722589e-01, 2.31804808e+00])
# 16 0
# differential_evolution step 1: f(x)= 6074.71
# differential_evolution step 2: f(x)= 3948.98
# differential_evolution step 3: f(x)= 3000.1
# differential_evolution step 4: f(x)= 2779.1
# differential_evolution step 5: f(x)= 2641.03
# differential_evolution step 6: f(x)= 2641.03
# differential_evolution step 7: f(x)= 2641.03
# differential_evolution step 8: f(x)= 2129.75
# differential_evolution step 9: f(x)= 2129.75
# differential_evolution step 10: f(x)= 2125.04
# differential_evolution step 11: f(x)= 2114.72
# differential_evolution step 12: f(x)= 2097.48
# differential_evolution step 13: f(x)= 2071.78
# differential_evolution step 14: f(x)= 2049.19
# differential_evolution step 15: f(x)= 2049.19
# differential_evolution step 16: f(x)= 2049.19
# differential_evolution step 17: f(x)= 2049.19
# differential_evolution step 18: f(x)= 2049.19
# differential_evolution step 19: f(x)= 2048.54
# differential_evolution step 20: f(x)= 2048.54
# differential_evolution step 21: f(x)= 2046.31
# differential_evolution step 22: f(x)= 2046.31
# differential_evolution step 23: f(x)= 2046.31
# differential_evolution step 24: f(x)= 2028.99
# differential_evolution step 25: f(x)= 2028.99
# differential_evolution step 26: f(x)= 2028.99
# differential_evolution step 27: f(x)= 1992.3
# differential_evolution step 28: f(x)= 1992.3
# differential_evolution step 29: f(x)= 1983.94
# differential_evolution step 30: f(x)= 1983.94
# differential_evolution step 31: f(x)= 1977.98
# differential_evolution step 32: f(x)= 1977.98
# differential_evolution step 33: f(x)= 1977.98
# differential_evolution step 34: f(x)= 1977.98
# differential_evolution step 35: f(x)= 1977.98
# differential_evolution step 36: f(x)= 1977.98
# differential_evolution step 37: f(x)= 1977.98
# differential_evolution step 38: f(x)= 1977.98
# differential_evolution step 39: f(x)= 1977.98
# differential_evolution step 40: f(x)= 1977.98
# differential_evolution step 41: f(x)= 1977.98
# differential_evolution step 42: f(x)= 1971.51
# differential_evolution step 43: f(x)= 1958.23
# differential_evolution step 44: f(x)= 1958.23
# differential_evolution step 45: f(x)= 1958.23
# differential_evolution step 46: f(x)= 1958.23
# differential_evolution step 47: f(x)= 1956.74
# differential_evolution step 48: f(x)= 1956.74
# differential_evolution step 49: f(x)= 1956.74
# differential_evolution step 50: f(x)= 1956.74
# differential_evolution step 51: f(x)= 1953.44
# differential_evolution step 52: f(x)= 1953.44
# differential_evolution step 53: f(x)= 1953.44
# differential_evolution step 54: f(x)= 1953.44
#      fun: 1936.8492465192728
#      jac: array([ 0.14031229,  0.24426754, -0.74203399,  0.88730303, -0.51843471,
#        -0.44326498,  0.05059064, -0.02753495,  0.69642283, -0.22203039,
#         0.57445959])
#  message: 'Optimization terminated successfully.'
#     nfev: 12435
#      nit: 54
#  success: True
#        x: array([7.33808335e-01, 8.33328374e-01, 9.73694728e-01, 2.22378416e-03,
#        8.44030742e-01, 5.17674418e-02, 2.51147734e+01, 5.86526198e-01,
#        4.32345499e-03, 2.48368992e-01, 6.21109413e-01])
# 17 0
# differential_evolution step 1: f(x)= 2383.59
# differential_evolution step 2: f(x)= 2383.59
# differential_evolution step 3: f(x)= 2383.59
# differential_evolution step 4: f(x)= 2383.59
# differential_evolution step 5: f(x)= 2252.45
# differential_evolution step 6: f(x)= 2252.45
# differential_evolution step 7: f(x)= 2252.45
# differential_evolution step 8: f(x)= 2252.45
# differential_evolution step 9: f(x)= 2252.45
# differential_evolution step 10: f(x)= 2243.46
# differential_evolution step 11: f(x)= 2243.46
# differential_evolution step 12: f(x)= 2243.46
# differential_evolution step 13: f(x)= 2243.46
# differential_evolution step 14: f(x)= 2243.46
# differential_evolution step 15: f(x)= 2243.46
# differential_evolution step 16: f(x)= 2231.72
# differential_evolution step 17: f(x)= 2231.72
# differential_evolution step 18: f(x)= 2231.72
# differential_evolution step 19: f(x)= 2231.72
# differential_evolution step 20: f(x)= 2155.09
# differential_evolution step 21: f(x)= 2155.09
# differential_evolution step 22: f(x)= 2081.54
# differential_evolution step 23: f(x)= 2081.54
# differential_evolution step 24: f(x)= 2070.63
# differential_evolution step 25: f(x)= 2070.63
# differential_evolution step 26: f(x)= 2070.63
# differential_evolution step 27: f(x)= 2012.49
# differential_evolution step 28: f(x)= 1982.3
# differential_evolution step 29: f(x)= 1941.66
# differential_evolution step 30: f(x)= 1871.85
# differential_evolution step 31: f(x)= 1871.85
# differential_evolution step 32: f(x)= 1871.85
# differential_evolution step 33: f(x)= 1867.7
# differential_evolution step 34: f(x)= 1867.7
# differential_evolution step 35: f(x)= 1867.7
# differential_evolution step 36: f(x)= 1862.19
# differential_evolution step 37: f(x)= 1834.88
# differential_evolution step 38: f(x)= 1834.88
# differential_evolution step 39: f(x)= 1779.97
# differential_evolution step 40: f(x)= 1779.97
# differential_evolution step 41: f(x)= 1776.05
# differential_evolution step 42: f(x)= 1776.05
# differential_evolution step 43: f(x)= 1771.59
# differential_evolution step 44: f(x)= 1771.59
# differential_evolution step 45: f(x)= 1769.37
# differential_evolution step 46: f(x)= 1760.88
# differential_evolution step 47: f(x)= 1758.51
# differential_evolution step 48: f(x)= 1758.51
# differential_evolution step 49: f(x)= 1758.51
# differential_evolution step 50: f(x)= 1758.51
# differential_evolution step 51: f(x)= 1758.51
# differential_evolution step 52: f(x)= 1741.89
# differential_evolution step 53: f(x)= 1741.89
# differential_evolution step 54: f(x)= 1740.84
# differential_evolution step 55: f(x)= 1740.84
# differential_evolution step 56: f(x)= 1739.66
# differential_evolution step 57: f(x)= 1739.66
# differential_evolution step 58: f(x)= 1739.66
# differential_evolution step 59: f(x)= 1736.8
# differential_evolution step 60: f(x)= 1736.8
# differential_evolution step 61: f(x)= 1736.8
#      fun: 1717.3064873316825
#      jac: array([ 3.09628375e+00,  6.28278940e-01,  8.69472383e+00, -2.16543822e+02,
#         4.17119282e+00, -3.51942617e+00,  3.72574474e-01, -1.43722900e+00,
#        -8.23245045e+00, -3.40605766e-02,  2.04468050e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 13542
#      nit: 61
#  success: True
#        x: array([9.12721934e-01, 4.79938471e-01, 9.92827322e-01, 1.83192603e-04,
#        1.44026413e-01, 2.92370430e-02, 1.39297465e+01, 6.15936366e-01,
#        4.72138788e-03, 2.22370630e-01, 8.15803959e-01])
# 18 0
# differential_evolution step 1: f(x)= 2544.13
# differential_evolution step 2: f(x)= 2544.13
# differential_evolution step 3: f(x)= 2385.84
# differential_evolution step 4: f(x)= 2385.84
# differential_evolution step 5: f(x)= 2385.84
# differential_evolution step 6: f(x)= 2377.2
# differential_evolution step 7: f(x)= 2377.2
# differential_evolution step 8: f(x)= 2314.68
# differential_evolution step 9: f(x)= 2221.6
# differential_evolution step 10: f(x)= 2221.6
# differential_evolution step 11: f(x)= 2221.6
# differential_evolution step 12: f(x)= 2221.6
# differential_evolution step 13: f(x)= 2221.6
# differential_evolution step 14: f(x)= 2221.6
# differential_evolution step 15: f(x)= 2221.6
# differential_evolution step 16: f(x)= 2221.6
# differential_evolution step 17: f(x)= 2220.38
# differential_evolution step 18: f(x)= 2220.38
# differential_evolution step 19: f(x)= 2220.38
# differential_evolution step 20: f(x)= 2142.91
# differential_evolution step 21: f(x)= 2142.91
# differential_evolution step 22: f(x)= 2142.91
# differential_evolution step 23: f(x)= 2142.91
# differential_evolution step 24: f(x)= 2142.91
# differential_evolution step 25: f(x)= 2142.91
# differential_evolution step 26: f(x)= 2142.91
# differential_evolution step 27: f(x)= 2142.91
# differential_evolution step 28: f(x)= 2142.91
# differential_evolution step 29: f(x)= 2142.91
# differential_evolution step 30: f(x)= 2142.91
# differential_evolution step 31: f(x)= 2142.91
# differential_evolution step 32: f(x)= 2142.91
# differential_evolution step 33: f(x)= 2142.91
# differential_evolution step 34: f(x)= 2142.91
# differential_evolution step 35: f(x)= 2142.91
# differential_evolution step 36: f(x)= 2142.91
# differential_evolution step 37: f(x)= 2142.91
# differential_evolution step 38: f(x)= 2133.04
# differential_evolution step 39: f(x)= 2109.89
# differential_evolution step 40: f(x)= 2109.89
# differential_evolution step 41: f(x)= 2109.89
# differential_evolution step 42: f(x)= 2109.89
# differential_evolution step 43: f(x)= 2109.89
# differential_evolution step 44: f(x)= 2078.7
# differential_evolution step 45: f(x)= 2078.7
# differential_evolution step 46: f(x)= 2078.7
# differential_evolution step 47: f(x)= 2078.7
# differential_evolution step 48: f(x)= 2078.7
# differential_evolution step 49: f(x)= 2078.7
# differential_evolution step 50: f(x)= 2078.7
# differential_evolution step 51: f(x)= 2078.7
# differential_evolution step 52: f(x)= 2078.7
# differential_evolution step 53: f(x)= 2078.7
# differential_evolution step 54: f(x)= 2078.7
# differential_evolution step 55: f(x)= 2078.7
# differential_evolution step 56: f(x)= 2078.7
# differential_evolution step 57: f(x)= 2078.7
# differential_evolution step 58: f(x)= 2078.7
# differential_evolution step 59: f(x)= 2078.7
# differential_evolution step 60: f(x)= 2078.7
# differential_evolution step 61: f(x)= 2078.7
# differential_evolution step 62: f(x)= 2078.7
# differential_evolution step 63: f(x)= 2078.7
# differential_evolution step 64: f(x)= 2078.7
# differential_evolution step 65: f(x)= 2078.7
# differential_evolution step 66: f(x)= 2078.7
# differential_evolution step 67: f(x)= 2078.7
# differential_evolution step 68: f(x)= 2078.7
# differential_evolution step 69: f(x)= 2073.48
# differential_evolution step 70: f(x)= 2073.48
# differential_evolution step 71: f(x)= 2073.48
# differential_evolution step 72: f(x)= 2073.48
# differential_evolution step 73: f(x)= 2067.03
# differential_evolution step 74: f(x)= 2062.36
# differential_evolution step 75: f(x)= 2062.36
# differential_evolution step 76: f(x)= 2062.36
# differential_evolution step 77: f(x)= 2062.36
# differential_evolution step 78: f(x)= 2062.36
# differential_evolution step 79: f(x)= 2062.36
# differential_evolution step 80: f(x)= 2062.36
# differential_evolution step 81: f(x)= 2062.36
# differential_evolution step 82: f(x)= 2062.36
# differential_evolution step 83: f(x)= 2062.36
# differential_evolution step 84: f(x)= 2060.32
# differential_evolution step 85: f(x)= 2060.32
# differential_evolution step 86: f(x)= 2060.32
# differential_evolution step 87: f(x)= 2060.32
# differential_evolution step 88: f(x)= 2060.32
# differential_evolution step 89: f(x)= 2056.98
# differential_evolution step 90: f(x)= 2055.15
# differential_evolution step 91: f(x)= 2055.15
# differential_evolution step 92: f(x)= 2055.15
# differential_evolution step 93: f(x)= 2051.9
# differential_evolution step 94: f(x)= 2051.9
# differential_evolution step 95: f(x)= 2051.9
# differential_evolution step 96: f(x)= 2051.9
# differential_evolution step 97: f(x)= 2051.9
# differential_evolution step 98: f(x)= 2051.9
# differential_evolution step 99: f(x)= 2046.47
# differential_evolution step 100: f(x)= 2046.47
# differential_evolution step 101: f(x)= 2046.47
# differential_evolution step 102: f(x)= 2044.55
# differential_evolution step 103: f(x)= 2044.55
# differential_evolution step 104: f(x)= 2044.55
# differential_evolution step 105: f(x)= 2038.35
# differential_evolution step 106: f(x)= 2038.35
# differential_evolution step 107: f(x)= 2037.7
# differential_evolution step 108: f(x)= 2035.32
# differential_evolution step 109: f(x)= 2035.32
# differential_evolution step 110: f(x)= 2031.66
# differential_evolution step 111: f(x)= 2031.66
# differential_evolution step 112: f(x)= 2031.66
# differential_evolution step 113: f(x)= 2031.66
# differential_evolution step 114: f(x)= 2026.71
#      fun: 1701.0777225975955
#      jac: array([-0.15131718,  0.20943389, -0.46820787,  0.37418886, -0.77850472,
#         0.0368118 ,  0.19797426, -0.33655851,  2.44588136, -0.35524863,
#        -0.00318323])
#  message: 'Optimization terminated successfully.'
#     nfev: 24807
#      nit: 114
#  success: True
#        x: array([6.88255106e-01, 9.02584448e-01, 9.03336908e-01, 2.20679041e-02,
#        6.94014940e-01, 5.90375955e-01, 1.09141831e+00, 3.46653362e-01,
#        1.63107955e-03, 2.85487408e-01, 4.57424593e+00])
# 19 0
# differential_evolution step 1: f(x)= 2399.79
# differential_evolution step 2: f(x)= 2399.79
# differential_evolution step 3: f(x)= 2399.79
# differential_evolution step 4: f(x)= 2399.79
# differential_evolution step 5: f(x)= 2399.79
# differential_evolution step 6: f(x)= 2399.79
# differential_evolution step 7: f(x)= 2399.79
# differential_evolution step 8: f(x)= 2349.3
# differential_evolution step 9: f(x)= 2349.3
# differential_evolution step 10: f(x)= 2349.3
# differential_evolution step 11: f(x)= 2349.3
# differential_evolution step 12: f(x)= 2318.63
# differential_evolution step 13: f(x)= 2318.63
# differential_evolution step 14: f(x)= 2318.63
# differential_evolution step 15: f(x)= 2292.03
# differential_evolution step 16: f(x)= 2292.03
# differential_evolution step 17: f(x)= 2292.03
# differential_evolution step 18: f(x)= 2287.41
# differential_evolution step 19: f(x)= 2269.81
# differential_evolution step 20: f(x)= 2269.81
# differential_evolution step 21: f(x)= 2249.64
# differential_evolution step 22: f(x)= 2185.14
# differential_evolution step 23: f(x)= 2055.85
# differential_evolution step 24: f(x)= 2055.85
# differential_evolution step 25: f(x)= 2055.85
# differential_evolution step 26: f(x)= 2055.85
# differential_evolution step 27: f(x)= 2055.85
# differential_evolution step 28: f(x)= 2055.85
# differential_evolution step 29: f(x)= 2055.85
# differential_evolution step 30: f(x)= 2044.87
# differential_evolution step 31: f(x)= 2044.87
# differential_evolution step 32: f(x)= 2044.87
# differential_evolution step 33: f(x)= 1983.01
# differential_evolution step 34: f(x)= 1983.01
# differential_evolution step 35: f(x)= 1983.01
# differential_evolution step 36: f(x)= 1983.01
# differential_evolution step 37: f(x)= 1967.74
# differential_evolution step 38: f(x)= 1967.74
# differential_evolution step 39: f(x)= 1967.74
# differential_evolution step 40: f(x)= 1967.74
# differential_evolution step 41: f(x)= 1900.67
# differential_evolution step 42: f(x)= 1900.67
# differential_evolution step 43: f(x)= 1900.67
# differential_evolution step 44: f(x)= 1900.67
# differential_evolution step 45: f(x)= 1885.09
# differential_evolution step 46: f(x)= 1885.09
# differential_evolution step 47: f(x)= 1885.09
# differential_evolution step 48: f(x)= 1885.09
# differential_evolution step 49: f(x)= 1885.09
# differential_evolution step 50: f(x)= 1885.09
# differential_evolution step 51: f(x)= 1885.09
# differential_evolution step 52: f(x)= 1885.09
# differential_evolution step 53: f(x)= 1885.09
# differential_evolution step 54: f(x)= 1885.09
# ...
#        -8.30345925e-01, -1.52135726e-01,  5.07498044e-02])
#  message: 'Optimization terminated successfully.'
#     nfev: 6813
#      nit: 24
#  success: True
#        x: array([9.87041071e-01, 2.22044605e-16, 9.94944790e-01, 1.10157595e-04,
#        1.00000000e+00, 9.56162706e-01, 5.15027573e+01, 4.21990234e+01,
#        2.05343670e-02, 2.90176608e-01, 2.35757755e-01])
# 31 0
# differential_evolution step 1: f(x)= 2037.23
# differential_evolution step 2: f(x)= 2037.23
# differential_evolution step 3: f(x)= 1542.99
# differential_evolution step 4: f(x)= 1542.99
# differential_evolution step 5: f(x)= 1531.85
# differential_evolution step 6: f(x)= 1531.85
# differential_evolution step 7: f(x)= 1503.58
# differential_evolution step 8: f(x)= 1503.58
# differential_evolution step 9: f(x)= 1503.58
# differential_evolution step 10: f(x)= 1503.58
# differential_evolution step 11: f(x)= 1503.58
# differential_evolution step 12: f(x)= 1503.58
# differential_evolution step 13: f(x)= 1503.58
# differential_evolution step 14: f(x)= 1503.43
# differential_evolution step 15: f(x)= 1494.89
# differential_evolution step 16: f(x)= 1494.89
# differential_evolution step 17: f(x)= 1494.89
# differential_evolution step 18: f(x)= 1494.89
# differential_evolution step 19: f(x)= 1494.89
# differential_evolution step 20: f(x)= 1494.89
# differential_evolution step 21: f(x)= 1489.84
# differential_evolution step 22: f(x)= 1489.55
# differential_evolution step 23: f(x)= 1489.55
# differential_evolution step 24: f(x)= 1489.26
# differential_evolution step 25: f(x)= 1484.49
# differential_evolution step 26: f(x)= 1474.66
# differential_evolution step 27: f(x)= 1474.66
# differential_evolution step 28: f(x)= 1474.04
#      fun: 1372.9794703327132
#      jac: array([ 0.11698376, -0.01657554, -0.36789061,  4.22373887,  0.08337793,
#        -0.08064944,  0.0152113 ,  0.        , -0.73277988, -0.41034127,
#        -0.06868959])
#  message: 'Optimization terminated successfully.'
#     nfev: 7629
#      nit: 28
#  success: True
#        x: array([8.57446404e-01, 2.81464426e-02, 9.51608178e-01, 6.04038120e-03,
#        7.73963485e-01, 7.37771411e-01, 1.14135865e+00, 5.68734934e+01,
#        3.71532648e-02, 1.41573057e-01, 1.07701948e+00])
# 32 0
# differential_evolution step 1: f(x)= 2564.45
# differential_evolution step 2: f(x)= 2564.45
# differential_evolution step 3: f(x)= 2564.45
# differential_evolution step 4: f(x)= 2534.61
# differential_evolution step 5: f(x)= 2534.61
# differential_evolution step 6: f(x)= 2486.82
# differential_evolution step 7: f(x)= 2486.82
# differential_evolution step 8: f(x)= 2486.82
# differential_evolution step 9: f(x)= 2486.82
# differential_evolution step 10: f(x)= 2486.82
# differential_evolution step 11: f(x)= 2486.82
# differential_evolution step 12: f(x)= 2486.82
# differential_evolution step 13: f(x)= 2486.82
# differential_evolution step 14: f(x)= 2475.99
# differential_evolution step 15: f(x)= 2475.99
# differential_evolution step 16: f(x)= 2475.99
# differential_evolution step 17: f(x)= 2437.83
# differential_evolution step 18: f(x)= 2329.38
# differential_evolution step 19: f(x)= 2329.38
# differential_evolution step 20: f(x)= 2329.38
# differential_evolution step 21: f(x)= 2268.29
# differential_evolution step 22: f(x)= 2268.29
# differential_evolution step 23: f(x)= 2268.29
# differential_evolution step 24: f(x)= 2268.29
# differential_evolution step 25: f(x)= 2268.29
# differential_evolution step 26: f(x)= 2268.29
# differential_evolution step 27: f(x)= 2268.29
# differential_evolution step 28: f(x)= 2220.26
# differential_evolution step 29: f(x)= 2220.26
# differential_evolution step 30: f(x)= 2220.26
# differential_evolution step 31: f(x)= 2219.15
# differential_evolution step 32: f(x)= 2176.68
# differential_evolution step 33: f(x)= 2176.68
# differential_evolution step 34: f(x)= 2136.81
# differential_evolution step 35: f(x)= 2136.81
# differential_evolution step 36: f(x)= 2136.81
# differential_evolution step 37: f(x)= 2116.97
# differential_evolution step 38: f(x)= 2116.97
# differential_evolution step 39: f(x)= 2113.81
# differential_evolution step 40: f(x)= 2113.81
# differential_evolution step 41: f(x)= 2113.81
# differential_evolution step 42: f(x)= 2105.84
# differential_evolution step 43: f(x)= 2105.84
# differential_evolution step 44: f(x)= 2105.84
# differential_evolution step 45: f(x)= 2075.76
# differential_evolution step 46: f(x)= 2075.76
# differential_evolution step 47: f(x)= 2075.76
# differential_evolution step 48: f(x)= 2069.2
# differential_evolution step 49: f(x)= 2069.2
# differential_evolution step 50: f(x)= 2069.2
# differential_evolution step 51: f(x)= 2069.2
# differential_evolution step 52: f(x)= 2069.2
# differential_evolution step 53: f(x)= 2069.2
# differential_evolution step 54: f(x)= 2060.73
# differential_evolution step 55: f(x)= 2060.73
# differential_evolution step 56: f(x)= 2060.73
# differential_evolution step 57: f(x)= 2051.95
# differential_evolution step 58: f(x)= 2051.95
# differential_evolution step 59: f(x)= 2051.95
# differential_evolution step 60: f(x)= 2051.95
# differential_evolution step 61: f(x)= 2051.95
# differential_evolution step 62: f(x)= 2051.95
# differential_evolution step 63: f(x)= 2049.56
# differential_evolution step 64: f(x)= 2049.56
# differential_evolution step 65: f(x)= 2049.56
# differential_evolution step 66: f(x)= 2047.53
# differential_evolution step 67: f(x)= 2045.47
# differential_evolution step 68: f(x)= 2045.47
#      fun: 2039.5115975433246
#      jac: array([-0.27644091,  0.30590854, -0.28362592, -0.22193944, -0.60267666,
#         0.42284682,  0.0383352 ,  0.        , -1.22190613,  0.4785079 ,
#        -0.02582965])
#  message: 'Optimization terminated successfully.'
#     nfev: 15153
#      nit: 68
#  success: True
#        x: array([8.67508040e-01, 1.65068722e-01, 9.36856682e-01, 7.58675559e-03,
#        1.00000000e+00, 5.21359485e-01, 2.95372746e+00, 5.54582754e+01,
#        5.46803038e-03, 1.75647200e-01, 1.51374455e+00])
# 33 0
# differential_evolution step 1: f(x)= 1773.99
# differential_evolution step 2: f(x)= 1773.92
# differential_evolution step 3: f(x)= 1773.92
# differential_evolution step 4: f(x)= 1773.92
# differential_evolution step 5: f(x)= 1737.36
# differential_evolution step 6: f(x)= 1731.63
# differential_evolution step 7: f(x)= 1730.34
# differential_evolution step 8: f(x)= 1702.39
# differential_evolution step 9: f(x)= 1702.39
# differential_evolution step 10: f(x)= 1683.58
# differential_evolution step 11: f(x)= 1683.58
# differential_evolution step 12: f(x)= 1683.58
# differential_evolution step 13: f(x)= 1683.58
# differential_evolution step 14: f(x)= 1683.58
# differential_evolution step 15: f(x)= 1683.58
# differential_evolution step 16: f(x)= 1683.58
# differential_evolution step 17: f(x)= 1683.58
# differential_evolution step 18: f(x)= 1683.58
#      fun: 1644.4015782182003
#      jac: array([-1.36265044e-01, -5.15387908e-01, -2.51965506e+03, -2.81715982e-02,
#         1.94609129e-01, -5.11818141e-01,  2.13026379e-01, -3.27872840e-02,
#         2.44403964e-01,  5.30917532e-02, -8.95170156e-02])
#  message: 'Optimization terminated successfully.'
#     nfev: 3879
#      nit: 18
#  success: True
#        x: array([1.31679976e-01, 8.53824545e-01, 1.00000000e+00, 5.98321214e-01,
#        1.03060941e-01, 9.99869292e-01, 2.81914890e+01, 4.03570590e-01,
#        1.72458080e-02, 1.85901224e-01, 6.95200716e-01])
# 34 0
# differential_evolution step 1: f(x)= 2897.02
# differential_evolution step 2: f(x)= 2574.21
# differential_evolution step 3: f(x)= 2465.47
# differential_evolution step 4: f(x)= 2465.47
# differential_evolution step 5: f(x)= 2465.47
# differential_evolution step 6: f(x)= 2429.87
# differential_evolution step 7: f(x)= 2429.87
# differential_evolution step 8: f(x)= 2400.05
# differential_evolution step 9: f(x)= 2324.25
# differential_evolution step 10: f(x)= 2324.25
# differential_evolution step 11: f(x)= 2324.25
# differential_evolution step 12: f(x)= 2324.25
# differential_evolution step 13: f(x)= 2324.25
# differential_evolution step 14: f(x)= 2284.35
# differential_evolution step 15: f(x)= 2284.35
# differential_evolution step 16: f(x)= 2280.96
# differential_evolution step 17: f(x)= 2148.78
# differential_evolution step 18: f(x)= 2148.78
# differential_evolution step 19: f(x)= 2139.45
# differential_evolution step 20: f(x)= 1987.34
# differential_evolution step 21: f(x)= 1987.34
# differential_evolution step 22: f(x)= 1964.7
# differential_evolution step 23: f(x)= 1791.95
# differential_evolution step 24: f(x)= 1791.95
# differential_evolution step 25: f(x)= 1791.95
# differential_evolution step 26: f(x)= 1791.95
# differential_evolution step 27: f(x)= 1791.95
# differential_evolution step 28: f(x)= 1791.95
# differential_evolution step 29: f(x)= 1779.65
# differential_evolution step 30: f(x)= 1779.65
# differential_evolution step 31: f(x)= 1779.65
# differential_evolution step 32: f(x)= 1779.65
# differential_evolution step 33: f(x)= 1779.65
# differential_evolution step 34: f(x)= 1779.65
# differential_evolution step 35: f(x)= 1779.65
# differential_evolution step 36: f(x)= 1779.65
# differential_evolution step 37: f(x)= 1779.65
# differential_evolution step 38: f(x)= 1779.65
# differential_evolution step 39: f(x)= 1779.65
# differential_evolution step 40: f(x)= 1779.65
# differential_evolution step 41: f(x)= 1779.65
# differential_evolution step 42: f(x)= 1779.65
# differential_evolution step 43: f(x)= 1779.65
# differential_evolution step 44: f(x)= 1779.65
# differential_evolution step 45: f(x)= 1771.75
# differential_evolution step 46: f(x)= 1771.75
# differential_evolution step 47: f(x)= 1771.75
# differential_evolution step 48: f(x)= 1771.75
# differential_evolution step 49: f(x)= 1771.75
# differential_evolution step 50: f(x)= 1766.2
# differential_evolution step 51: f(x)= 1766.2
# differential_evolution step 52: f(x)= 1762
# differential_evolution step 53: f(x)= 1762
# differential_evolution step 54: f(x)= 1761.25
# differential_evolution step 55: f(x)= 1759.59
# differential_evolution step 56: f(x)= 1759.51
#      fun: 1751.420593318261
#      jac: array([-2.40834196e-01,  1.34377842e-02,  1.28625288e-01,  3.42515705e-01,
#        -2.74962984e-01, -5.45696818e-03, -1.59161574e-04,  0.00000000e+00,
#         8.71386874e-01, -2.00998329e-02, -3.49473341e-02])
#  message: 'Optimization terminated successfully.'
#     nfev: 11961
#      nit: 56
#  success: True
#        x: array([8.45952827e-01, 9.20487202e-01, 9.56963628e-01, 3.40266286e-03,
#        8.00343229e-01, 5.05196963e-01, 1.24635774e+00, 2.99957060e+01,
#        7.03722724e-03, 1.61597608e-01, 1.47809479e+00])
# 35 0
# differential_evolution step 1: f(x)= 2697.95
# differential_evolution step 2: f(x)= 2402.34
# differential_evolution step 3: f(x)= 2330.51
# differential_evolution step 4: f(x)= 2330.51
# differential_evolution step 5: f(x)= 2330.51
# differential_evolution step 6: f(x)= 2310.67
# differential_evolution step 7: f(x)= 2308.81
# differential_evolution step 8: f(x)= 2299.32
# differential_evolution step 9: f(x)= 2299.32
# differential_evolution step 10: f(x)= 2299.32
# differential_evolution step 11: f(x)= 2299.32
# differential_evolution step 12: f(x)= 2292.14
# differential_evolution step 13: f(x)= 2292.14
# differential_evolution step 14: f(x)= 2292.14
# differential_evolution step 15: f(x)= 2288.61
# differential_evolution step 16: f(x)= 2288.61
# differential_evolution step 17: f(x)= 2288.61
# differential_evolution step 18: f(x)= 2288.21
# differential_evolution step 19: f(x)= 2283.05
# differential_evolution step 20: f(x)= 2283.05
# differential_evolution step 21: f(x)= 2283.05
# differential_evolution step 22: f(x)= 2283.05
# differential_evolution step 23: f(x)= 2283.05
#      fun: 1928.1180479489267
#      jac: array([-5.76060299e+00,  8.32646943e+00, -2.21264280e+02, -7.42035036e+02,
#        -1.92903825e+00, -2.82825566e+00,  4.85442757e-02,  0.00000000e+00,
#        -4.62473963e+01, -4.19590833e+00,  1.58684088e+00])
#  message: 'Optimization terminated successfully.'
#     nfev: 7584
#      nit: 23
#  success: True
#        x: array([9.91064901e-01, 9.18999610e-01, 9.99968150e-01, 9.22583240e-07,
#        1.00000000e+00, 8.12422270e-01, 5.31886108e+01, 5.31509800e+01,
#        6.60894171e-03, 1.90145546e-01, 3.05093658e-01])
# 36 0
# differential_evolution step 1: f(x)= 4216.01
# differential_evolution step 2: f(x)= 1726.21
# differential_evolution step 3: f(x)= 1726.21
# differential_evolution step 4: f(x)= 1726.21
# differential_evolution step 5: f(x)= 1726.21
# differential_evolution step 6: f(x)= 1726.21
# differential_evolution step 7: f(x)= 1711.55
# differential_evolution step 8: f(x)= 1705.84
# differential_evolution step 9: f(x)= 1705.84
# differential_evolution step 10: f(x)= 1705.84
# differential_evolution step 11: f(x)= 1705.39
# differential_evolution step 12: f(x)= 1692.89
# differential_evolution step 13: f(x)= 1660.4
# differential_evolution step 14: f(x)= 1649.78
# differential_evolution step 15: f(x)= 1649.78
# differential_evolution step 16: f(x)= 1649.78
# differential_evolution step 17: f(x)= 1649.78
# differential_evolution step 18: f(x)= 1649.78
#      fun: 1596.5728786618013
#      jac: array([-2.94978689e+00,  1.03269894e+02,  3.23946095e+00,  1.02864851e+02,
#         1.50453160e-01, -8.92077874e-01,  1.31649347e-02,  0.00000000e+00,
#         5.50214736e+00,  3.85853127e+00, -3.01520231e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 5679
#      nit: 18
#  success: True
#        x: array([9.49158306e-01, 9.99997662e-01, 9.97620800e-01, 9.05718080e-06,
#        5.67350134e-01, 5.47704744e-01, 5.89909043e+01, 3.94987416e+01,
#        2.58399843e-02, 1.38434589e-01, 2.44237151e-01])
# 37 0
# differential_evolution step 1: f(x)= 1008.02
# differential_evolution step 2: f(x)= 1008.02
# differential_evolution step 3: f(x)= 1008.02
# differential_evolution step 4: f(x)= 979.015
# differential_evolution step 5: f(x)= 979.015
# differential_evolution step 6: f(x)= 978.199
# differential_evolution step 7: f(x)= 972.177
# differential_evolution step 8: f(x)= 972.177
# differential_evolution step 9: f(x)= 964.435
# differential_evolution step 10: f(x)= 964.435
# differential_evolution step 11: f(x)= 956.649
# differential_evolution step 12: f(x)= 926.901
# differential_evolution step 13: f(x)= 926.901
# differential_evolution step 14: f(x)= 926.901
# differential_evolution step 15: f(x)= 898.108
# differential_evolution step 16: f(x)= 898.108
# differential_evolution step 17: f(x)= 898.108
# differential_evolution step 18: f(x)= 898.108
# differential_evolution step 19: f(x)= 898.108
# differential_evolution step 20: f(x)= 898.108
# differential_evolution step 21: f(x)= 897.317
# differential_evolution step 22: f(x)= 897.317
# differential_evolution step 23: f(x)= 897.317
# differential_evolution step 24: f(x)= 897.317
# differential_evolution step 25: f(x)= 897.317
# differential_evolution step 26: f(x)= 897.317
# differential_evolution step 27: f(x)= 891.347
# differential_evolution step 28: f(x)= 871.794
# differential_evolution step 29: f(x)= 871.794
# differential_evolution step 30: f(x)= 871.794
# differential_evolution step 31: f(x)= 871.794
# differential_evolution step 32: f(x)= 868.195
# differential_evolution step 33: f(x)= 868.195
# differential_evolution step 34: f(x)= 868.195
# differential_evolution step 35: f(x)= 865.356
# differential_evolution step 36: f(x)= 865.356
# differential_evolution step 37: f(x)= 864.611
# differential_evolution step 38: f(x)= 861.877
# differential_evolution step 39: f(x)= 861.877
# differential_evolution step 40: f(x)= 861.251
# differential_evolution step 41: f(x)= 858.505
# differential_evolution step 42: f(x)= 857.726
# differential_evolution step 43: f(x)= 857.516
# differential_evolution step 44: f(x)= 857.516
# differential_evolution step 45: f(x)= 857.516
# differential_evolution step 46: f(x)= 857.516
# differential_evolution step 47: f(x)= 857.516
#      fun: 853.265896416244
#      jac: array([ 1.80682490e-01, -1.28989086e-01, -9.66929287e-01, -1.29728051e-01,
#         7.22411638e-01,  9.39269280e-01, -3.75166533e-04,  0.00000000e+00,
#         3.24007487e-02,  2.07398898e-01, -2.06387086e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 8964
#      nit: 47
#  success: True
#        x: array([8.38944192e-01, 2.58146890e-01, 9.99990017e-01, 1.02998769e-02,
#        9.40153947e-01, 5.23544916e-01, 1.02580243e+01, 6.89585285e+01,
#        4.34046281e-02, 2.66701247e-01, 1.30563758e+00])
