# %% [markdown]
# ## Analyzing Patterns in Fitted Prediction Errors
# > We can look at item level details of prediction errors and compare against phenomenon-based fits to brainstorm further analyses to add to the pile for systematic consideration. Measure where prediction error changes as function of fitting technique instead of just tracking individual changes. Event-level visualizations such as the raster plot help us scouting.

# %%
from compmemlearn.datasets import prepare_murdock1970_data
import seaborn as sns

trials, events, list_length = prepare_murdock1970_data('../../data/mo1970.txt')
events.head()
# Out:
#    subject  list  item  input  output  study  recall  repeat  intrusion
# 0        1     1     1      1     NaN   True   False       0      False
# 1        1     1     2      2     NaN   True   False       0      False
# 2        1     1     3      3     NaN   True   False       0      False
# 3        1     1     4      4     NaN   True   False       0      False
# 4        1     1     5      5     NaN   True   False       0      False

# %%
fig, axes = plt.subplots(figsize=(10, 7.5), sharey=False)
point_size = 400

sns.scatterplot(
    ax=axes,
    data=events, x='list', y='output', hue='input', 
    palette='viridis', legend=False, marker='s', s=point_size)

sns.scatterplot(
    ax=axes,
    data=events, x='list', y='output', hue='input',
    legend=False, marker='o', s=point_size/8)


plt.ylim([0, 15])
plt.show()
