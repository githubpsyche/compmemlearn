# %%
#default_exp familiarity

# %% [markdown]
# # The Differential Encoding Mechanism
# We intend for the differential encoding mechanism we're integrating into CMR to directly differentiate the strength of memory for spaced repetitions of items relative to that of massed repetitions of items.
#
# But how exactly does the mechanism work? Here, we'll specify the mechanism and perform some demonstrations exploring:
#
# 1. How the mechanism modulates learning as familiarity and parameter values vary
# 2. How the mechanism shapes model representations under different conditions
# 3. How these modified model representations then shape simulated behavior

# %% [markdown]
# ## The Mechanism

# %% [markdown]
# Lohnas & Kahana (2015) demonstrate that CMR realizes alternative accounts of the spacing effect -- the contextual variability and study-phase retrieval accounts. But the big idea of the deficient encoding hypothesis as an account of the spacing effect is that:
# 1. Item familiarity ("close acquaintance") impairs attention and memory of subsequent encoding.
# 2. Repeated experience of an item increases familiarity with that item
# 3. On the other hand, familiarity decreases with intervening experience, allowing better memory of repetitions

# %% [markdown]
# We're still exploring exactly how to implement this mechanism. However, at the moment we realize this mechanism through episode-by-episode modulation of $M^{CF}$ learning rate, much like how the primacy effect is enforced in the Morton & Polyn (2016) specification of CMR.
#
# $$
# \Delta M^{CF}_{exp} = \zeta_i \phi_i f_i c^{'}_i
# $$
#
# where
#
# $$
# \zeta_i = \zeta_s [1 - S(f_i, c_i)]
# $$
#
# With $S$ as the cosine similarity function and a familiarity_scale parameter $\zeta_s$ controlling the extent to which item familiarity scales learning.

# %%
# preferred linear function
familiarity = lambda familiarity_scale, similarity: np.multiply(1-similarity, familiarity_scale) + 1

# power law function
familiarity = lambda familiarity_scale, similarity: np.power(np.multiply(1-similarity, familiarity_scale) + 1, 3) + 1

# exponential function
familiarity = lambda familiarity_scale, similarity: np.power(familiarity_scale, 1-similarity)

# %%
# export

from numba import njit
import numpy as np

@njit
def familiarity_weighting(familiarity_scale, similarity):
    return np.power(1-similarity, familiarity_scale)

# %% [markdown]
# ## How Do Values of $\zeta_i$ Vary?

# %% [markdown]
# Given the kinds of representation states that $f_i$ and $c_i$ can have under simulation of CMR and how cosine similarity works, $(S(f_i, c_i)$ always ranges in (0, 1). Furthermore, we enforce that for items encoded for the first time (and preserving the orthogonality assumption for item representations), familiarity always a neutral effect on learning (i.e., $\zeta_i = 1$). In theory, when $c_i$ and $f_i$ are equivalent, no learning happens. But in practice, the representations always differ at least a little. $\zeta_s$ is intended to control the extent to which item familiarity constrains learning. When $\zeta_s = 1$, the function is linear. At very high values of $\zeta_s$, the effect of familiarity on learning is neutral across all relevant similarity values. Alternatively, as $\zeta_s$ approaches zero, only completely unfamiliar items influence recall.

# %%
import numpy as np
import matplotlib.pyplot as plt

similarity_values = np.arange(0, 1.01, .01)

for familiarity_scale in[0, .5, 1, 2]:
    plt.plot(similarity_values, [familiarity_weighting(familiarity_scale, s) for s in similarity_values], label=str(familiarity_scale))

plt.title('How Learning Modulation Varies With Familiarity and Parameter Values')
plt.ylabel('Learning Modulation')
plt.xlabel('Similarity Between Current Context and Experience')
plt.legend(title='Parameter Value')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## How Do Values of $\zeta_i$ Configure Model Representations?
# We know $\zeta_i$ modulates $\Delta M^{CF}_{exp}$ in study lists with item repetitions. In particular, it intends to reduce context-to-item associations in $M^{CF}$ corresponding to the repeated study item depending on the spacing between item presentations (but also other factors configuring item familiarity, like the rate of contextual drift).
#
# We can visualize this effect by simulating processing of a study list with item repetitions using CMR with different parameter values, and then inspecting the summed support for recall of each item across possible contextual inputs in $M^{CF}$.

# %%
from compmemlearn.models import Classic_CMR

free_parameters = [
    'encoding_drift_rate',
    'start_drift_rate',
    'recall_drift_rate',
    'shared_support',
    'item_support',
    'learning_rate',
    'primacy_scale',
    'primacy_decay',
    'stop_probability_scale',
    'stop_probability_growth',
    'choice_sensitivity',
    'familiarity_scale']

fit_values = [6.69941126e-01, 1.09189743e-01, 8.93439617e-01, 4.33712328e-03,
            3.07498806e-01, 3.63436921e-02, 9.46980497e+00, 9.45689916e+01,
            1.64802945e-02, 3.06620677e-01, 2.04345530e+00]

parameters = {free_parameters[i]:fit_values[i] for i in range(len(fit_values))}
parameters['sampling_rule'] = 0

# %%
# repeat the 3-indexed item at position 10, and the 10-index item at position 14
presentation = [0, 1, 2, 3, 4, 5, 6, 7, 3, 8, 9, 10, 10, 11, 12, 13, 14, 13, 15, 16]

f, (ax1, ax2) = plt.subplots(2, 1, sharey=False, figsize=(8, 8))

for scale in [0, .5, 1, 1.75, 5, 10]:
    
    test_params = parameters.copy()
    test_params['familiarity_scale'] = scale
    
    item_count = np.max(presentation)+1
    model = Classic_CMR(**{'item_count': item_count, 'presentation_count': len(presentation), **test_params})

    # simulate study events
    model.experience(np.eye(model.item_count, model.item_count)[presentation])

    #plot_states(model.mcf, 'Final Mcf')
    ax1.plot(np.arange(16), np.sum(model.mcf, axis=0)[1:], label=str(scale))
    ax2.plot(np.arange(17), np.sum(model.mfc, axis=1), label=str(scale))
    
#ax1.set_legend(title='familiarity_scale')
ax1.set_title('Total Mcf Weights Supporting Recall of Each Item')
ax2.set_title('Total Mfc Weights Supporting Recall of Each Item')
ax1.set_xlabel('Item Index')
ax2.set_xlabel('Item Index')
ax2.set_ylabel('np.sum(model.mcf, axis=0)')
ax1.set_ylabel('np.sum(model.mcf, axis=0)')
plt.tight_layout()
plt.show()

# %% [markdown]
# Later, values in $M^{CF}$ configure the activation of each item during recall as context evolves:
#
# $$
# a = M^{CF}c
# $$
#
# With the probability of recalling items based on their activation varying according to:
#
# $$
# P(i, j) = (1-P(stop, j))\frac{a^{\tau}_i}{\sum_{k}^{N}a^{\tau}_k}
# $$
#
# $\tau$ is thus another parameter configuring how influential deficient encoding is on predicted recalls; at high values of $\tau$, small differences in context-to-item associations encoded in $M^{CF}$ and retrievable given a state of $c$ drive stronger differences between items' probability of being recalled.

# %% [markdown]
# ## How Do Values of $\zeta_s$ Configure the Spacing Effect?
# We intend for $\zeta_s$ to control the distinction in learning between highly familiar and highly novel items. Greater values for the parameter should correspond to less learning for mass-repeated items relative to that of spaced-repeated items, but no difference in learning for singly-presented items. We'll demo this functionality using the trials presented by Lohnas & Kahana (2015) to study repetition memory.

# %%
from compmemlearn.datasets import prepare_lohnas2014_data
from compmemlearn.analyses import sim_recall_probability_by_lag

trials, events, list_length, presentations, list_types, rep_data, subjects = prepare_lohnas2014_data(
    '../../data/repFR.mat')

events.head()
# Out:
#    subject  list  item  input  output  study  recall  repeat  intrusion  \
# 0        1     1     0      1     1.0   True    True       0      False
# 1        1     1     1      2     2.0   True    True       0      False
# 2        1     1     2      3     3.0   True    True       0      False
# 3        1     1     3      4     4.0   True    True       0      False
# 4        1     1     4      5     5.0   True    True       0      False
#
#    condition
# 0          4
# 1          4
# 2          4
# 3          4
# 4          4

# %%
for scale in [.5, 1, 1.75, 5]:
    print(scale)
    
    test_params = parameters.copy()
    test_params['familiarity_scale'] = scale

    result = sim_recall_probability_by_lag(
        Classic_CMR, {'presentation_count': 40, **test_params}, 
        presentations[list_types==4], experiment_count=100)[-1]

    print(result)

    plt.plot(['N/A', '0', '1-2', '3-5', '6-8'], result, label=str(scale))

plt.xlabel('Number of Intervening Items Between Repetitions')
plt.ylabel('Recall Probability')
plt.legend()
plt.show()
# Out:
# 0.5
# [0.18954252 0.30732143 0.35594643 0.35857143 0.36142857]
# 1
# [0.19000935 0.30335714 0.350375   0.3577619  0.35920238]
# 1.75
# [0.19109184 0.29882143 0.34371429 0.35584524 0.35569048]
# 5
# [0.19259099 0.29242857 0.33467857 0.34957143 0.35430952]

# %% [markdown]
# ## Does CMR With Differential Encoding fit Better to Repetition Memory Data?
# To find out, we'll fit CMR to the data presented by Lohnas & Kahana (2015) to study repetition memory, once freeing the familiarity_scale parameter and once fixing it to a value of 1. Then we'll compare the fits. If the model doesn't fit better, that's really bizarre.

# %%
from compmemlearn.fitting import cmr_rep_objective_function
from scipy.optimize import differential_evolution

# %%
base_cmr_free_parameters = [
    'encoding_drift_rate',
    'start_drift_rate',
    'recall_drift_rate',
    'shared_support',
    'item_support',
    'learning_rate',
    'primacy_scale',
    'primacy_decay',
    'stop_probability_scale',
    'stop_probability_growth',
    'choice_sensitivity']

lb = np.finfo(float).eps
ub = 1-np.finfo(float).eps

base_cmr_bounds = [
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, 100),
    (lb, 100),
    (lb, ub),
    (lb, 10),
    (lb, 10)
]

# cost function to be minimized
# ours scales inversely with the probability that the data could have been 
# generated using the specified parameters and our model
selection = list_types > 0
cost_function = cmr_rep_objective_function(
    trials[selection], presentations[selection], list_types[selection], list_length,
    {'sampling_rule': 0, 'familiarity_scale': 0}, base_cmr_free_parameters)

base_cmr_result = differential_evolution(cost_function, base_cmr_bounds, disp=True)
print(base_cmr_result)
# Out:
# differential_evolution step 1: f(x)= 101691
# differential_evolution step 2: f(x)= 80620.9
# differential_evolution step 3: f(x)= 76038.7
# differential_evolution step 4: f(x)= 69068.7
# differential_evolution step 5: f(x)= 68499.5
# differential_evolution step 6: f(x)= 68499.5
# differential_evolution step 7: f(x)= 68072.9
# differential_evolution step 8: f(x)= 68017.4
# differential_evolution step 9: f(x)= 68017.4
# differential_evolution step 10: f(x)= 66716.7
# differential_evolution step 11: f(x)= 66461.9
# differential_evolution step 12: f(x)= 66461.9
# differential_evolution step 13: f(x)= 64689.2
# differential_evolution step 14: f(x)= 62862.9
# differential_evolution step 15: f(x)= 62862.9
# differential_evolution step 16: f(x)= 62862.9
# differential_evolution step 17: f(x)= 62862.9
# differential_evolution step 18: f(x)= 62862.9
# differential_evolution step 19: f(x)= 62329.1
# differential_evolution step 20: f(x)= 62329.1
# differential_evolution step 21: f(x)= 61536.2
# differential_evolution step 22: f(x)= 61244.2
# differential_evolution step 23: f(x)= 61244.2
# differential_evolution step 24: f(x)= 61244.2
# differential_evolution step 25: f(x)= 61244.2
# differential_evolution step 26: f(x)= 61244.2
# differential_evolution step 27: f(x)= 61244.2
# differential_evolution step 28: f(x)= 61244.2
# differential_evolution step 29: f(x)= 61244.2
# differential_evolution step 30: f(x)= 61244.2
# differential_evolution step 31: f(x)= 61244.2
# differential_evolution step 32: f(x)= 61244.2
# differential_evolution step 33: f(x)= 61244.2
# differential_evolution step 34: f(x)= 60883.3
#      fun: 60478.1019466284
#      jac: array([ 1.08630047,  0.11132215,  1.36933522, -1.69166015,  5.53409336,
#         0.08294592,  0.04947651, -0.57843863, -0.22919266,  0.87893568,
#         0.30195224])
#  message: 'Optimization terminated successfully.'
#     nfev: 9135
#      nit: 34
#  success: True
#        x: array([8.44372928e-01, 4.81458492e-01, 9.64223664e-01, 4.65816632e-02,
#        2.22044605e-16, 4.10940675e-01, 4.40233307e+00, 3.66840572e-01,
#        2.51597155e-02, 1.01414510e-01, 1.14330514e+00])

# %% [markdown]
# ```
#      fun: 60842.736553683644
#      jac: array([ 0.01309672, -0.21682354,  1.12049747, -7.79909897, -0.17607817,
#        -0.31723175, -0.05311449,  0.        ,  1.80007191, -4.10509529,
#         0.65920176])
#  message: 'Optimization terminated successfully.'
#     nfev: 8460
#      nit: 39
#  success: True
#        x: array([8.55701851e-01, 8.69404926e-01, 9.57492934e-01, 3.59862056e-02,
#        4.19323374e-02, 4.60108719e-01, 1.29818878e+00, 3.68807430e+01,
#        2.51672402e-02, 1.01401624e-01, 1.14216028e+00])
# ```

# %%
cmrde_free_parameters = [
    'encoding_drift_rate',
    'start_drift_rate',
    'recall_drift_rate',
    'shared_support',
    'item_support',
    'learning_rate',
    'primacy_scale',
    'primacy_decay',
    'stop_probability_scale',
    'stop_probability_growth',
    'choice_sensitivity',
    'familiarity_scale']

lb = np.finfo(float).eps
ub = 1-np.finfo(float).eps

cmrde_bounds = [
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, 100),
    (lb, 100),
    (lb, ub),
    (lb, 10),
    (lb, 10),
    (lb, 100),
]

# cost function to be minimized
# ours scales inversely with the probability that the data could have been 
# generated using the specified parameters and our model
selection = list_types > 0
cost_function = cmr_rep_objective_function(
    trials[selection], presentations[selection], list_types[selection], list_length,
    {'sampling_rule': 0}, cmrde_free_parameters)

cmrde_result = differential_evolution(cost_function, cmrde_bounds, disp=True)
print(cmrde_result)
# Out:
# differential_evolution step 1: f(x)= 73570.1
# differential_evolution step 2: f(x)= 73570.1
# differential_evolution step 3: f(x)= 73570.1
# differential_evolution step 4: f(x)= 73570.1
# differential_evolution step 5: f(x)= 67931.5
# differential_evolution step 6: f(x)= 67931.5
# differential_evolution step 7: f(x)= 67054.4
# differential_evolution step 8: f(x)= 67054.4
# differential_evolution step 9: f(x)= 64490.6
# differential_evolution step 10: f(x)= 64490.6
# differential_evolution step 11: f(x)= 64490.6
# differential_evolution step 12: f(x)= 63677.5
# differential_evolution step 13: f(x)= 63677.5
# differential_evolution step 14: f(x)= 63410.5
# differential_evolution step 15: f(x)= 63252.5
# differential_evolution step 16: f(x)= 62552.7
# differential_evolution step 17: f(x)= 62478.8
# differential_evolution step 18: f(x)= 62181.2
# differential_evolution step 19: f(x)= 61762.9
# differential_evolution step 20: f(x)= 61678.3
# differential_evolution step 21: f(x)= 61678.3
# differential_evolution step 22: f(x)= 61678.3
# differential_evolution step 23: f(x)= 61678.3
# differential_evolution step 24: f(x)= 61651.6
# differential_evolution step 25: f(x)= 61651.6
# differential_evolution step 26: f(x)= 61506.2
# differential_evolution step 27: f(x)= 61453
# differential_evolution step 28: f(x)= 61419.8
# differential_evolution step 29: f(x)= 61419.8
# differential_evolution step 30: f(x)= 61419.8
# differential_evolution step 31: f(x)= 61324.4
# differential_evolution step 32: f(x)= 61324.4
# differential_evolution step 33: f(x)= 61324.4
# differential_evolution step 34: f(x)= 61324.4
# differential_evolution step 35: f(x)= 61108
# differential_evolution step 36: f(x)= 60945.8
# differential_evolution step 37: f(x)= 60933.1
#      fun: 60471.64108291889
#      jac: array([ 0.28885552,  0.47075446, -1.35842128, -2.51675374, 19.81898095,
#         0.24956534,  1.49884728, -0.46202331, -3.47135938, -2.5749614 ,
#        -0.59953891,  2.22353246])
#  message: 'Optimization terminated successfully.'
#     nfev: 7854
#      nit: 37
#  success: True
#        x: array([8.29539342e-01, 5.00393783e-01, 9.54782950e-01, 7.18117014e-02,
#        2.22044605e-16, 5.01675115e-01, 2.64162525e+00, 3.47775346e-01,
#        2.51609814e-02, 1.01410988e-01, 1.57114916e+00, 2.52982250e+01])

# %% [markdown]
# ```
#      fun: 60656.759693958404
#      jac: array([-9.82254273e-02, -3.66708262e-01, -1.33222783e+00, -1.03929778e+01,
#         2.59315129e+00, -8.09086483e-01,  7.27595701e-04,  0.00000000e+00,
#         1.49870175e+01,  8.64965842e+00,  4.35102268e-01,  3.05590195e-02])
#  message: 'Optimization terminated successfully.'
#     nfev: 6977
#      nit: 27
#  success: True
#        x: array([8.29834655e-01, 7.86606041e-01, 9.50948923e-01, 1.00000000e+00,
#        2.22044605e-16, 5.26894655e-01, 2.35109439e+01, 3.59834568e+01,
#        2.51636523e-02, 1.01413145e-01, 1.75875098e+00, 1.22323634e+01])
#
# ```

# %%
def aic(k, likelihood):
    return 2*k + 2*likelihood

# %%
aic(11, 60842.73)
# Out:
# 121707.46

# %%
aic(12, 60656.75)
# Out:
# 121337.5

# %%
np.exp((121337.5 - 121707.46)/2)
# Out:
# 4.615372281957718e-81

# %% [markdown]
# ## Does CMR with Differential Encoding Generalize Better Across List Types?
# Fit each version of CMR to conditions 2, 3, and 4. Then compare predictions about behavior in the control condition. Look at overall predictive accuracy, serial position curve, lag-CRP, and probability of first recall.

# %%
base_cmr_free_parameters = [
    'encoding_drift_rate',
    'start_drift_rate',
    'recall_drift_rate',
    'shared_support',
    'item_support',
    'learning_rate',
    'primacy_scale',
    'primacy_decay',
    'stop_probability_scale',
    'stop_probability_growth',
    'choice_sensitivity']

lb = np.finfo(float).eps
ub = 1-np.finfo(float).eps

base_cmr_bounds = [
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, 100),
    (lb, 100),
    (lb, ub),
    (lb, 10),
    (lb, 10)
]

# cost function to be minimized
# ours scales inversely with the probability that the data could have been 
# generated using the specified parameters and our model
selection = list_types > 1
cost_function = cmr_rep_objective_function(
    trials[selection], presentations[selection], list_types[selection], list_length,
    {'sampling_rule': 0, 'familiarity_scale': 0}, base_cmr_free_parameters)

base_cmr_result = differential_evolution(cost_function, base_cmr_bounds, disp=True)
print(base_cmr_result)
# Out:
# differential_evolution step 1: f(x)= 94365
# differential_evolution step 2: f(x)= 53000.8
# differential_evolution step 3: f(x)= 53000.8
# differential_evolution step 4: f(x)= 47663.1
# differential_evolution step 5: f(x)= 47663.1
# differential_evolution step 6: f(x)= 47663.1
# differential_evolution step 7: f(x)= 46223.4
# differential_evolution step 8: f(x)= 45180.1
# differential_evolution step 9: f(x)= 44206.2
# differential_evolution step 10: f(x)= 44206.2
# differential_evolution step 11: f(x)= 44206.2
# differential_evolution step 12: f(x)= 44206.2
# differential_evolution step 13: f(x)= 44206.2
# differential_evolution step 14: f(x)= 44138.9
# differential_evolution step 15: f(x)= 44138.9
# differential_evolution step 16: f(x)= 43375.1
# differential_evolution step 17: f(x)= 43238.1
# differential_evolution step 18: f(x)= 43238.1
# differential_evolution step 19: f(x)= 43238.1
# differential_evolution step 20: f(x)= 42818.7
# differential_evolution step 21: f(x)= 42726.9
# differential_evolution step 22: f(x)= 42392.9
# differential_evolution step 23: f(x)= 42160.2
# differential_evolution step 24: f(x)= 42160.2
# differential_evolution step 25: f(x)= 42160.2
# differential_evolution step 26: f(x)= 42160.2
# differential_evolution step 27: f(x)= 42160.2
# differential_evolution step 28: f(x)= 42120.5
# differential_evolution step 29: f(x)= 42120.5
# differential_evolution step 30: f(x)= 42028
# differential_evolution step 31: f(x)= 42028
# differential_evolution step 32: f(x)= 42028
# differential_evolution step 33: f(x)= 42028
# differential_evolution step 34: f(x)= 42028
# differential_evolution step 35: f(x)= 42028
#      fun: 41777.52411653746
#      jac: array([ 0.28740032,  1.05137587,  0.31068339,  0.22118911,  3.93338269,
#        -1.42608769,  0.02619345,  0.        , -8.97853169, -3.47208698,
#         0.32014214])
#  message: 'Optimization terminated successfully.'
#     nfev: 6720
#      nit: 35
#  success: True
#        x: array([8.52679304e-01, 8.88007930e-01, 9.51255248e-01, 5.31490779e-02,
#        2.22044605e-16, 4.18946033e-01, 1.18850472e+00, 6.24806635e+01,
#        2.18345065e-02, 1.21199318e-01, 1.24286060e+00])

# %% [markdown]
# ```
#      fun: 41497.26353317461
#      jac: array([-4.24479365e+00, -5.58793542e-01,  6.70843289e-01, -1.51339918e-01,
#         2.24936230e+01,  1.60798663e+00, -1.89174899e-02,  7.56699592e-02,
#         5.57047315e+00,  2.18060450e+00, -4.94765121e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 7332
#      nit: 31
#  success: True
#        x: array([8.28973398e-01, 5.33964911e-01, 9.57801515e-01, 8.04512609e-02,
#        2.22044605e-16, 3.56305996e-01, 3.86494049e+00, 3.13622019e-01,
#        2.18382083e-02, 1.21198764e-01, 1.31666973e+00])
# ```

# %%
cmrde_free_parameters = [
    'encoding_drift_rate',
    'start_drift_rate',
    'recall_drift_rate',
    'shared_support',
    'item_support',
    'learning_rate',
    'primacy_scale',
    'primacy_decay',
    'stop_probability_scale',
    'stop_probability_growth',
    'choice_sensitivity',
    'familiarity_scale']

lb = np.finfo(float).eps
ub = 1-np.finfo(float).eps

cmrde_bounds = [
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, ub),
    (lb, 100),
    (lb, 100),
    (lb, ub),
    (lb, 10),
    (lb, 10),
    (lb, 100),
]

# cost function to be minimized
# ours scales inversely with the probability that the data could have been 
# generated using the specified parameters and our model
selection = list_types > 1
cost_function = cmr_rep_objective_function(
    trials[selection], presentations[selection], list_types[selection], list_length,
    {'sampling_rule': 0}, cmrde_free_parameters)

cmrde_result = differential_evolution(cost_function, cmrde_bounds, disp=True)
print(cmrde_result)
# Out:
# differential_evolution step 1: f(x)= 98416.9
# differential_evolution step 2: f(x)= 56320.4
# differential_evolution step 3: f(x)= 50287.6
# differential_evolution step 4: f(x)= 48534.3
# differential_evolution step 5: f(x)= 48534.3
# differential_evolution step 6: f(x)= 47523.2
# differential_evolution step 7: f(x)= 47523.2
# differential_evolution step 8: f(x)= 47022.5
# differential_evolution step 9: f(x)= 43342.3
# differential_evolution step 10: f(x)= 43342.3
# differential_evolution step 11: f(x)= 43342.3
# differential_evolution step 12: f(x)= 43342.3
# differential_evolution step 13: f(x)= 43342.3
# differential_evolution step 14: f(x)= 43342.3
# differential_evolution step 15: f(x)= 43342.3
# differential_evolution step 16: f(x)= 42973.4
# differential_evolution step 17: f(x)= 42973.4
# differential_evolution step 18: f(x)= 42973.4
# differential_evolution step 19: f(x)= 42973.4
# differential_evolution step 20: f(x)= 42614.2
# differential_evolution step 21: f(x)= 42614.2
# differential_evolution step 22: f(x)= 42439
# differential_evolution step 23: f(x)= 42439
# differential_evolution step 24: f(x)= 42439
# differential_evolution step 25: f(x)= 42439
# differential_evolution step 26: f(x)= 42439
# differential_evolution step 27: f(x)= 42421.1
# differential_evolution step 28: f(x)= 42391.9
# differential_evolution step 29: f(x)= 42098.8
# differential_evolution step 30: f(x)= 42079.8
# differential_evolution step 31: f(x)= 42079.8
# differential_evolution step 32: f(x)= 42079.8
# differential_evolution step 33: f(x)= 42079.8
# differential_evolution step 34: f(x)= 42079.8
# differential_evolution step 35: f(x)= 42079.8
# differential_evolution step 36: f(x)= 42046.7
# differential_evolution step 37: f(x)= 42024.1
# differential_evolution step 38: f(x)= 42024.1
# differential_evolution step 39: f(x)= 42024.1
#      fun: 41648.40745886476
#      jac: array([ 0.9436917 , -0.64610503, -0.68830559, -0.26921043, 15.31298039,
#        -0.53551048, -0.17535058,  0.        , 10.59670467,  3.77403922,
#        -1.10521797,  1.91503206])
#  message: 'Optimization terminated successfully.'
#     nfev: 8877
#      nit: 39
#  success: True
#        x: array([8.34334711e-01, 8.13678562e-01, 9.46335352e-01, 1.06810557e-01,
#        2.22044605e-16, 5.25683715e-01, 9.24170714e-01, 5.86072743e+01,
#        2.18401749e-02, 1.21196832e-01, 1.94326446e+00, 1.59401242e+00])

# %% [markdown]
# ```
#      fun: 41643.775624569986
#      jac: array([ -0.85201463,   1.12049747,   0.82000042, -18.4540112 ,
#          4.33356036,  -0.04802132,   0.63664624,   0.        ,
#        -15.39592631,  -3.65762389,  -1.56505849,   0.19354046])
#  message: 'Optimization terminated successfully.'
#     nfev: 5982
#      nit: 24
#  success: True
#        x: array([8.34919784e-01, 8.06042311e-01, 9.48380699e-01, 1.00000000e+00,
#        2.22044605e-16, 4.79395179e-01, 2.22187175e+01, 5.17768644e+01,
#        2.18282918e-02, 1.21211177e-01, 1.75392471e+00, 1.11957669e+01])
# ```

# %%
events.head()
# Out:
#    subject  list  item  input  output  study  recall  repeat  intrusion  \
# 0        1     1     0      1     1.0   True    True       0      False
# 1        1     1     1      2     2.0   True    True       0      False
# 2        1     1     2      3     3.0   True    True       0      False
# 3        1     1     3      4     4.0   True    True       0      False
# 4        1     1     4      5     5.0   True    True       0      False
#
#    condition
# 0          4
# 1          4
# 2          4
# 3          4
# 4          4

# %%
def extended_apply_and_concatenate(function, dfs, contrast_name='contrast', labels='AB'):
    """
    Concatenates the results of a function applied to passed dataframes and creates a new column identifying the contrast.
    """
    return pd.concat([function(df) for df in dfs], keys=labels, names=[contrast_name]).reset_index()

# %%
from compmemlearn.datasets import prepare_lohnas2014_data, simulate_data
from psifr import fr
import pandas as pd

base_model = Classic_CMR(
    **{**{'item_count': list_length, 'presentation_count': list_length, 'sampling_rule': 0, 'familiarity_scale': 1},
    **{base_cmr_free_parameters[i]:base_cmr_result.x[i] for i in range(len(base_cmr_result.x))}})

de_model = Classic_CMR(
    **{**{'item_count': list_length, 'presentation_count': list_length, 'sampling_rule': 0},
    **{cmrde_free_parameters[i]:cmrde_result.x[i] for i in range(len(cmrde_result.x))}})

base_df = simulate_data(base_model, 1000)
de_df = simulate_data(de_model, 1000)

dfs = [base_df, de_df, events.loc[events.condition == 1]]
labels = ['CMR', 'CMR-DE', 'Data']

spc = extended_apply_and_concatenate(fr.spc, dfs, contrast_name='source', labels=labels)
lag_crp = extended_apply_and_concatenate(fr.lag_crp, dfs, contrast_name='source', labels=labels)
pfr = extended_apply_and_concatenate(fr.pnr, dfs, contrast_name='source', labels=labels)
pfr = pfr.query('output <= 1')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")

sns.lineplot(data=spc, x='input', y='recall', err_style='bars', hue='source', legend=True, ci=False)
plt.show()

max_lag = 5
filt_neg = f'{-max_lag} <= lag < 0'
filt_pos = f'0 < lag <= {max_lag}'

sns.lineplot(data=lag_crp.query(filt_neg), x='lag', y='prob', 
             err_style='bars', hue='source', legend=False)
sns.lineplot(data=lag_crp.query(filt_pos), x='lag', y='prob', 
             err_style='bars', hue='source', legend=True)
plt.show()

sns.lineplot(data=pfr, x='input', y='prob', err_style='bars', hue='source', legend=True)
plt.show()

sns.catplot(data=spc, x='source', y='recall', kind='bar')
plt.show()
